# %% [markdown]
# <h1 align="center" style="margin-bottom: 20px;">Machine Learning 2024-25</h1>
# <h3 align="center" style="margin-top: 20px; margin-bottom: 20px;">To Grant or Not to Grant: Deciding on Compensation Benefits</h3>
# <h5 align="center" style="margin-top: 20px; margin-bottom: 0px;">Cross-Validation for Models with Default Parameters</h5>
#
# ### Group 38 - Members:
# - Ana Marta Azinheira  - 20240496@novaims.unl.pt
# - Braulio Damba - 20240007@novaims.unl.pt
# - Catarina Ribeirinha - 20240507@novaims.unl.pt
# - Marco Galão  - r20201545@novaims.unl.pt
# - Rodrigo Sardinha - 20211627@novaims.unl.pt

# %% [markdown]
# # Table of Contents
#
# * [1. Imports](#imports)
#   * [1.1. Import Libraries](#import_libraries)
#   * [1.2. Imports Datasets](#import_datasets)
#
# * [2. Cross-Validation for Models with Default Parameters](#cv_default_parameters)

# %% [markdown]
# # 1. Imports <a id="imports"></a>

# %% [markdown]
# ## 1.1. Import the Libraries <a class="anchor" id="import_libraries"></a>

# %%
# Cross Validation Utils
from utils import *

# Visualization Settings
# %config InlineBackend.figure_format = 'retina'
sns.set()

# Omit Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1.2. Import the Datasets <a class="anchor" id="import_datasets"></a>

# %%
# Define date columns to parse
date_cols = ["Accident Date", "Assembly Date", "C-2 Date", "C-3 Date", "First Hearing Date"]

# %%
df = pd.read_csv('df_nb2.csv', sep=',', parse_dates=date_cols, index_col='Claim Identifier')
df.head()
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5393875             2019-12-30             31                             0.0
# 5393091             2019-08-30             46                             0.0
# 5393889             2019-12-06             40                             0.0
# 5393887             2019-12-30             61                             0.0
# 5393863             2019-12-26             67                             0.0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393875             2020-01-01                        0                 0.00
# 5393091             2020-01-01                        1              1745.93
# 5393889             2020-01-01                        0              1434.80
# 5393887             2020-01-01                        0                  NaN
# 5393863             2020-01-01                        0                 0.00
#
#                    C-2 Date   C-3 Date                       Carrier Name  \
# Claim Identifier
# 5393875          2019-12-31        NaT    new hampshire insurance company
# 5393091          2020-01-01 2020-01-01  zurich american insurance company
# 5393889          2020-01-01        NaT     indemnity insurance company of
# 5393887          2019-12-31        NaT               state insurance fund
# 5393863          2019-12-31        NaT   indemnity insurance of n america
#
#                  Carrier Type  ...  \
# Claim Identifier               ...
# 5393875           1A. PRIVATE  ...
# 5393091           1A. PRIVATE  ...
# 5393889           1A. PRIVATE  ...
# 5393887               2A. SIF  ...
# 5393863           1A. PRIVATE  ...
#
#                                           Industry Code Description  \
# Claim Identifier
# 5393875                                                RETAIL TRADE
# 5393091                                                CONSTRUCTION
# 5393889           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...
# 5393887                           HEALTH CARE AND SOCIAL ASSISTANCE
# 5393863                                                RETAIL TRADE
#
#                  Medical Fee Region  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                           I                       27.0
# 5393091                           I                       97.0
# 5393889                          II                       79.0
# 5393887                          II                       16.0
# 5393863                          IV                       31.0
#
#                  WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 5393875              FROM LIQUID OR GREASE SPILLS                       10.0
# 5393091                         REPETITIVE MOTION                       49.0
# 5393889            OBJECT BEING LIFTED OR HANDLED                        7.0
# 5393887           HAND TOOL, UTENSIL; NOT POWERED                       43.0
# 5393863                   FALL, SLIP OR TRIP, NOC                       10.0
#
#                   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5393875                                   CONTUSION                   62.0
# 5393091                              SPRAIN OR TEAR                   38.0
# 5393889                                  CONCUSSION                   10.0
# 5393887                                    PUNCTURE                   36.0
# 5393863                                   CONTUSION                   38.0
#
#                  WCIO Part Of Body Description  Zip Code Male
# Claim Identifier
# 5393875                               BUTTOCKS   13662.0  1.0
# 5393091                            SHOULDER(S)   14569.0  0.0
# 5393889                   MULTIPLE HEAD INJURY   12589.0  1.0
# 5393887                              FINGER(S)   12603.0  1.0
# 5393863                            SHOULDER(S)   11772.0  1.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # 2. Cross-Validation for Models with Default Parameters <a id="cv_default_parameters"></a>

# %%
# Define default models
models_default_parameters = {
    "Adaboost": {},
    "Bagging": {},
    "DecisionTree": {},
    # "GBM": {},
    "GaussianNB": {},
    "LogisticRegression": {},
    "NeuralNetworks": {},
    "RandomForest": {},
    # "SVM": {},
    "XGBoost": {},
}

# Using default models to choose which ones to optimize
default_models = define_models(models_default_parameters)
results, results_df = show_results(default_models, df, feats_dict)
results_df
# Out:
# --------------------------------------------------------------------------------
# CV Iteration 1
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.286, F1 Train = 0.287, F1 Val-Train = -0.002, Time (s) = 14.85, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.343, F1 Train = 0.995, F1 Val-Train = -0.652, Time (s) = 151.63, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.360, F1 Train = 0.548, F1 Val-Train = -0.188, Time (s) = 34.72, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.351, F1 Train = 0.957, F1 Val-Train = -0.606, Time (s) = 47.46, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.319, F1 Train = 0.995, F1 Val-Train = -0.676, Time (s) = 6.24, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.336, F1 Train = 0.339, F1 Val-Train = -0.003, Time (s) = 91.21, Avg Iter = 96.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.263, F1 Train = 0.264, F1 Val-Train = -0.001, Time (s) = 17.94, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.331, F1 Train = 0.445, F1 Val-Train = -0.114, Time (s) = 597.88, Avg Iter = 0.0 Best Params = {}
#
# --------------------------------------------------------------------------------
# CV Iteration 2
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.299, F1 Train = 0.297, F1 Val-Train = 0.001, Time (s) = 9.45, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.351, F1 Train = 0.996, F1 Val-Train = -0.645, Time (s) = 89.60, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.338, F1 Train = 0.539, F1 Val-Train = -0.201, Time (s) = 25.83, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.358, F1 Train = 0.962, F1 Val-Train = -0.604, Time (s) = 25.36, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.326, F1 Train = 0.996, F1 Val-Train = -0.671, Time (s) = 4.04, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.355, F1 Train = 0.367, F1 Val-Train = -0.012, Time (s) = 133.39, Avg Iter = 137.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.259, F1 Train = 0.258, F1 Val-Train = 0.001, Time (s) = 17.53, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.334, F1 Train = 0.405, F1 Val-Train = -0.071, Time (s) = 583.92, Avg Iter = 0.0 Best Params = {}
#
# --------------------------------------------------------------------------------
# CV Iteration 3
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.301, F1 Train = 0.300, F1 Val-Train = 0.001, Time (s) = 8.22, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.348, F1 Train = 0.996, F1 Val-Train = -0.648, Time (s) = 79.45, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.369, F1 Train = 0.538, F1 Val-Train = -0.169, Time (s) = 24.32, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.358, F1 Train = 0.958, F1 Val-Train = -0.600, Time (s) = 24.07, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.327, F1 Train = 0.996, F1 Val-Train = -0.669, Time (s) = 3.96, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.355, F1 Train = 0.370, F1 Val-Train = -0.015, Time (s) = 109.32, Avg Iter = 126.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.251, F1 Train = 0.251, F1 Val-Train = -0.000, Time (s) = 16.24, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.346, F1 Train = 0.452, F1 Val-Train = -0.105, Time (s) = 542.81, Avg Iter = 0.0 Best Params = {}
#
# --------------------------------------------------------------------------------
# CV Iteration 4
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.299, F1 Train = 0.300, F1 Val-Train = -0.000, Time (s) = 8.29, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.349, F1 Train = 0.996, F1 Val-Train = -0.647, Time (s) = 78.81, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.365, F1 Train = 0.550, F1 Val-Train = -0.185, Time (s) = 23.51, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.354, F1 Train = 0.960, F1 Val-Train = -0.606, Time (s) = 22.31, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.320, F1 Train = 0.996, F1 Val-Train = -0.676, Time (s) = 3.40, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.344, F1 Train = 0.359, F1 Val-Train = -0.015, Time (s) = 91.52, Avg Iter = 106.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.252, F1 Train = 0.252, F1 Val-Train = -0.001, Time (s) = 16.60, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.335, F1 Train = 0.447, F1 Val-Train = -0.112, Time (s) = 541.29, Avg Iter = 0.0 Best Params = {}
#
# --------------------------------------------------------------------------------
# CV Iteration 5
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.288, F1 Train = 0.289, F1 Val-Train = -0.001, Time (s) = 8.74, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.343, F1 Train = 0.995, F1 Val-Train = -0.653, Time (s) = 79.49, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.367, F1 Train = 0.551, F1 Val-Train = -0.184, Time (s) = 24.39, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.357, F1 Train = 0.955, F1 Val-Train = -0.598, Time (s) = 22.77, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.321, F1 Train = 0.995, F1 Val-Train = -0.675, Time (s) = 3.10, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.352, F1 Train = 0.358, F1 Val-Train = -0.006, Time (s) = 82.48, Avg Iter = 96.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.247, F1 Train = 0.246, F1 Val-Train = 0.000, Time (s) = 16.96, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.337, F1 Train = 0.400, F1 Val-Train = -0.063, Time (s) = 568.56, Avg Iter = 0.0 Best Params = {}
#
# --------------------------------------------------------------------------------
# CV Iteration 6
# --------------------------------------------------------------------------------
#
# End of Preprocessing; Starting GridSearch
#
# Collecting Model Metrics
# LogisticRegression: F1 Val = 0.292, F1 Train = 0.293, F1 Val-Train = -0.001, Time (s) = 8.87, Avg Iter = 100.0 Best Params = {}
#
# Collecting Model Metrics
# RandomForest: F1 Val = 0.340, F1 Train = 0.996, F1 Val-Train = -0.656, Time (s) = 81.98, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# XGBoost: F1 Val = 0.358, F1 Train = 0.548, F1 Val-Train = -0.190, Time (s) = 24.32, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# Bagging: F1 Val = 0.352, F1 Train = 0.961, F1 Val-Train = -0.608, Time (s) = 24.18, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# DecisionTree: F1 Val = 0.327, F1 Train = 0.996, F1 Val-Train = -0.670, Time (s) = 3.25, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# NeuralNetworks: F1 Val = 0.346, F1 Train = 0.345, F1 Val-Train = 0.001, Time (s) = 84.93, Avg Iter = 91.0 Best Params = {}
#
# Collecting Model Metrics
# Adaboost: F1 Val = 0.263, F1 Train = 0.262, F1 Val-Train = 0.001, Time (s) = 20.21, Avg Iter = 0.0 Best Params = {}
#
# Collecting Model Metrics
# GBM: F1 Val = 0.335, F1 Train = 0.444, F1 Val-Train = -0.109, Time (s) = 583.77, Avg Iter = 0.0 Best Params = {}
# ({'LogisticRegression': {'f1_diff_list': [-0.001618162205908047,
#     0.0012822632051325833,
#     0.0008005505163791726,
#     -0.0003934710380639195,
#     -0.0012772122519291718,
#     -0.0011351148696839286],
#    'f1_val_list': [0.2855670291575271,
#     0.29865893368073915,
#     0.30053454886475195,
#     0.29944216104840665,
#     0.2877362051309561,
#     0.2922147691613581],
#    'f1_train_list': [0.2871851913634351,
#     0.29737667047560656,
#     0.2997339983483728,
#     0.29983563208647057,
#     0.2890134173828853,
#     0.293349884031042],
#    'time_list': [14.8477392999921,
#     9.446232600021176,
#     8.218577799969353,
#     8.294494300032966,
#     8.74023319996195,
#     8.86878630000865],
#    'n_iter_list': [array([100], dtype=int32),
#     array([100], dtype=int32),
#     array([100], dtype=int32),
#     array([100], dtype=int32),
#     array([100], dtype=int32),
#     array([100], dtype=int32)],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'RandomForest': {'f1_diff_list': [-0.6522473990199411,
#     -0.6448292133885385,
#     -0.6480016802988688,
#     -0.6466855258655496,
#     -0.6526733072216002,
#     -0.6564812879945784],
#    'f1_val_list': [0.34267459732600153,
#     0.3514613738963989,
#     0.34827141547710966,
#     0.34922613425350757,
#     0.3427636978952929,
#     0.33987072236586224],
#    'f1_train_list': [0.9949219963459426,
#     0.9962905872849374,
#     0.9962730957759784,
#     0.9959116601190572,
#     0.9954370051168931,
#     0.9963520103604406],
#    'time_list': [151.6330838999711,
#     89.59548040002119,
#     79.44529190001776,
#     78.81338279996999,
#     79.49226129997987,
#     81.97529219998978],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'XGBoost': {'f1_diff_list': [-0.18807261064477204,
#     -0.20055530215495132,
#     -0.1687959838135955,
#     -0.184904931563399,
#     -0.18365197816487444,
#     -0.18968562559277558],
#    'f1_val_list': [0.3596428909816845,
#     0.33805537054314305,
#     0.3687536457541227,
#     0.3651841097749849,
#     0.36707255865112365,
#     0.358359056288592],
#    'f1_train_list': [0.5477155016264565,
#     0.5386106726980944,
#     0.5375496295677182,
#     0.5500890413383839,
#     0.5507245368159981,
#     0.5480446818813676],
#    'time_list': [34.720723199949134,
#     25.830198300012853,
#     24.3236837000004,
#     23.513595400028862,
#     24.38774989999365,
#     24.317006499972194],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'Bagging': {'f1_diff_list': [-0.605835526190015,
#     -0.6044699578298497,
#     -0.6001404758424372,
#     -0.6058251220100244,
#     -0.597703335382753,
#     -0.6084606125296002],
#    'f1_val_list': [0.35116744679504364,
#     0.35765079075584383,
#     0.3583242555899543,
#     0.35416990730584563,
#     0.3573870984543724,
#     0.35221392436402477],
#    'f1_train_list': [0.9570029729850587,
#     0.9621207485856935,
#     0.9584647314323915,
#     0.95999502931587,
#     0.9550904338371254,
#     0.9606745368936249],
#    'time_list': [47.45725549996132,
#     25.35902570001781,
#     24.072449999977835,
#     22.306835299998056,
#     22.76906839996809,
#     24.183781099971384],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'DecisionTree': {'f1_diff_list': [-0.6760934842533506,
#     -0.6707899467606002,
#     -0.6693016120115567,
#     -0.6756708067207113,
#     -0.6745319871672714,
#     -0.6697646702582118],
#    'f1_val_list': [0.31888956243795197,
#     0.32554963027446043,
#     0.3270251004462463,
#     0.3203065736338811,
#     0.320947632532786,
#     0.3266348325908973],
#    'f1_train_list': [0.9949830466913026,
#     0.9963395770350606,
#     0.996326712457803,
#     0.9959773803545925,
#     0.9954796197000574,
#     0.9963995028491092],
#    'time_list': [6.23896650003735,
#     4.042194899986498,
#     3.960467599972617,
#     3.40292830002727,
#     3.1030509999836795,
#     3.254728400032036],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'NeuralNetworks': {'f1_diff_list': [-0.0028853180893619323,
#     -0.012162465443354697,
#     -0.014653790873810357,
#     -0.014697861173528115,
#     -0.0058598698576718955,
#     0.0012163167688331034],
#    'f1_val_list': [0.3361943223534475,
#     0.3548295686106899,
#     0.3554203526972802,
#     0.3443545510372534,
#     0.35243208898713174,
#     0.3463686069535268],
#    'f1_train_list': [0.3390796404428094,
#     0.3669920340540446,
#     0.37007414357109053,
#     0.3590524122107815,
#     0.35829195884480364,
#     0.3451522901846937],
#    'time_list': [91.20924080000259,
#     133.39150319999317,
#     109.31884880003054,
#     91.52232129999902,
#     82.47988240001723,
#     84.93414939998183],
#    'n_iter_list': [96, 137, 126, 106, 96, 91],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'Adaboost': {'f1_diff_list': [-0.0006134994047106157,
#     0.0005376473191984199,
#     -0.00048822991411123784,
#     -0.0008457876811909792,
#     0.00012976607531936524,
#     0.0008399344106169715],
#    'f1_val_list': [0.2628886163478292,
#     0.25885000563781774,
#     0.25099307099870766,
#     0.2515792184629683,
#     0.2466213062829069,
#     0.26272191069574335],
#    'f1_train_list': [0.2635021157525398,
#     0.2583123583186193,
#     0.2514813009128189,
#     0.2524250061441593,
#     0.24649154020758754,
#     0.2618819762851264],
#    'time_list': [17.936234600027092,
#     17.529057600011583,
#     16.24254700000165,
#     16.601734400028363,
#     16.95699469995452,
#     20.21266730001662],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]},
#   'GBM': {'f1_diff_list': [-0.11369769062044743,
#     -0.07064290825478431,
#     -0.10542921725659726,
#     -0.1120344470343641,
#     -0.06321543196781149,
#     -0.10920236777006376],
#    'f1_val_list': [0.33144652140747116,
#     0.3341645466379956,
#     0.3464444200939124,
#     0.3353338402272399,
#     0.33694839861839787,
#     0.33457000912580503],
#    'f1_train_list': [0.4451442120279186,
#     0.4048074548927799,
#     0.45187363735050967,
#     0.447368287261604,
#     0.40016383058620936,
#     0.4437723768958688],
#    'time_list': [597.8781947000534,
#     583.9206877999823,
#     542.8108155999798,
#     541.2918729999801,
#     568.5591912000091,
#     583.7691662000143],
#    'n_iter_list': [[0], [0], [0], [0], [0], [0]],
#    'best_params_list': [{}, {}, {}, {}, {}, {}]}},
#                              F1 Val        F1 Train     F1 Val-Train  \
#  XGBoost             0.360 +/- 0.01  0.545 +/- 0.01  -0.186 +/- 0.01
#  Bagging             0.355 +/- 0.00  0.959 +/- 0.00  -0.604 +/- 0.00
#  NeuralNetworks      0.348 +/- 0.01  0.356 +/- 0.01  -0.008 +/- 0.01
#  RandomForest        0.346 +/- 0.00  0.996 +/- 0.00  -0.650 +/- 0.00
#  GBM                 0.336 +/- 0.00  0.432 +/- 0.02  -0.096 +/- 0.02
#  DecisionTree        0.323 +/- 0.00  0.996 +/- 0.00  -0.673 +/- 0.00
#  LogisticRegression  0.294 +/- 0.01  0.294 +/- 0.00  -0.000 +/- 0.00
#  Adaboost            0.256 +/- 0.01  0.256 +/- 0.01  -0.000 +/- 0.00
#
#                               Time (s)      Iterations Best Params
#  XGBoost               26.182 +/- 3.88     0.0 +/- 0.0        None
#  Bagging               27.691 +/- 8.90     0.0 +/- 0.0        None
#  NeuralNetworks       98.809 +/- 17.68  108.7 +/- 17.0        None
#  RandomForest         93.492 +/- 26.26     0.0 +/- 0.0        None
#  GBM                 569.705 +/- 21.31     0.0 +/- 0.0        None
#  DecisionTree           4.000 +/- 1.06     0.0 +/- 0.0        None
#  LogisticRegression     9.736 +/- 2.32   100.0 +/- 0.0        None
#  Adaboost              17.580 +/- 1.30     0.0 +/- 0.0        None  )

# %%
# Save the returned dictionary
joblib.dump(results, 'cv_dict_default_models.pkl')

# Save the returned DataFrame
joblib.dump(results_df, 'cv_df_default_models.pkl')
# Out:
# ['cv_results_df_default.pkl']

# %% [markdown]
# **Best Default Models:** XGBoost, Bagging, NeuralNetworks, RandomForest (GBM optional)
