# %% [markdown]
# # **<h3 align="center">Machine Learning 2024-25</h3>**
# ## **<h3 align="center">To Grant or Not to Grant: Deciding on Compensation Benefits</h3>**
#
#
# **Group 38 members:**<br>
# Ana Marta Azinheira  - 20240496@novaims.unl.pt<br>
# Braulio Damba - 20240007@novaims.unl.pt<br>
# Henry Tirla  - 20221016@novaims.unl.pt<br>
# Marco Galão  - r20201545@novaims.unl.pt<br>
# Rodrigo Sardinha - 20211627@novaims.unl.pt<br>

# %% [markdown]
# <a id = "toc"></a>
#
# # Table of Contents
#
# * [1. Import the Libraries](#import_libraries)
# * [2. Import the Dataset](#import_dataset)
# * [3. Description of the Dataset’s Structure](#dataset_structure)
# * [4. Exploring the Dataset](#exploration)
#     * [4.1. Constant Features](#constant_features)
#     * [4.2. Duplicates](#duplicates)
#     * [4.3. Missing Values](#missing_values)
#     * [4.4. Data Types](#data_types)
#     * [4.5. Coherence Checking](#coherence_checking)
#         * [4.5.1. X](#x)
#     * [4.6. Visualizations](#visualizations)
#     * [4.7. Correlation Matrix](#correlation_matrix)
#     * [4.8. Outliers](#outliers)
# * [5. Feature Engineering](#feature_engineering)
#     * [5.1. X](#x)

# %% [markdown]
# # 1. Import the Libraries <a class="anchor" id="import_the_libraries"></a>

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl
import bokeh as bk
import sqlite3
import os
from math import ceil

import warnings
warnings.filterwarnings("ignore")

# %config InlineBackend.figure_format = 'retina'

sns.set()

#Date
from datetime import datetime
from dateutil import relativedelta

# %% [markdown]
# # 2. Import the DataSet <a class="anchor" id="import_the_dataset"></a>

# %%
df_train = pd.read_csv('train_data.csv', sep=',')

# %%
#importing the test dataset
df_test = pd.read_csv('test_data.csv', sep=',')

# %%
df_train[["Agreement Reached", "WCB Decision", "Claim Injury Type"]].head()
# Out:
#    Agreement Reached      WCB Decision Claim Injury Type
# 0                0.0  Not Work Related       2. NON-COMP
# 1                1.0  Not Work Related      4. TEMPORARY
# 2                0.0  Not Work Related      4. TEMPORARY
# 3                NaN               NaN               NaN
# 4                0.0  Not Work Related       2. NON-COMP

# %%
# Check if specific columns are in df_test and store results in a dictionary
column_check = {col: col in df_test.columns for col in ["Agreement Reached", "WCB Decision", "Claim Injury Type"]}

print(column_check)
# Out:
# {'Agreement Reached': False, 'WCB Decision': False, 'Claim Injury Type': False}

# %% [markdown]
# # 3. Description of the Dataset’s Structure <a class="anchor" id="dataset_structure"></a>

# %% [markdown]
# - *Accident Date* - Injury date of the claim.
#
# - *Age at Injury* - Age of injured worker when the injury occurred.
#
# - *Alternative Dispute Resolution* - Adjudication processes external to the Board.
#
# - *Assembly Date* - The date the claim was first assembled.
#
# - *Attorney/Representative* - Is the claim being represented by an Attorney?
#
# - *Average Weekly Wage* - The wage used to calculate workers’ compensation, disability, or an Paid Leave wage replacement benefits.
#
# - *Birth Year* - The reported year of birth of the injured worker.
#
# - *C-2 Date* - Date of receipt of the Employer's Report of Work-Related Injury/Illness or equivalent (formerly Form C-2).
#
# - *C-3 Date* - Date Form C-3 (Employee Claim Form) was received.
#
# - *Carrier Name* - Name of primary insurance provider responsible for providing workers’ compensation coverage to the injured worker’s employer.
#
# - *Carrier Type* - Type of primary insurance provider responsible for providing workers’ compensation coverage.
#
# - *Claim Identifier* - Unique identifier for each claim, assigned by WCB.
#
# - *County of Injury* - Name of the New York County where the injury occurred.
#
# - *COVID-19 Indicator* - Indication that the claim may be associated with COVID-19.
#
# - *District Name* - Name of the WCB district office that oversees claims for that region or area of the state.
#
# - *First Hearing Date* - Date the first hearing was held on a claim at a WCB hearing location. A blank date means the claim has not yet had a hearing held.
#
# - *Gender* - The reported gender of the injured worker.
#
# - *IME-4 Count* - Number of IME-4 forms received per claim. The IME-4 form is the “Independent Examiner's Report of Independent Medical Examination” form.
#
# - *Industry Code* - NAICS code and descriptions are available at: https://www.naics.com/search-naics-codes-by-industry/.
#
# - *Industry Code Description* - 2-digit NAICS industry code description used to classify businesses according to their economic activity.
#
# - *Medical Fee Region* - Approximate region where the injured worker would receive medical service.
#
# - *OIICS Nature of Injury Description* - The OIICS nature of injury codes & descriptions are available at https://www.bls.gov/iif/oiics_manual_2007.pdf.
#
# - *WCIO Cause of Injury Code* - The WCIO cause of injury codes & descriptions are at https://www.wcio.org/Active%20PNC/WCIO_Cause_Table.pdf
#
# - *WCIO Cause of Injury Description* - See description of field above.
#
# - *WCIO Nature of Injury Code* - The WCIO nature of injury are available at https://www.wcio.org/Active%20PNC/WCIO_Nature_Table.pdf
#
# - *WCIO Nature of Injury Description* - See description of field above.
#
# - *WCIO Part Of Body Code* - The WCIO part of body codes & descriptions are available at https://www.wcio.org/Active%20PNC/WCIO_Part_Table.pdf
#
# - *WCIO Part Of Body Description* - See description of field above.
#
# - *Zip Code* - The reported ZIP code of the injured worker’s home address.
#
# - *Agreement Reached* - Binary variable: Yes if there is an agreement without the involvement of the WCB -> unknown at the start of a claim.
#
# - *WCB Decision* - Multiclass variable: Decision of the WCB relative to the claim: “Accident” means that claim refers to workplace accident, “Occupational Disease” means illness from the workplace. -> requires WCB deliberation so it is unknown at start of claim.
#
# - *Claim Injury Type* - Main target variable: Deliberation of the WCB relative to benefits awarded to the claim. Numbering indicates severity.

# %% [markdown]
# # 4. Exploring the DataSet <a class="anchor" id="exploration"></a>

# %%
df_train.shape
# Out:
# (593471, 33)

# %%
df_train.head().T
# Out:
#                                                                0  \
# Accident Date                                         2019-12-30
# Age at Injury                                               31.0
# Alternative Dispute Resolution                                 N
# Assembly Date                                         2020-01-01
# Attorney/Representative                                        N
# Average Weekly Wage                                          0.0
# Birth Year                                                1988.0
# C-2 Date                                              2019-12-31
# C-3 Date                                                     NaN
# Carrier Name                          NEW HAMPSHIRE INSURANCE CO
# Carrier Type                                         1A. PRIVATE
# Claim Identifier                                         5393875
# Claim Injury Type                                    2. NON-COMP
# County of Injury                                    ST. LAWRENCE
# COVID-19 Indicator                                             N
# District Name                                           SYRACUSE
# First Hearing Date                                           NaN
# Gender                                                         M
# IME-4 Count                                                  NaN
# Industry Code                                               44.0
# Industry Code Description                           RETAIL TRADE
# Medical Fee Region                                             I
# OIICS Nature of Injury Description                           NaN
# WCIO Cause of Injury Code                                   27.0
# WCIO Cause of Injury Description    FROM LIQUID OR GREASE SPILLS
# WCIO Nature of Injury Code                                  10.0
# WCIO Nature of Injury Description                      CONTUSION
# WCIO Part Of Body Code                                      62.0
# WCIO Part Of Body Description                           BUTTOCKS
# Zip Code                                                   13662
# Agreement Reached                                            0.0
# WCB Decision                                    Not Work Related
# Number of Dependents                                         1.0
#
#                                                                1  \
# Accident Date                                         2019-08-30
# Age at Injury                                               46.0
# Alternative Dispute Resolution                                 N
# Assembly Date                                         2020-01-01
# Attorney/Representative                                        Y
# Average Weekly Wage                                      1745.93
# Birth Year                                                1973.0
# C-2 Date                                              2020-01-01
# C-3 Date                                              2020-01-14
# Carrier Name                        ZURICH AMERICAN INSURANCE CO
# Carrier Type                                         1A. PRIVATE
# Claim Identifier                                         5393091
# Claim Injury Type                                   4. TEMPORARY
# County of Injury                                         WYOMING
# COVID-19 Indicator                                             N
# District Name                                          ROCHESTER
# First Hearing Date                                    2020-02-21
# Gender                                                         F
# IME-4 Count                                                  4.0
# Industry Code                                               23.0
# Industry Code Description                           CONSTRUCTION
# Medical Fee Region                                             I
# OIICS Nature of Injury Description                           NaN
# WCIO Cause of Injury Code                                   97.0
# WCIO Cause of Injury Description               REPETITIVE MOTION
# WCIO Nature of Injury Code                                  49.0
# WCIO Nature of Injury Description                 SPRAIN OR TEAR
# WCIO Part Of Body Code                                      38.0
# WCIO Part Of Body Description                        SHOULDER(S)
# Zip Code                                                   14569
# Agreement Reached                                            1.0
# WCB Decision                                    Not Work Related
# Number of Dependents                                         4.0
#
#                                                                                     2  \
# Accident Date                                                              2019-12-06
# Age at Injury                                                                    40.0
# Alternative Dispute Resolution                                                      N
# Assembly Date                                                              2020-01-01
# Attorney/Representative                                                             N
# Average Weekly Wage                                                            1434.8
# Birth Year                                                                     1979.0
# C-2 Date                                                                   2020-01-01
# C-3 Date                                                                          NaN
# Carrier Name                                                INDEMNITY INSURANCE CO OF
# Carrier Type                                                              1A. PRIVATE
# Claim Identifier                                                              5393889
# Claim Injury Type                                                        4. TEMPORARY
# County of Injury                                                               ORANGE
# COVID-19 Indicator                                                                  N
# District Name                                                                  ALBANY
# First Hearing Date                                                                NaN
# Gender                                                                              M
# IME-4 Count                                                                       NaN
# Industry Code                                                                    56.0
# Industry Code Description           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...
# Medical Fee Region                                                                 II
# OIICS Nature of Injury Description                                                NaN
# WCIO Cause of Injury Code                                                        79.0
# WCIO Cause of Injury Description                       OBJECT BEING LIFTED OR HANDLED
# WCIO Nature of Injury Code                                                        7.0
# WCIO Nature of Injury Description                                          CONCUSSION
# WCIO Part Of Body Code                                                           10.0
# WCIO Part Of Body Description                                    MULTIPLE HEAD INJURY
# Zip Code                                                                        12589
# Agreement Reached                                                                 0.0
# WCB Decision                                                         Not Work Related
# Number of Dependents                                                              6.0
#
#                                              3  \
# Accident Date                              NaN
# Age at Injury                              NaN
# Alternative Dispute Resolution             NaN
# Assembly Date                       2020-01-01
# Attorney/Representative                    NaN
# Average Weekly Wage                        NaN
# Birth Year                                 NaN
# C-2 Date                                   NaN
# C-3 Date                                   NaN
# Carrier Name                               NaN
# Carrier Type                               NaN
# Claim Identifier                     957648180
# Claim Injury Type                          NaN
# County of Injury                           NaN
# COVID-19 Indicator                         NaN
# District Name                              NaN
# First Hearing Date                         NaN
# Gender                                     NaN
# IME-4 Count                                NaN
# Industry Code                              NaN
# Industry Code Description                  NaN
# Medical Fee Region                         NaN
# OIICS Nature of Injury Description         NaN
# WCIO Cause of Injury Code                  NaN
# WCIO Cause of Injury Description           NaN
# WCIO Nature of Injury Code                 NaN
# WCIO Nature of Injury Description          NaN
# WCIO Part Of Body Code                     NaN
# WCIO Part Of Body Description              NaN
# Zip Code                                   NaN
# Agreement Reached                          NaN
# WCB Decision                               NaN
# Number of Dependents                       NaN
#
#                                                                     4
# Accident Date                                              2019-12-30
# Age at Injury                                                    61.0
# Alternative Dispute Resolution                                      N
# Assembly Date                                              2020-01-01
# Attorney/Representative                                             N
# Average Weekly Wage                                               NaN
# Birth Year                                                     1958.0
# C-2 Date                                                   2019-12-31
# C-3 Date                                                          NaN
# Carrier Name                                     STATE INSURANCE FUND
# Carrier Type                                                  2A. SIF
# Claim Identifier                                              5393887
# Claim Injury Type                                         2. NON-COMP
# County of Injury                                             DUTCHESS
# COVID-19 Indicator                                                  N
# District Name                                                  ALBANY
# First Hearing Date                                                NaN
# Gender                                                              M
# IME-4 Count                                                       NaN
# Industry Code                                                    62.0
# Industry Code Description           HEALTH CARE AND SOCIAL ASSISTANCE
# Medical Fee Region                                                 II
# OIICS Nature of Injury Description                                NaN
# WCIO Cause of Injury Code                                        16.0
# WCIO Cause of Injury Description      HAND TOOL, UTENSIL; NOT POWERED
# WCIO Nature of Injury Code                                       43.0
# WCIO Nature of Injury Description                            PUNCTURE
# WCIO Part Of Body Code                                           36.0
# WCIO Part Of Body Description                               FINGER(S)
# Zip Code                                                        12603
# Agreement Reached                                                 0.0
# WCB Decision                                         Not Work Related
# Number of Dependents                                              1.0

# %%
df_train.tail().T
# Out:
#                                         593466  \
# Accident Date                              NaN
# Age at Injury                              NaN
# Alternative Dispute Resolution             NaN
# Assembly Date                       2022-12-31
# Attorney/Representative                    NaN
# Average Weekly Wage                        NaN
# Birth Year                                 NaN
# C-2 Date                                   NaN
# C-3 Date                                   NaN
# Carrier Name                               NaN
# Carrier Type                               NaN
# Claim Identifier                     327160035
# Claim Injury Type                          NaN
# County of Injury                           NaN
# COVID-19 Indicator                         NaN
# District Name                              NaN
# First Hearing Date                         NaN
# Gender                                     NaN
# IME-4 Count                                NaN
# Industry Code                              NaN
# Industry Code Description                  NaN
# Medical Fee Region                         NaN
# OIICS Nature of Injury Description         NaN
# WCIO Cause of Injury Code                  NaN
# WCIO Cause of Injury Description           NaN
# WCIO Nature of Injury Code                 NaN
# WCIO Nature of Injury Description          NaN
# WCIO Part Of Body Code                     NaN
# WCIO Part Of Body Description              NaN
# Zip Code                                   NaN
# Agreement Reached                          NaN
# WCB Decision                               NaN
# Number of Dependents                       NaN
#
#                                                               593467  \
# Accident Date                                             2022-12-13
# Age at Injury                                                   72.0
# Alternative Dispute Resolution                                     N
# Assembly Date                                             2022-12-31
# Attorney/Representative                                            N
# Average Weekly Wage                                              0.0
# Birth Year                                                    1950.0
# C-2 Date                                                  2022-12-31
# C-3 Date                                                         NaN
# Carrier Name                           TECHNOLOGY INSURANCE CO. INC.
# Carrier Type                                             1A. PRIVATE
# Claim Identifier                                             6165075
# Claim Injury Type                                        2. NON-COMP
# County of Injury                                            SULLIVAN
# COVID-19 Indicator                                                 N
# District Name                                             BINGHAMTON
# First Hearing Date                                               NaN
# Gender                                                             F
# IME-4 Count                                                      NaN
# Industry Code                                                   48.0
# Industry Code Description             TRANSPORTATION AND WAREHOUSING
# Medical Fee Region                                                 I
# OIICS Nature of Injury Description                               NaN
# WCIO Cause of Injury Code                                       25.0
# WCIO Cause of Injury Description    FROM DIFFERENT LEVEL (ELEVATION)
# WCIO Nature of Injury Code                                      90.0
# WCIO Nature of Injury Description    MULTIPLE PHYSICAL INJURIES ONLY
# WCIO Part Of Body Code                                          -9.0
# WCIO Part Of Body Description                               MULTIPLE
# Zip Code                                                       12779
# Agreement Reached                                                0.0
# WCB Decision                                        Not Work Related
# Number of Dependents                                             3.0
#
#                                         593468      593469      593470
# Accident Date                              NaN         NaN         NaN
# Age at Injury                              NaN         NaN         NaN
# Alternative Dispute Resolution             NaN         NaN         NaN
# Assembly Date                       2022-12-31  2022-12-31  2022-12-31
# Attorney/Representative                    NaN         NaN         NaN
# Average Weekly Wage                        NaN         NaN         NaN
# Birth Year                                 NaN         NaN         NaN
# C-2 Date                                   NaN         NaN         NaN
# C-3 Date                                   NaN         NaN         NaN
# Carrier Name                               NaN         NaN         NaN
# Carrier Type                               NaN         NaN         NaN
# Claim Identifier                     249875936   120584215   818961390
# Claim Injury Type                          NaN         NaN         NaN
# County of Injury                           NaN         NaN         NaN
# COVID-19 Indicator                         NaN         NaN         NaN
# District Name                              NaN         NaN         NaN
# First Hearing Date                         NaN         NaN         NaN
# Gender                                     NaN         NaN         NaN
# IME-4 Count                                NaN         NaN         NaN
# Industry Code                              NaN         NaN         NaN
# Industry Code Description                  NaN         NaN         NaN
# Medical Fee Region                         NaN         NaN         NaN
# OIICS Nature of Injury Description         NaN         NaN         NaN
# WCIO Cause of Injury Code                  NaN         NaN         NaN
# WCIO Cause of Injury Description           NaN         NaN         NaN
# WCIO Nature of Injury Code                 NaN         NaN         NaN
# WCIO Nature of Injury Description          NaN         NaN         NaN
# WCIO Part Of Body Code                     NaN         NaN         NaN
# WCIO Part Of Body Description              NaN         NaN         NaN
# Zip Code                                   NaN         NaN         NaN
# Agreement Reached                          NaN         NaN         NaN
# WCB Decision                               NaN         NaN         NaN
# Number of Dependents                       NaN         NaN         NaN

# %%
#checking the data types of the variables of the training dataset and if there are any missing values
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593471 entries, 0 to 593470
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
#  11  Claim Identifier                    593471 non-null  int64
#  12  Claim Injury Type                   574026 non-null  object
#  13  County of Injury                    574026 non-null  object
#  14  COVID-19 Indicator                  574026 non-null  object
#  15  District Name                       574026 non-null  object
#  16  First Hearing Date                  150798 non-null  object
#  17  Gender                              574026 non-null  object
#  18  IME-4 Count                         132803 non-null  float64
#  19  Industry Code                       564068 non-null  float64
#  20  Industry Code Description           564068 non-null  object
#  21  Medical Fee Region                  574026 non-null  object
#  22  OIICS Nature of Injury Description  0 non-null       float64
#  23  WCIO Cause of Injury Code           558386 non-null  float64
#  24  WCIO Cause of Injury Description    558386 non-null  object
#  25  WCIO Nature of Injury Code          558369 non-null  float64
#  26  WCIO Nature of Injury Description   558369 non-null  object
#  27  WCIO Part Of Body Code              556944 non-null  float64
#  28  WCIO Part Of Body Description       556944 non-null  object
#  29  Zip Code                            545389 non-null  object
#  30  Agreement Reached                   574026 non-null  float64
#  31  WCB Decision                        574026 non-null  object
#  32  Number of Dependents                574026 non-null  float64
# dtypes: float64(11), int64(1), object(21)
# memory usage: 149.4+ MB

# %% [markdown]
# - From this information, we can see that the variables 'Assembly Date' and 'Claim Identifier' have no missing values.

# %%
#getting the main descriptive statistics only for the numerical variables

df_train.describe().round(2).T
# Out:
#                                        count         mean           std  \
# Age at Injury                       574026.0        42.11  1.426000e+01
# Average Weekly Wage                 545375.0       491.09  6.092920e+03
# Birth Year                          544948.0      1886.77  4.146400e+02
# Claim Identifier                    593471.0  23667598.79  1.079271e+08
# IME-4 Count                         132803.0         3.21  2.830000e+00
# Industry Code                       564068.0        58.65  1.964000e+01
# OIICS Nature of Injury Description       0.0          NaN           NaN
# WCIO Cause of Injury Code           558386.0        54.38  2.587000e+01
# WCIO Nature of Injury Code          558369.0        41.01  2.221000e+01
# WCIO Part Of Body Code              556944.0        39.74  2.237000e+01
# Agreement Reached                   574026.0         0.05  2.100000e-01
# Number of Dependents                574026.0         3.01  2.000000e+00
#
#                                           min        25%        50%  \
# Age at Injury                             0.0       31.0       42.0
# Average Weekly Wage                       0.0        0.0        0.0
# Birth Year                                0.0     1965.0     1977.0
# Claim Identifier                    5393066.0  5593414.5  5791212.0
# IME-4 Count                               1.0        1.0        2.0
# Industry Code                            11.0       45.0       61.0
# OIICS Nature of Injury Description        NaN        NaN        NaN
# WCIO Cause of Injury Code                 1.0       31.0       56.0
# WCIO Nature of Injury Code                1.0       16.0       49.0
# WCIO Part Of Body Code                   -9.0       33.0       38.0
# Agreement Reached                         0.0        0.0        0.0
# Number of Dependents                      0.0        1.0        3.0
#
#                                           75%          max
# Age at Injury                            54.0        117.0
# Average Weekly Wage                     841.0    2828079.0
# Birth Year                             1989.0       2018.0
# Claim Identifier                    5991000.5  999891667.0
# IME-4 Count                               4.0         73.0
# Industry Code                            71.0         92.0
# OIICS Nature of Injury Description        NaN          NaN
# WCIO Cause of Injury Code                75.0         99.0
# WCIO Nature of Injury Code               52.0         91.0
# WCIO Part Of Body Code                   53.0         99.0
# Agreement Reached                         0.0          1.0
# Number of Dependents                      5.0          6.0

# %% [markdown]
# <br>
#
# - 'Claim Identifier': set it as the df index (and check for duplicates)
#
# - convert to integer:
#     - 'Age at Injury': also explore min and max & check consistency with 'Birth Year'
#     - 'Birth Year': also explore zeros & treat outliers (born in 2018)
#     - 'IME-4 Count': also treat outlier
#     - 'Industry Code': also check consistency with the link
#     - 'Number of Dependents': not in metadata (make assumption) & seems uniformly distributed (strange - similar number of workers with 4, 5 or 6 dependents and workers with 0 or 1 dependents)
#
# - special missing values:
#     - 'OIICS Nature of Injury Description': full of missing values (drop this column)
#
# - 'Average Weekly Wage': explore wage of 0 & treat outliers
# - 'WCIO Cause of Injury Code': explore codes meaning (link doesn't work) & check consistency with 'WCIO Cause of Injury Description'
# - 'WCIO Part Of Body Code': explore codes meaning (link doesn't work) & treat outliers (can accept negative codes?) & check consistency with 'WCIO Part Of Body Description'
# - 'Agreement Reached': seems okay (missing value at the start of the claim)

# %%
# getting the main descriptive statistics for the remaining cathegorical variables

df_train.describe(include = ['object']).T
# Out:
#                                     count unique  \
# Accident Date                      570337   5539
# Alternative Dispute Resolution     574026      3
# Assembly Date                      593471   1096
# Attorney/Representative            574026      2
# C-2 Date                           559466   2475
# C-3 Date                           187245   1648
# Carrier Name                       574026   2046
# Carrier Type                       574026      8
# Claim Injury Type                  574026      8
# County of Injury                   574026     63
# COVID-19 Indicator                 574026      2
# District Name                      574026      8
# First Hearing Date                 150798   1094
# Gender                             574026      4
# Industry Code Description          564068     20
# Medical Fee Region                 574026      5
# WCIO Cause of Injury Description   558386     74
# WCIO Nature of Injury Description  558369     56
# WCIO Part Of Body Description      556944     54
# Zip Code                           545389  10060
# WCB Decision                       574026      1
#
#                                                                  top    freq
# Accident Date                                             2020-03-01    1245
# Alternative Dispute Resolution                                     N  571412
# Assembly Date                                             2020-03-06    1422
# Attorney/Representative                                            N  392291
# C-2 Date                                                  2021-05-11    1847
# C-3 Date                                                  2021-04-21     350
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285368
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546505
# District Name                                                    NYC  270779
# First Hearing Date                                        2022-04-15     440
# Gender                                                             M  335218
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3302
# WCB Decision                                        Not Work Related  574026

# %% [markdown]
# <br>
#
# - convert to datetime (check if dates are from the start of 2020 till the end of 2022):
#     - 'Accident Date'
#     - 'Assembly Date'
#     - 'C-2 Date'
#     - 'C-3 Date'
#     - 'First Hearing Date' (missing values: a blank date means the claim has not yet had a hearing held)
#
# - convert to binary:
#     - 'Alternative Dispute Resolution': maybe the 'U's represent missing values (we can make this assumption)
#     - 'Attorney/Representative'
#     - 'COVID-19 Indicator'
#
# - special missing values:
#     - 'Carrier Type': replace 'UNKNOWN' (maybe also '5D. SPECIAL FUND - UNKNOWN') & explore online (for example, do the code represents a category)
#     - 'Gender': explore values 'U' and 'X' (maybe 'U' means Unknown or Unspecified, and 'X' refers to Non-Binary, Gender X, or Other gender identities) - make assumptions
#     - 'Medical Fee Region': explore values & 'UK' maybe stands for Unknown or Unclassified
#
#
# - 'Claim Injury Type': seems okay (just need to understand the different values)
# - 'Carrier Name': explore (for example, check if the same insurance provider is written differently)
# - 'County of Injury': seems okay (just need to explore the different values)
# - 'District Name': seems okay (just need to explore if the values correspond to NY districts)
# - 'Industry Code Description': seems okay (just need to check consistency with the link of 'Industry Code')
# - 'WCIO Cause of Injury Description': seems okay (just need to explore values & check consistency with 'WCIO Cause of Injury Code')
# - 'WCIO Part Of Body Description': seems okay (just need to explore values & check consistency with 'WCIO Part Of Body Code')
# - 'Zip Code': seems okay (just need to explore values)
# - 'WCB Decision': just 'Not Work Related', which is not stated in the metadata (missing value at the start of the claim, because requires WCB deliberation)

# %% [markdown]
# # 4.0. Set Index <a id="set_index"></a>

# %% [markdown]
# Let's check if 'Claim Identifier' is appropriate for index

# %%
# Ensure all values in 'Claim Identifier' are converted to strings for length calculation
claim_lengths = df_train["Claim Identifier"].astype(str).apply(len)

# Count occurrences of each unique length
length_counts = claim_lengths.value_counts(normalize=True) * 100

# Display the results
print("Number of values by length in 'Claim Identifier':")
print(length_counts.round(2))
# Out:
# Number of values by length in 'Claim Identifier':
# Claim Identifier
# 7    96.72
# 9     3.28
# Name: proportion, dtype: float64

# %%
# Filter rows by length of 'Claim Identifier' (7 or 9 characters)
claim_id_7_length = df_train[df_train['Claim Identifier'].astype(str).apply(len) == 7]
claim_id_9_length = df_train[df_train['Claim Identifier'].astype(str).apply(len) == 9]

# %%
claim_id_7_length.describe().T
# Out:
#                                        count          mean            std  \
# Age at Injury                       574026.0  4.211427e+01      14.256432
# Average Weekly Wage                 545375.0  4.910883e+02    6092.918120
# Birth Year                          544948.0  1.886768e+03     414.644423
# Claim Identifier                    574026.0  5.778956e+06  222308.226013
# IME-4 Count                         132803.0  3.207337e+00       2.832303
# Industry Code                       564068.0  5.864531e+01      19.644175
# OIICS Nature of Injury Description       0.0           NaN            NaN
# WCIO Cause of Injury Code           558386.0  5.438114e+01      25.874281
# WCIO Nature of Injury Code          558369.0  4.101384e+01      22.207521
# WCIO Part Of Body Code              556944.0  3.973815e+01      22.365940
# Agreement Reached                   574026.0  4.666513e-02       0.210921
# Number of Dependents                574026.0  3.006559e+00       2.000801
#
#                                           min         25%        50%  \
# Age at Injury                             0.0       31.00       42.0
# Average Weekly Wage                       0.0        0.00        0.0
# Birth Year                                0.0     1965.00     1977.0
# Claim Identifier                    5393066.0  5586764.25  5778282.5
# IME-4 Count                               1.0        1.00        2.0
# Industry Code                            11.0       45.00       61.0
# OIICS Nature of Injury Description        NaN         NaN        NaN
# WCIO Cause of Injury Code                 1.0       31.00       56.0
# WCIO Nature of Injury Code                1.0       16.00       49.0
# WCIO Part Of Body Code                   -9.0       33.00       38.0
# Agreement Reached                         0.0        0.00        0.0
# Number of Dependents                      0.0        1.00        3.0
#
#                                            75%        max
# Age at Injury                            54.00      117.0
# Average Weekly Wage                     841.00  2828079.0
# Birth Year                             1989.00     2018.0
# Claim Identifier                    5971328.75  6165685.0
# IME-4 Count                               4.00       73.0
# Industry Code                            71.00       92.0
# OIICS Nature of Injury Description         NaN        NaN
# WCIO Cause of Injury Code                75.00       99.0
# WCIO Nature of Injury Code               52.00       91.0
# WCIO Part Of Body Code                   53.00       99.0
# Agreement Reached                         0.00        1.0
# Number of Dependents                      5.00        6.0

# %%
claim_id_7_length.describe(include='object').T
# Out:
#                                     count unique  \
# Accident Date                      570337   5539
# Alternative Dispute Resolution     574026      3
# Assembly Date                      574026    897
# Attorney/Representative            574026      2
# C-2 Date                           559466   2475
# C-3 Date                           187245   1648
# Carrier Name                       574026   2046
# Carrier Type                       574026      8
# Claim Injury Type                  574026      8
# County of Injury                   574026     63
# COVID-19 Indicator                 574026      2
# District Name                      574026      8
# First Hearing Date                 150798   1094
# Gender                             574026      4
# Industry Code Description          564068     20
# Medical Fee Region                 574026      5
# WCIO Cause of Injury Description   558386     74
# WCIO Nature of Injury Description  558369     56
# WCIO Part Of Body Description      556944     54
# Zip Code                           545389  10060
# WCB Decision                       574026      1
#
#                                                                  top    freq
# Accident Date                                             2020-03-01    1245
# Alternative Dispute Resolution                                     N  571412
# Assembly Date                                             2020-03-06    1413
# Attorney/Representative                                            N  392291
# C-2 Date                                                  2021-05-11    1847
# C-3 Date                                                  2021-04-21     350
# Carrier Name                                    STATE INSURANCE FUND  111144
# Carrier Type                                             1A. PRIVATE  285368
# Claim Injury Type                                        2. NON-COMP  291078
# County of Injury                                             SUFFOLK   60430
# COVID-19 Indicator                                                 N  546505
# District Name                                                    NYC  270779
# First Hearing Date                                        2022-04-15     440
# Gender                                                             M  335218
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  114339
# Medical Fee Region                                                IV  265981
# WCIO Cause of Injury Description                             LIFTING   46610
# WCIO Nature of Injury Description                     STRAIN OR TEAR  153373
# WCIO Part Of Body Description                        LOWER BACK AREA   51862
# Zip Code                                                       11236    3302
# WCB Decision                                        Not Work Related  574026

# %%
claim_id_9_length.describe(include='all').T
# Out:
#                                       count unique         top freq  \
# Accident Date                             0      0         NaN  NaN
# Age at Injury                           0.0    NaN         NaN  NaN
# Alternative Dispute Resolution            0      0         NaN  NaN
# Assembly Date                         19445   1096  2022-09-02   30
# Attorney/Representative                   0      0         NaN  NaN
# Average Weekly Wage                     0.0    NaN         NaN  NaN
# Birth Year                              0.0    NaN         NaN  NaN
# C-2 Date                                  0      0         NaN  NaN
# C-3 Date                                  0      0         NaN  NaN
# Carrier Name                              0      0         NaN  NaN
# Carrier Type                              0      0         NaN  NaN
# Claim Identifier                    19445.0    NaN         NaN  NaN
# Claim Injury Type                         0      0         NaN  NaN
# County of Injury                          0      0         NaN  NaN
# COVID-19 Indicator                        0      0         NaN  NaN
# District Name                             0      0         NaN  NaN
# First Hearing Date                        0      0         NaN  NaN
# Gender                                    0      0         NaN  NaN
# IME-4 Count                             0.0    NaN         NaN  NaN
# Industry Code                           0.0    NaN         NaN  NaN
# Industry Code Description                 0      0         NaN  NaN
# Medical Fee Region                        0      0         NaN  NaN
# OIICS Nature of Injury Description      0.0    NaN         NaN  NaN
# WCIO Cause of Injury Code               0.0    NaN         NaN  NaN
# WCIO Cause of Injury Description          0      0         NaN  NaN
# WCIO Nature of Injury Code              0.0    NaN         NaN  NaN
# WCIO Nature of Injury Description         0      0         NaN  NaN
# WCIO Part Of Body Code                  0.0    NaN         NaN  NaN
# WCIO Part Of Body Description             0      0         NaN  NaN
# Zip Code                                  0      0         NaN  NaN
# Agreement Reached                       0.0    NaN         NaN  NaN
# WCB Decision                              0      0         NaN  NaN
# Number of Dependents                    0.0    NaN         NaN  NaN
#
#                                                 mean               std  \
# Accident Date                                    NaN               NaN
# Age at Injury                                    NaN               NaN
# Alternative Dispute Resolution                   NaN               NaN
# Assembly Date                                    NaN               NaN
# Attorney/Representative                          NaN               NaN
# Average Weekly Wage                              NaN               NaN
# Birth Year                                       NaN               NaN
# C-2 Date                                         NaN               NaN
# C-3 Date                                         NaN               NaN
# Carrier Name                                     NaN               NaN
# Carrier Type                                     NaN               NaN
# Claim Identifier                    551749177.147802  259220840.065138
# Claim Injury Type                                NaN               NaN
# County of Injury                                 NaN               NaN
# COVID-19 Indicator                               NaN               NaN
# District Name                                    NaN               NaN
# First Hearing Date                               NaN               NaN
# Gender                                           NaN               NaN
# IME-4 Count                                      NaN               NaN
# Industry Code                                    NaN               NaN
# Industry Code Description                        NaN               NaN
# Medical Fee Region                               NaN               NaN
# OIICS Nature of Injury Description               NaN               NaN
# WCIO Cause of Injury Code                        NaN               NaN
# WCIO Cause of Injury Description                 NaN               NaN
# WCIO Nature of Injury Code                       NaN               NaN
# WCIO Nature of Injury Description                NaN               NaN
# WCIO Part Of Body Code                           NaN               NaN
# WCIO Part Of Body Description                    NaN               NaN
# Zip Code                                         NaN               NaN
# Agreement Reached                                NaN               NaN
# WCB Decision                                     NaN               NaN
# Number of Dependents                             NaN               NaN
#
#                                             min          25%          50%  \
# Accident Date                               NaN          NaN          NaN
# Age at Injury                               NaN          NaN          NaN
# Alternative Dispute Resolution              NaN          NaN          NaN
# Assembly Date                               NaN          NaN          NaN
# Attorney/Representative                     NaN          NaN          NaN
# Average Weekly Wage                         NaN          NaN          NaN
# Birth Year                                  NaN          NaN          NaN
# C-2 Date                                    NaN          NaN          NaN
# C-3 Date                                    NaN          NaN          NaN
# Carrier Name                                NaN          NaN          NaN
# Carrier Type                                NaN          NaN          NaN
# Claim Identifier                    100031438.0  328429921.0  554012330.0
# Claim Injury Type                           NaN          NaN          NaN
# County of Injury                            NaN          NaN          NaN
# COVID-19 Indicator                          NaN          NaN          NaN
# District Name                               NaN          NaN          NaN
# First Hearing Date                          NaN          NaN          NaN
# Gender                                      NaN          NaN          NaN
# IME-4 Count                                 NaN          NaN          NaN
# Industry Code                               NaN          NaN          NaN
# Industry Code Description                   NaN          NaN          NaN
# Medical Fee Region                          NaN          NaN          NaN
# OIICS Nature of Injury Description          NaN          NaN          NaN
# WCIO Cause of Injury Code                   NaN          NaN          NaN
# WCIO Cause of Injury Description            NaN          NaN          NaN
# WCIO Nature of Injury Code                  NaN          NaN          NaN
# WCIO Nature of Injury Description           NaN          NaN          NaN
# WCIO Part Of Body Code                      NaN          NaN          NaN
# WCIO Part Of Body Description               NaN          NaN          NaN
# Zip Code                                    NaN          NaN          NaN
# Agreement Reached                           NaN          NaN          NaN
# WCB Decision                                NaN          NaN          NaN
# Number of Dependents                        NaN          NaN          NaN
#
#                                             75%          max
# Accident Date                               NaN          NaN
# Age at Injury                               NaN          NaN
# Alternative Dispute Resolution              NaN          NaN
# Assembly Date                               NaN          NaN
# Attorney/Representative                     NaN          NaN
# Average Weekly Wage                         NaN          NaN
# Birth Year                                  NaN          NaN
# C-2 Date                                    NaN          NaN
# C-3 Date                                    NaN          NaN
# Carrier Name                                NaN          NaN
# Carrier Type                                NaN          NaN
# Claim Identifier                    777096910.0  999891667.0
# Claim Injury Type                           NaN          NaN
# County of Injury                            NaN          NaN
# COVID-19 Indicator                          NaN          NaN
# District Name                               NaN          NaN
# First Hearing Date                          NaN          NaN
# Gender                                      NaN          NaN
# IME-4 Count                                 NaN          NaN
# Industry Code                               NaN          NaN
# Industry Code Description                   NaN          NaN
# Medical Fee Region                          NaN          NaN
# OIICS Nature of Injury Description          NaN          NaN
# WCIO Cause of Injury Code                   NaN          NaN
# WCIO Cause of Injury Description            NaN          NaN
# WCIO Nature of Injury Code                  NaN          NaN
# WCIO Nature of Injury Description           NaN          NaN
# WCIO Part Of Body Code                      NaN          NaN
# WCIO Part Of Body Description               NaN          NaN
# Zip Code                                    NaN          NaN
# Agreement Reached                           NaN          NaN
# WCB Decision                                NaN          NaN
# Number of Dependents                        NaN          NaN

# %% [markdown]
# **Decision:** The records with a 9-length Claim Identifier account for just 3.28% of the data and have missing values across all columns, except for “Assembly Date”. Since they provide very little information, we’ve decided to drop them to maintain data quality (with all records now having a 7-length Claim Identifier) and improve model performance

# %%
df_train_no_claim_id_9_length = df_train[df_train['Claim Identifier'].astype(str).apply(len) != 9]

# %% [markdown]
# Let's check if "Claim Identifier" has missing values

# %%
df_train_no_claim_id_9_length["Claim Identifier"].isna().sum()
# Out:
# 0

# %% [markdown]
# **Conclusion:** No missing values

# %% [markdown]
# Let's check if "Claim Identifier" has duplicates

# %%
df_train_no_claim_id_9_length["Claim Identifier"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Conclusion:** No duplicates

# %%
df_train_index = df_train_no_claim_id_9_length.set_index("Claim Identifier")
df_train_index.head()
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393875             2019-12-30           31.0                              N
# 5393091             2019-08-30           46.0                              N
# 5393889             2019-12-06           40.0                              N
# 5393887             2019-12-30           61.0                              N
# 5393863             2019-12-26           67.0                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393875             2020-01-01                       N                 0.00
# 5393091             2020-01-01                       Y              1745.93
# 5393889             2020-01-01                       N              1434.80
# 5393887             2020-01-01                       N                  NaN
# 5393863             2020-01-01                       N                 0.00
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 5393875               1988.0  2019-12-31         NaN
# 5393091               1973.0  2020-01-01  2020-01-14
# 5393889               1979.0  2020-01-01         NaN
# 5393887               1958.0  2019-12-31         NaN
# 5393863               1952.0  2019-12-31         NaN
#
#                                   Carrier Name  ... WCIO Cause of Injury Code  \
# Claim Identifier                                ...
# 5393875             NEW HAMPSHIRE INSURANCE CO  ...                      27.0
# 5393091           ZURICH AMERICAN INSURANCE CO  ...                      97.0
# 5393889              INDEMNITY INSURANCE CO OF  ...                      79.0
# 5393887                   STATE INSURANCE FUND  ...                      16.0
# 5393863            INDEMNITY INS. OF N AMERICA  ...                      31.0
#
#                  WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 5393875              FROM LIQUID OR GREASE SPILLS                       10.0
# 5393091                         REPETITIVE MOTION                       49.0
# 5393889            OBJECT BEING LIFTED OR HANDLED                        7.0
# 5393887           HAND TOOL, UTENSIL; NOT POWERED                       43.0
# 5393863                   FALL, SLIP OR TRIP, NOC                       10.0
#
#                  WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5393875                                  CONTUSION                   62.0
# 5393091                             SPRAIN OR TEAR                   38.0
# 5393889                                 CONCUSSION                   10.0
# 5393887                                   PUNCTURE                   36.0
# 5393863                                  CONTUSION                   38.0
#
#                  WCIO Part Of Body Description Zip Code  Agreement Reached  \
# Claim Identifier
# 5393875                               BUTTOCKS    13662                0.0
# 5393091                            SHOULDER(S)    14569                1.0
# 5393889                   MULTIPLE HEAD INJURY    12589                0.0
# 5393887                              FINGER(S)    12603                0.0
# 5393863                            SHOULDER(S)    11772                0.0
#
#                       WCB Decision Number of Dependents
# Claim Identifier
# 5393875           Not Work Related                  1.0
# 5393091           Not Work Related                  4.0
# 5393889           Not Work Related                  6.0
# 5393887           Not Work Related                  1.0
# 5393863           Not Work Related                  5.0
#
# [5 rows x 32 columns]

# %% [markdown]
# # 4.1. Constant Features <a id="constant_feature"></a>

# %%
variances = df_train_index.var(numeric_only=True)
variances[variances == 0]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# **Conclusion**: There are no univariate features

# %% [markdown]
# # 4.2. Duplicates

# %%
# Check for duplicated observations
df_train_index.duplicated().sum()
# Out:
# 1

# %% [markdown]
# **Conclusion:** There is 1 duplicated observation. Let's drop it

# %%
# Drop all duplicates
df_train_no_duplicates = df_train_index.drop_duplicates(keep='first')

# %% [markdown]
# # 4.3. Missing Values

# %% [markdown]
# - columns with just missing values:
#   - 'OIICS Nature of Injury Description'
# - hidden missing values:
#   - 'Carrier Type'
#   - 'Gender'
#   - 'Medical Fee Region'
#   - 'Alternative Dispute Resolution'

# %%
df_train_treat_missing = df_train_no_duplicates.copy()

# %% [markdown]
# Drop column "OIICS Nature of Injury Description", because it has only missing values

# %%
df_train_treat_missing["OIICS Nature of Injury Description"].value_counts(dropna=False, normalize=True) * 100
# Out:
# OIICS Nature of Injury Description
# NaN    100.0
# Name: proportion, dtype: float64

# %%
df_train_treat_missing.drop(columns=["OIICS Nature of Injury Description"], inplace=True)

# %% [markdown]
# Check hidden missing values

# %%
df_train_treat_missing["Carrier Type"].value_counts(dropna=False, normalize=True) * 100
# Out:
# Carrier Type
# 1A. PRIVATE                                    49.713340
# 3A. SELF PUBLIC                                21.239493
# 2A. SIF                                        19.362223
# 4A. SELF PRIVATE                                9.196115
# UNKNOWN                                         0.309046
# 5D. SPECIAL FUND - UNKNOWN                      0.178215
# 5C. SPECIAL FUND - POI CARRIER WCB MENANDS      0.000871
# 5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)     0.000697
# Name: proportion, dtype: float64

# %%
df_train_treat_missing[df_train_treat_missing["Carrier Type"] == "UNKNOWN"].describe().T
# Out:
#                              count         mean         std   min     25%  \
# Age at Injury               1774.0    37.949267   17.329159   0.0    28.0
# Average Weekly Wage         1682.0    10.470488  103.732252   0.0     0.0
# Birth Year                  1681.0  1710.386675  676.139876   0.0  1960.0
# IME-4 Count                  116.0     2.293103    1.652493   1.0     1.0
# Industry Code                625.0    46.411200   18.525940  11.0    23.0
# WCIO Cause of Injury Code    387.0    52.299742   26.988350   1.0    28.5
# WCIO Nature of Injury Code   366.0    47.117486   27.002483   1.0    20.5
# WCIO Part Of Body Code       555.0    23.819820   33.051103  -9.0    -9.0
# Agreement Reached           1774.0     0.020293    0.141041   0.0     0.0
# Number of Dependents        1774.0     3.016347    1.997817   0.0     1.0
#
#                                50%     75%     max
# Age at Injury                 38.0    51.0    79.0
# Average Weekly Wage            0.0     0.0  2500.0
# Birth Year                  1974.0  1987.0  2008.0
# IME-4 Count                    2.0     3.0    11.0
# Industry Code                 48.0    56.0    92.0
# WCIO Cause of Injury Code     45.0    75.0    99.0
# WCIO Nature of Injury Code    52.0    59.0    90.0
# WCIO Part Of Body Code        23.0    46.0    99.0
# Agreement Reached              0.0     0.0     1.0
# Number of Dependents           3.0     5.0     6.0

# %%
df_train_treat_missing[df_train_treat_missing["Carrier Type"] == "UNKNOWN"].describe(include='object').T
# Out:
#                                   count unique  \
# Accident Date                      1719    941
# Alternative Dispute Resolution     1774      1
# Assembly Date                      1774    679
# Attorney/Representative            1774      2
# C-2 Date                            572    375
# C-3 Date                           1421    696
# Carrier Name                       1774      1
# Carrier Type                       1774      1
# Claim Injury Type                  1774      5
# County of Injury                   1774     57
# COVID-19 Indicator                 1774      2
# District Name                      1774      8
# First Hearing Date                  682    425
# Gender                             1774      4
# Industry Code Description           625     18
# Medical Fee Region                 1774      5
# WCIO Cause of Injury Description    387     47
# WCIO Nature of Injury Description   366     29
# WCIO Part Of Body Description       555     44
# Zip Code                           1698    638
# WCB Decision                       1774      1
#
#                                                                            top  \
# Accident Date                                                       2001-09-11
# Alternative Dispute Resolution                                               N
# Assembly Date                                                       2022-10-03
# Attorney/Representative                                                      Y
# C-2 Date                                                            2022-09-27
# C-3 Date                                                            2020-02-03
# Carrier Name                                      *** CARRIER UNDETERMINED ***
# Carrier Type                                                           UNKNOWN
# Claim Injury Type                                                  2. NON-COMP
# County of Injury                                                        QUEENS
# COVID-19 Indicator                                                           N
# District Name                                                        STATEWIDE
# First Hearing Date                                                  2022-08-05
# Gender                                                                       M
# Industry Code Description                                         CONSTRUCTION
# Medical Fee Region                                                          IV
# WCIO Cause of Injury Description   COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# WCIO Nature of Injury Description                                    CONTUSION
# WCIO Part Of Body Description                                         MULTIPLE
# Zip Code                                                                 11368
# WCB Decision                                                  Not Work Related
#
#                                    freq
# Accident Date                        56
# Alternative Dispute Resolution     1774
# Assembly Date                         8
# Attorney/Representative            1079
# C-2 Date                              7
# C-3 Date                              8
# Carrier Name                       1774
# Carrier Type                       1774
# Claim Injury Type                  1529
# County of Injury                    404
# COVID-19 Indicator                 1721
# District Name                       695
# First Hearing Date                    7
# Gender                             1383
# Industry Code Description           157
# Medical Fee Region                 1154
# WCIO Cause of Injury Description     52
# WCIO Nature of Injury Description    69
# WCIO Part Of Body Description       238
# Zip Code                             52
# WCB Decision                       1774

# %% [markdown]
# **Decision:** 'UNKNOWN' indicates that the type of the insurance provider was unavailable or not recorded at the time the data was collected, so it should be replaced with np.nan (instead of dropping because they have meaningful information)

# %%
df_train_treat_missing["Gender"].value_counts(dropna=False, normalize=True) * 100
# Out:
# Gender
# M    58.397631
# F    40.773660
# U     0.820696
# X     0.008014
# Name: proportion, dtype: float64

# %%
df_train_treat_missing[df_train_treat_missing["Gender"] == "U"].describe().T
# Out:
#                              count         mean         std   min     25%  \
# Age at Injury               4711.0    39.962428   14.608975   0.0    29.0
# Average Weekly Wage         4488.0   264.574615  597.232754   0.0     0.0
# Birth Year                  4471.0  1835.771416  514.235587   0.0  1965.0
# IME-4 Count                  567.0     3.250441    2.921360   1.0     1.0
# Industry Code               4656.0    55.841065   14.845878  11.0    48.0
# WCIO Cause of Injury Code   4648.0    56.717083   26.655002   1.0    31.0
# WCIO Nature of Injury Code  4648.0    45.676850   24.565870   1.0    28.0
# WCIO Part Of Body Code      4642.0    44.548255   23.583361  -9.0    35.0
# Agreement Reached           4711.0     0.035237    0.184397   0.0     0.0
# Number of Dependents        4711.0     3.009128    2.009352   0.0     1.0
#
#                                50%     75%      max
# Age at Injury                 38.0    52.0    84.00
# Average Weekly Wage            0.0     0.0  5309.25
# Birth Year                  1980.0  1991.0  2006.00
# IME-4 Count                    2.0     4.0    21.00
# Industry Code                 61.0    62.0    92.00
# WCIO Cause of Injury Code     59.0    81.0    99.00
# WCIO Nature of Injury Code    52.0    59.0    91.00
# WCIO Part Of Body Code        42.0    55.0    99.00
# Agreement Reached              0.0     0.0     1.00
# Number of Dependents           3.0     5.0     6.00

# %%
df_train_treat_missing[df_train_treat_missing["Gender"] == "U"].describe(include='object').T
# Out:
#                                   count unique  \
# Accident Date                      4710   1248
# Alternative Dispute Resolution     4711      2
# Assembly Date                      4711    771
# Attorney/Representative            4711      2
# C-2 Date                           4652    879
# C-3 Date                            754    501
# Carrier Name                       4711    449
# Carrier Type                       4711      7
# Claim Injury Type                  4711      6
# County of Injury                   4711     63
# COVID-19 Indicator                 4711      2
# District Name                      4711      8
# First Hearing Date                  673    468
# Gender                             4711      1
# Industry Code Description          4656     20
# Medical Fee Region                 4711      5
# WCIO Cause of Injury Description   4648     67
# WCIO Nature of Injury Description  4648     41
# WCIO Part Of Body Description      4642     53
# Zip Code                           4468   1289
# WCB Decision                       4711      1
#
#                                                                  top  freq
# Accident Date                                             2022-01-03    18
# Alternative Dispute Resolution                                     N  4709
# Assembly Date                                             2022-01-07    22
# Attorney/Representative                                            N  3940
# C-2 Date                                                  2022-10-20    21
# C-3 Date                                                  2022-12-22     5
# Carrier Name                           SAFETY NATIONAL CASUALTY CORP   693
# Carrier Type                                             1A. PRIVATE  3713
# Claim Injury Type                                        2. NON-COMP  3072
# County of Injury                                              QUEENS   451
# COVID-19 Indicator                                                 N  4067
# District Name                                                    NYC  2331
# First Hearing Date                                        2023-05-09     6
# Gender                                                             U  4711
# Industry Code Description          HEALTH CARE AND SOCIAL ASSISTANCE  1407
# Medical Fee Region                                                IV  1998
# WCIO Cause of Injury Description                            PANDEMIC   625
# WCIO Nature of Injury Description                     STRAIN OR TEAR  1110
# WCIO Part Of Body Description                        LOWER BACK AREA   364
# Zip Code                                                       12208    32
# WCB Decision                                        Not Work Related  4711

# %% [markdown]
# **Decision:**
# - Drop X: Since the X category represents a very small percentage (0.008%), it likely won’t provide much value for the predictive model, so it can be safely dropped.
# - Convert U to missing: The U category may represent unknown or unspecified gender. Therefore, converting U to missing value seems a reasonable approach

# %%
df_train_treat_missing = df_train_treat_missing[df_train_treat_missing['Gender'] != 'X']

# %%
df_train_treat_missing["Medical Fee Region"].value_counts(dropna=False, normalize=True) * 100
# Out:
# Medical Fee Region
# IV     46.333402
# I      23.674211
# II     14.814479
# III     9.347380
# UK      5.830527
# Name: proportion, dtype: float64

# %% [markdown]
# **Decision:** 'UK' likely refers to 'Unknown'. Therefore, replacing 'UK' with np.nan allows subsequent analyses to focus on the regions that are known (I, II, III, IV) without the influence of ambiguous entries

# %%
df_train_treat_missing["Alternative Dispute Resolution"].value_counts(dropna=False, normalize=True) * 100
# Out:
# Alternative Dispute Resolution
# N    99.544583
# Y     0.454546
# U     0.000871
# Name: proportion, dtype: float64

# %% [markdown]
# **Decision:** Treating 'U' as a missing value (pd.NA) seems a good approach given the binary context of the variable and the low frequency of this value. This will help in maintaining data integrity and ensuring that our analysis is accurate and meaningful

# %% [markdown]
# The missing values in the original DataFrame are represented as np.nan. To ensure consistency throughout our dataset, we will standardize the representation of missing values (as np.nan)

# %%
df_train_treat_missing["Carrier Type"].replace("UNKNOWN", np.nan, inplace=True)
df_train_treat_missing["Gender"].replace("U", np.nan, inplace=True)
df_train_treat_missing["Medical Fee Region"].replace("UK", np.nan, inplace=True)
df_train_treat_missing["Alternative Dispute Resolution"].replace("U", np.nan, inplace=True)

# %% [markdown]
# "As a general rule of thumb, only features that are missing in excess of 60% of their values should be considered for complete removal" (Fundamentals of Machine Learning for Predictive Data Analytics Algorithms).

# %%
# Calculate the percentage of missing values in each column
perc_missing_values = (df_train_treat_missing.isna().sum() / len(df_train_treat_missing) * 100).round(2)
perc_missing_values[perc_missing_values > 0].sort_values(ascending=False)
# Out:
# IME-4 Count                          76.87
# First Hearing Date                   73.73
# C-3 Date                             67.39
# Medical Fee Region                    5.83
# Birth Year                            5.07
# Zip Code                              4.99
# Average Weekly Wage                   4.99
# WCIO Part Of Body Description         2.98
# WCIO Part Of Body Code                2.98
# WCIO Nature of Injury Description     2.73
# WCIO Nature of Injury Code            2.73
# WCIO Cause of Injury Code             2.72
# WCIO Cause of Injury Description      2.72
# C-2 Date                              2.54
# Industry Code                         1.73
# Industry Code Description             1.73
# Gender                                0.82
# Accident Date                         0.64
# Carrier Type                          0.31
# dtype: float64

# %% [markdown]
# Let's evaluate the columns with more than 60% of missing values, before dropping them

# %% [markdown]
# **'IME-4 Count':**

# %%
df_train_treat_missing["IME-4 Count"].value_counts(dropna=False, normalize=True).sort_index() * 100
# Out:
# IME-4 Count
# 1.0      6.985273
# 2.0      6.010847
# 3.0      2.810904
# 4.0      2.400959
# 5.0      1.338028
# 6.0      1.119727
# 7.0      0.668666
# 8.0      0.549846
# 9.0      0.333636
# 10.0     0.254365
# 11.0     0.174571
# 12.0     0.140597
# 13.0     0.089899
# 14.0     0.068992
# 15.0     0.047563
# 16.0     0.037284
# 17.0     0.021778
# 18.0     0.024391
# 19.0     0.013764
# 20.0     0.009756
# 21.0     0.009234
# 22.0     0.005924
# 23.0     0.003310
# 24.0     0.002788
# 25.0     0.001220
# 26.0     0.001394
# 27.0     0.002439
# 28.0     0.000697
# 29.0     0.000871
# 30.0     0.000697
# 31.0     0.000348
# 32.0     0.000697
# 33.0     0.000348
# 34.0     0.000697
# 35.0     0.000174
# 36.0     0.000523
# 37.0     0.000174
# 39.0     0.000348
# 47.0     0.000174
# 48.0     0.000174
# 73.0     0.000174
# NaN     76.866749
# Name: proportion, dtype: float64

# %% [markdown]
# A value of 0 in "IME-4 Count" seems plausible, as it indicates that no forms were submitted for certain claims. Since there are no recorded instances with a value of 0, it raises the possibility that the existing missing values might actually represent cases where no forms were received, suggesting that some of these NaNs could be interpreted as 0. However, assuming all missing values correspond 0 is a very strong assumption
#
# Due to this potential interpretation, we need to analyze the variable more carefully

# %%
# Calculate the total number of entries
total_count = df_train_treat_missing['IME-4 Count'].count() + df_train_treat_missing['IME-4 Count'].isna().sum()

# Count NaN values and counts of 1 and 2
count_nan_or_1_or_2 = df_train_treat_missing['IME-4 Count'].isna().sum() + \
                      ((df_train_treat_missing['IME-4 Count'] == 1).sum()) + \
                      ((df_train_treat_missing['IME-4 Count'] == 2).sum())

# Count occurrences greater than 2
count_above_2 = (df_train_treat_missing['IME-4 Count'] > 2).sum()

# Create a summary DataFrame with percentages
summary_df = pd.DataFrame({
    'Category': ['NaN or 1 or 2', 'Above 2'],
    'Count': [count_nan_or_1_or_2, count_above_2]
})

# Calculate percentages
summary_df['Percentage'] = (summary_df['Count'] / total_count) * 100

# Create a bar chart for percentages
plt.figure(figsize=(8, 5))
bars = plt.bar(summary_df['Category'], summary_df['Percentage'], color=['orange', 'blue'])
plt.title('Percentage of IME-4 Count', fontsize=14)
plt.ylabel('Percentage', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.2f}%', ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Conclusion:** As a large portion of the dataset (around 90%) either has no information on IME-4 forms (which could indicate 0 IME-4 forms received per claim) or reports very low counts, the column may not add valuable insights or predictive power in modeling contexts. Therefore, we decided to drop this variable

# %%
df_train_treat_missing.drop(columns="IME-4 Count", inplace=True)

# %% [markdown]
# **'First Hearing Date':**
# While this variable contains a significant proportion of missing values (73.73%), these missing values carry important information— a blank date indicates that the claim has not yet had a hearing. Therefore, we will retain this variable.
#
# **'C-3 Date':** Similarly, C-3 Date also has a large proportion of missing values (67.39%). However, these missing values are meaningful because they may indicate that the form has not been received yet. Therefore, we will retain this variable.

# %% [markdown]
# Let's treat missing values (by row)

# %% [markdown]
# Check the percentage and cumulative percentage of rows in the DataFrame based on the number of missing values

# %%
# Count the number of missing values per row
missing_counts = df_train_treat_missing.isna().sum(axis=1)

# Calculate the total number of rows
total_rows = len(df_train_treat_missing)

# Calculate the percentage of missing values per row
total_columns = df_train_treat_missing.shape[1]  # Total number of columns
missing_value_percentage_per_row = (missing_counts / total_columns) * 100

# Count the occurrences of each missing value percentage
missing_percentage_counts = missing_value_percentage_per_row.value_counts().sort_index()

# Calculate the percentage of rows corresponding to each unique count of missing values
perc_rows_count = missing_percentage_counts.values / total_rows * 100

# Create a DataFrame with missing values and their percentages
results_df = pd.DataFrame({
    'Missing Values (%)': missing_percentage_counts.index.round(2),
    'Rows Count (%)': perc_rows_count.round(2),
})

# Calculate cumulative percentage
results_df['Cumulative Rows Count (%)'] = perc_rows_count.cumsum().round(2)

# Set the index name
results_df.index.name = 'Missing Values'

# Display the results
results_df
# Out:
#                 Missing Values (%)  Rows Count (%)  Cumulative Rows Count (%)
# Missing Values
# 0                             0.00           14.62                      14.62
# 1                             3.33           19.02                      33.64
# 2                             6.67           51.37                      85.01
# 3                            10.00           10.91                      95.92
# 4                            13.33            1.26                      97.18
# 5                            16.67            0.13                      97.31
# 6                            20.00            0.04                      97.35
# 7                            23.33            0.07                      97.43
# 8                            26.67            0.40                      97.82
# 9                            30.00            0.57                      98.39
# 10                           33.33            0.62                      99.01
# 11                           36.67            0.73                      99.74
# 12                           40.00            0.23                      99.97
# 13                           43.33            0.03                     100.00
# 14                           46.67            0.00                     100.00
# 15                           50.00            0.00                     100.00

# %%
# Create formatted labels for the x-axis
results_df['Missing Values Labels'] = '(' + results_df['Missing Values (%)'].astype(str) + '%)  ' + results_df.index.astype(str)

# Create a line chart for cumulative rows count
plt.figure(figsize=(10, 6))

# Plot Cumulative Rows Count (%)
plt.plot(results_df['Missing Values (%)'], results_df['Cumulative Rows Count (%)'], marker='o', color='orange', linewidth=2, label='Cumulative Rows Count (%)')

# Add labels and title
plt.title('Cumulative Rows Count (%) by Missing Values', fontsize=14)
plt.xlabel('Missing Values', labelpad=15, fontsize=12)
plt.ylabel('Cumulative Rows Count (%)', fontsize=12)

# Set y-axis limits to start from 0
plt.ylim(0, 110)  # Adding a little space for the highest point

# Display custom labels on x-ticks
plt.xticks(results_df['Missing Values (%)'], results_df['Missing Values Labels'], rotation=90)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show data labels on the cumulative line
for index, value in enumerate(results_df['Cumulative Rows Count (%)']):
    plt.text(results_df['Missing Values (%)'].iloc[index], value + 3, f"{value:.2f}", ha='center')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/3433442896.py in <module>
#       6
#       7 # Plot Cumulative Rows Count (%)
# ----> 8 plt.plot(results_df['Missing Values (%)'], results_df['Cumulative Rows Count (%)'], marker='o', color='orange', linewidth=2, label='Cumulative Rows Count (%)')
#       9
#      10 # Add labels and title
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     485
#     486         if len(xy) == 2:
# --> 487             x = _check_1d(xy[0])
#     488             y = _check_1d(xy[1])
#     489         else:
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1325                     message='Support for multi-dimensional indexing')
#    1326
# -> 1327                 ndim = x[:, None].ndim
#    1328                 # we have definitely hit a pandas index or series object
#    1329                 # cast to a numpy array.
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py in _get_with(self, key)
#    1161             )
#    1162         elif isinstance(key, tuple):
# -> 1163             return self._get_values_tuple(key)
#    1164
#    1165         elif not is_list_like(key):
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py in _get_values_tuple(self, key)
#    1201             # the asarray is needed to avoid returning a 2D DatetimeArray
#    1202             result = np.asarray(self._values[key])
# -> 1203             disallow_ndim_indexing(result)
#    1204             return result
#    1205
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexers/utils.py in disallow_ndim_indexing(result)
#     339     """
#     340     if np.ndim(result) > 1:
# --> 341         raise ValueError(
#     342             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# **Decision:** We decided to be a bit conservative and drop observations with 11 or more missing values (36.67% or more of missing values), affecting less than 1% of the dataset. This minimal loss of data ensures that we maintain a high-quality dataset without significantly impacting the analysis

# %%
# Print the shape of the original DataFrame
original_length = len(df_train_treat_missing)

# Define the threshold for missing values
threshold = 11  # More than 10 missing values

# Create a copy of the DataFrame to avoid modifying the original in place
df_train_treat_missing.dropna(thresh=df_train_treat_missing.shape[1] - threshold, inplace=True)

# Calculate the number of rows removed and the percentage
rows_removed = original_length - len(df_train_treat_missing)
percentage_removed = (rows_removed / original_length) * 100

# Print the number of rows removed and the percentage
print(f"Number of rows removed: {rows_removed} ({round(percentage_removed, 2)}%)")
# Out:
# Number of rows removed: 1502 (0.26%)

# %%
# Calculate the number of rows removed due to duplicates and missing values
total_rows_removed = len(df_train) - len(df_train_treat_missing)

# Calculate the percentage of rows removed
percent_total_rows_removed = total_rows_removed / len(df_train) * 100

# Print the results
print(f"Total rows removed until now: {total_rows_removed} ({round(percent_total_rows_removed, 2)}%)")
# Out:
# Total rows removed until now: 20994 (3.54%)

# %% [markdown]
# # 4.4 Data Types

# %% [markdown]
# - object to datetime:
#   - 'Accident Date'
#   - 'Assembly Date'
#   - 'C-2 Date'
#   - 'C-3 Date'
#   - 'First Hearing Date' (missing values: a blank date means the claim has not yet had a hearing held)
#
# - float to integer:
#   - 'Age at Injury'
#   - 'Birth Year'
#   - 'IME-4 Count'
#   - 'Number of Dependents': not in metadata (make assumption)
#
# - object to binary:
#   - 'Alternative Dispute Resolution'
#   - 'Attorney/Representative'
#   - 'COVID-19 Indicator'

# %%
df_train_adjust_dtypes = df_train_treat_missing.copy()

# %%
columns_object_to_datetime = ['Accident Date', 'Assembly Date', 'C-2 Date', 'C-3 Date', 'First Hearing Date']
columns_float_to_int = ['Age at Injury', 'Birth Year', 'Number of Dependents']
columns_object_to_binary = ['Alternative Dispute Resolution', 'Attorney/Representative', 'COVID-19 Indicator']

# %%
df_train_adjust_dtypes[columns_object_to_datetime + columns_float_to_int + columns_object_to_binary].dtypes
# Out:
# Accident Date                      object
# Assembly Date                      object
# C-2 Date                           object
# C-3 Date                           object
# First Hearing Date                 object
# Age at Injury                     float64
# Birth Year                        float64
# Number of Dependents              float64
# Alternative Dispute Resolution     object
# Attorney/Representative            object
# COVID-19 Indicator                 object
# dtype: object

# %%
df_train_adjust_dtypes[columns_object_to_datetime + columns_float_to_int + columns_object_to_binary].head().T
# Out:
# Claim Identifier                   5393875     5393091     5393889  \
# Accident Date                   2019-12-30  2019-08-30  2019-12-06
# Assembly Date                   2020-01-01  2020-01-01  2020-01-01
# C-2 Date                        2019-12-31  2020-01-01  2020-01-01
# C-3 Date                               NaN  2020-01-14         NaN
# First Hearing Date                     NaN  2020-02-21         NaN
# Age at Injury                         31.0        46.0        40.0
# Birth Year                          1988.0      1973.0      1979.0
# Number of Dependents                   1.0         4.0         6.0
# Alternative Dispute Resolution           N           N           N
# Attorney/Representative                  N           Y           N
# COVID-19 Indicator                       N           N           N
#
# Claim Identifier                   5393887     5393863
# Accident Date                   2019-12-30  2019-12-26
# Assembly Date                   2020-01-01  2020-01-01
# C-2 Date                        2019-12-31  2019-12-31
# C-3 Date                               NaN         NaN
# First Hearing Date                     NaN         NaN
# Age at Injury                         61.0        67.0
# Birth Year                          1958.0      1952.0
# Number of Dependents                   1.0         5.0
# Alternative Dispute Resolution           N           N
# Attorney/Representative                  N           N
# COVID-19 Indicator                       N           N

# %%
# Convert multiple object columns to datetime
for col in columns_object_to_datetime:
    df_train_adjust_dtypes[col] = pd.to_datetime(df_train_adjust_dtypes[col]).dt.date  # Converts missing dates to NaT

# Convert multiple float columns to integers
for col in columns_float_to_int:
    df_train_adjust_dtypes[col] = df_train_adjust_dtypes[col].astype('Int64')  # Use 'Int64' for nullable integer type

# Convert multiple object columns to binary
for col in columns_object_to_binary:
    df_train_adjust_dtypes[col] = df_train_adjust_dtypes[col].map({'Y': 1, 'N': 0}).astype('Int64')  # Use 'Int64' for nullable integers

# %%
# Check data types
df_train_adjust_dtypes[columns_object_to_datetime + columns_float_to_int + columns_object_to_binary].dtypes
# Out:
# Accident Date                     object
# Assembly Date                     object
# C-2 Date                          object
# C-3 Date                          object
# First Hearing Date                object
# Age at Injury                      Int64
# Birth Year                         Int64
# Number of Dependents               Int64
# Alternative Dispute Resolution     Int64
# Attorney/Representative            Int64
# COVID-19 Indicator                 Int64
# dtype: object

# %%
df_train_adjust_dtypes[columns_object_to_datetime + columns_float_to_int + columns_object_to_binary].head().T
# Out:
# Claim Identifier                   5393875     5393091     5393889  \
# Accident Date                   2019-12-30  2019-08-30  2019-12-06
# Assembly Date                   2020-01-01  2020-01-01  2020-01-01
# C-2 Date                        2019-12-31  2020-01-01  2020-01-01
# C-3 Date                               NaT  2020-01-14         NaT
# First Hearing Date                     NaT  2020-02-21         NaT
# Age at Injury                           31          46          40
# Birth Year                            1988        1973        1979
# Number of Dependents                     1           4           6
# Alternative Dispute Resolution           0           0           0
# Attorney/Representative                  0           1           0
# COVID-19 Indicator                       0           0           0
#
# Claim Identifier                   5393887     5393863
# Accident Date                   2019-12-30  2019-12-26
# Assembly Date                   2020-01-01  2020-01-01
# C-2 Date                        2019-12-31  2019-12-31
# C-3 Date                               NaT         NaT
# First Hearing Date                     NaT         NaT
# Age at Injury                           61          67
# Birth Year                            1958        1952
# Number of Dependents                     1           5
# Alternative Dispute Resolution           0           0
# Attorney/Representative                  0           0
# COVID-19 Indicator                       0           0

# %% [markdown]
# # 4.5. Inconsistencies

# %% [markdown]
# - from the start of 2020 till the end of 2022

# %%
df_inconsistencies = df_train_adjust_dtypes.copy()

# %% [markdown]
# ## Date Format

# %%
# Ensure 'Accident Date' is in datetime format
df_inconsistencies['Accident Date'] = pd.to_datetime(df_inconsistencies['Accident Date'], errors='coerce')

# Check for inconsistencies between 'Age at Injury', 'Accident Date', and 'Birth Year'
inconsistent_rows = df_inconsistencies[
    df_inconsistencies['Age at Injury'] != (df_inconsistencies['Accident Date'].dt.year - df_inconsistencies['Birth Year'])
]

# Display rows with inconsistencies
inconsistent_rows[['Age at Injury', 'Accident Date', 'Birth Year']]
# Out:
#                   Age at Injury Accident Date  Birth Year
# Claim Identifier
# 5394187                      21    2019-12-14           0
# 5393907                      62    2019-08-26        1956
# 5393931                      30    2019-09-15        1988
# 5394053                      53    2019-12-18           0
# 5393827                      21    2019-12-26           0
# ...                         ...           ...         ...
# 6165417                      59    2022-10-20        1962
# 6165584                      29    2022-12-29        1994
# 6164295                      45    2022-09-06        1976
# 6164286                      70    2022-12-28           0
# 6165627                      19    2022-11-27           0
#
# [267470 rows x 3 columns]

# %%
inconsistent_rows[['Age at Injury', 'Accident Date', 'Birth Year']].describe()
# Out:
#        Age at Injury                  Accident Date  Birth Year
# count       267470.0                         267470    267470.0
# mean        41.99361  2021-03-11 15:27:50.775788032  1797.02164
# min              0.0            1961-09-06 00:00:00         0.0
# 25%             31.0            2020-06-25 00:00:00      1963.0
# 50%             42.0            2021-04-23 00:00:00      1976.0
# 75%             53.0            2022-02-18 00:00:00      1988.0
# max            115.0            2023-08-01 00:00:00      2018.0
# std        13.972833                            NaN  569.916921

# %% [markdown]
# ## 'Zip-Code'

# %% [markdown]
# - Standard ZIP codes in NY are 5 digits long. Some locations use the extended ZIP+4 format, which is 9 digits in total.
# - (If we only have the last four digits of a ZIP+4 code, it would be very difficult, if not impossible, to identify a specific address or home on its own.)
# - [https://worldpopulationreview.com/zips/new-york]

# %%
count_invalid_zip_codes = df_inconsistencies[
    (df_inconsistencies["Zip Code"].astype(str).apply(len) != 5) & 
    (df_inconsistencies["Zip Code"].astype(str).apply(len) != 9) & 
    df_inconsistencies["Zip Code"].notna()
]
count_invalid_zip_codes
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5447424             2018-03-05             21                               0
# 5538122             2020-08-04             52                               0
# 5629816             2019-11-10             24                               0
# 5689543             2021-03-22             35                               0
# 5734008             2021-05-21             34                               0
# ...                        ...            ...                             ...
# 5939291             2022-02-12             28                               0
# 5949825             2020-10-11             25                               0
# 5984859             2022-04-30             30                               0
# 6012564             2021-04-21             26                               0
# 6111548             2021-10-02             23                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5447424             2020-03-09                        1              1305.92
# 5538122             2020-08-14                        1               540.00
# 5629816             2021-01-06                        1                 0.00
# 5689543             2021-03-29                        1              1450.17
# 5734008             2021-05-28                        0              1244.35
# ...                        ...                      ...                  ...
# 5939291             2022-03-09                        1              2289.38
# 5949825             2022-03-24                        1                 0.00
# 5984859             2022-05-06                        1              1455.54
# 6012564             2022-06-14                        1              1450.17
# 6111548             2022-10-19                        1              1594.56
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 5447424                    0  2020-04-14  2020-03-03
# 5538122                    0  2020-08-14  2020-08-19
# 5629816                    0  2021-01-19  2020-12-28
# 5689543                    0  2021-03-29  2022-04-07
# 5734008                 1987  2021-05-28         NaT
# ...                      ...         ...         ...
# 5939291                    0  2022-03-09  2023-06-14
# 5949825                    0  2022-04-26  2022-03-07
# 5984859                    0  2022-05-06         NaT
# 6012564                    0  2022-06-28  2022-06-10
# 6111548                 <NA>  2022-11-11  2022-10-12
#
#                                  Carrier Name  ... WCIO Cause of Injury Code  \
# Claim Identifier                               ...
# 5447424             FEDERAL INSURANCE COMPANY  ...                      53.0
# 5538122                  STATE INSURANCE FUND  ...                      27.0
# 5629816                  STATE INSURANCE FUND  ...                      19.0
# 5689543             ACE AMERICAN INSURANCE CO  ...                      74.0
# 5734008              MEMORIAL SLOAN KETTERING  ...                      56.0
# ...                                       ...  ...                       ...
# 5939291                  STATE INSURANCE FUND  ...                      53.0
# 5949825           TRI-STATE INSURANCE COMPANY  ...                      60.0
# 5984859                  STATE INSURANCE FUND  ...                      99.0
# 6012564             ACE AMERICAN INSURANCE CO  ...                      74.0
# 6111548             ACE AMERICAN INSURANCE CO  ...                      97.0
#
#                         WCIO Cause of Injury Description  \
# Claim Identifier
# 5447424                                         TWISTING
# 5538122                     FROM LIQUID OR GREASE SPILLS
# 5629816                       CUT, PUNCTURE, SCRAPE, NOC
# 5689543           FELLOW WORKER, PATIENT OR OTHER PERSON
# 5734008                                          LIFTING
# ...                                                  ...
# 5939291                                         TWISTING
# 5949825                         STRAIN OR INJURY BY, NOC
# 5984859                       OTHER - MISCELLANEOUS, NOC
# 6012564           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6111548                                REPETITIVE MOTION
#
#                  WCIO Nature of Injury Code  \
# Claim Identifier
# 5447424                                52.0
# 5538122                                28.0
# 5629816                                40.0
# 5689543                                49.0
# 5734008                                52.0
# ...                                     ...
# 5939291                                52.0
# 5949825                                52.0
# 5984859                                49.0
# 6012564                                49.0
# 6111548                                49.0
#
#                   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5447424                              STRAIN OR TEAR                   51.0
# 5538122                                    FRACTURE                   34.0
# 5629816                                  LACERATION                   18.0
# 5689543                              SPRAIN OR TEAR                   55.0
# 5734008                              STRAIN OR TEAR                   42.0
# ...                                             ...                    ...
# 5939291                              STRAIN OR TEAR                   53.0
# 5949825                              STRAIN OR TEAR                   55.0
# 5984859                              SPRAIN OR TEAR                   53.0
# 6012564                              SPRAIN OR TEAR                   53.0
# 6111548                              SPRAIN OR TEAR                   53.0
#
#                  WCIO Part Of Body Description Zip Code  Agreement Reached  \
# Claim Identifier
# 5447424                                    HIP      T2V                0.0
# 5538122                                  WRIST      SLV                1.0
# 5629816                            SOFT TISSUE      L9W                0.0
# 5689543                                  ANKLE      P7G                0.0
# 5734008                        LOWER BACK AREA  10567.0                0.0
# ...                                        ...      ...                ...
# 5939291                                   KNEE      K9J                0.0
# 5949825                                  ANKLE      M5R                0.0
# 5984859                                   KNEE      L1G                0.0
# 6012564                                   KNEE      J5K                0.0
# 6111548                                   KNEE      N8H                0.0
#
#                       WCB Decision Number of Dependents
# Claim Identifier
# 5447424           Not Work Related                    4
# 5538122           Not Work Related                    6
# 5629816           Not Work Related                    0
# 5689543           Not Work Related                    6
# 5734008           Not Work Related                    2
# ...                            ...                  ...
# 5939291           Not Work Related                    2
# 5949825           Not Work Related                    4
# 5984859           Not Work Related                    6
# 6012564           Not Work Related                    0
# 6111548           Not Work Related                    1
#
# [15004 rows x 30 columns]

# %%
df_with_letters_and_numbers = df_inconsistencies[df_inconsistencies['Zip Code'].str.contains(r'[A-Za-z]', regex=True) & df_inconsistencies['Zip Code'].str.contains(r'\d', regex=True)]
df_with_letters_and_numbers
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5399802             2019-12-21             25                               0
# 5404203             2020-01-11             29                               0
# 5407348             2019-12-28             23                               0
# 5413081             2020-01-21             27                               0
# 5415188             2020-01-23             54                               0
# ...                        ...            ...                             ...
# 6143240             2022-11-07             23                               0
# 6147711             2022-11-02             29                               0
# 6150118             2022-01-29             25                               0
# 6152050             2022-12-03             30                               0
# 6164424             2022-11-13             23                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5399802             2020-01-09                        0              1631.50
# 5404203             2020-01-16                        1              1401.17
# 5407348             2020-01-17                        0                 0.00
# 5413081             2020-01-27                        0                 0.00
# 5415188             2020-01-28                        0                 0.00
# ...                        ...                      ...                  ...
# 6143240             2022-11-29                        0                 0.00
# 6147711             2022-12-06                        0                 0.00
# 6150118             2022-12-09                        1              1748.25
# 6152050             2022-12-12                        0                 0.00
# 6164424             2022-12-29                        0                 0.00
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 5399802                    0  2020-01-09         NaT
# 5404203                    0  2020-03-11  2021-07-01
# 5407348                    0  2020-01-17         NaT
# 5413081                    0  2020-01-27         NaT
# 5415188                    0  2020-01-28         NaT
# ...                      ...         ...         ...
# 6143240                    0  2022-11-29         NaT
# 6147711                    0  2022-12-06         NaT
# 6150118                    0  2022-12-20  2022-12-06
# 6152050                    0  2022-12-12         NaT
# 6164424                    0  2022-12-29         NaT
#
#                                    Carrier Name  ...  \
# Claim Identifier                                 ...
# 5399802                    STATE INSURANCE FUND  ...
# 5404203              ACE AMERICAN INSURANCE CO.  ...
# 5407348                    STATE INSURANCE FUND  ...
# 5413081                    STATE INSURANCE FUND  ...
# 5415188                        AIU INSURANCE CO  ...
# ...                                         ...  ...
# 6143240                  ARCH INSURANCE COMPANY  ...
# 6147711                 A I U INSURANCE COMPANY  ...
# 6150118                    STATE INSURANCE FUND  ...
# 6152050                    STATE INSURANCE FUND  ...
# 6164424           TRI-STATE INS CO OF MINNESOTA  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5399802                               60.0
# 5404203                               75.0
# 5407348                               99.0
# 5413081                               60.0
# 5415188                               29.0
# ...                                    ...
# 6143240                               19.0
# 6147711                               19.0
# 6150118                               53.0
# 6152050                               99.0
# 6164424                               74.0
#
#                         WCIO Cause of Injury Description  \
# Claim Identifier
# 5399802                         STRAIN OR INJURY BY, NOC
# 5404203                         FALLING OR FLYING OBJECT
# 5407348                       OTHER - MISCELLANEOUS, NOC
# 5413081                         STRAIN OR INJURY BY, NOC
# 5415188                                    ON SAME LEVEL
# ...                                                  ...
# 6143240                       CUT, PUNCTURE, SCRAPE, NOC
# 6147711                       CUT, PUNCTURE, SCRAPE, NOC
# 6150118                                         TWISTING
# 6152050                       OTHER - MISCELLANEOUS, NOC
# 6164424           FELLOW WORKER, PATIENT OR OTHER PERSON
#
#                  WCIO Nature of Injury Code  \
# Claim Identifier
# 5399802                                52.0
# 5404203                                10.0
# 5407348                                 7.0
# 5413081                                49.0
# 5415188                                52.0
# ...                                     ...
# 6143240                                40.0
# 6147711                                43.0
# 6150118                                52.0
# 6152050                                52.0
# 6164424                                40.0
#
#                   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5399802                              STRAIN OR TEAR                   52.0
# 5404203                                   CONTUSION                   65.0
# 5407348                                  CONCUSSION                   18.0
# 5413081                              SPRAIN OR TEAR                   54.0
# 5415188                              STRAIN OR TEAR                   42.0
# ...                                             ...                    ...
# 6143240                                  LACERATION                   35.0
# 6147711                                    PUNCTURE                   36.0
# 6150118                              STRAIN OR TEAR                   55.0
# 6152050                              STRAIN OR TEAR                   38.0
# 6164424                                  LACERATION                   35.0
#
#                                       WCIO Part Of Body Description Zip Code  \
# Claim Identifier
# 5399802                                                   UPPER LEG    L1N 5
# 5404203           INSUFFICIENT INFO TO PROPERLY IDENTIFY - UNCLA...    T1B0P
# 5407348                                                 SOFT TISSUE    L6Y 1
# 5413081                                                   LOWER LEG    N2P 1
# 5415188                                             LOWER BACK AREA    H7X3Z
# ...                                                             ...      ...
# 6143240                                                        HAND    V1M2B
# 6147711                                                   FINGER(S)    L2P0A
# 6150118                                                       ANKLE    L6L 1
# 6152050                                                 SHOULDER(S)    L1A 1
# 6164424                                                        HAND    G9B0Y
#
#                   Agreement Reached      WCB Decision Number of Dependents
# Claim Identifier
# 5399802                         0.0  Not Work Related                    0
# 5404203                         0.0  Not Work Related                    5
# 5407348                         0.0  Not Work Related                    2
# 5413081                         0.0  Not Work Related                    3
# 5415188                         0.0  Not Work Related                    0
# ...                             ...               ...                  ...
# 6143240                         0.0  Not Work Related                    2
# 6147711                         0.0  Not Work Related                    3
# 6150118                         0.0  Not Work Related                    0
# 6152050                         0.0  Not Work Related                    5
# 6164424                         0.0  Not Work Related                    0
#
# [319 rows x 30 columns]

# %% [markdown]
# **Conclusion:** We have 319 rows that the zip-code contains letters. As we know, the zip-code in NY only contains numbers!

# %%
#M3K2B

df_with_letters_and_numbers[df_with_letters_and_numbers["Zip Code"] == "V6B2M"]
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5826137             2021-06-14             26                               0
# 5965183             2022-03-23             22                               0
# 6009803             2022-05-27             22                               0
# 6045709             2022-07-19             28                               0
# 6046792             2022-07-02             25                               0
# 6050019             2022-07-26             29                               0
# 6052975             2022-07-30             26                               0
# 6054068             2022-06-28             29                               0
# 6072873             2022-08-20             26                               0
# 6083661             2022-09-01             26                               0
# 6086926             2022-09-06             21                               0
# 6097232             2022-09-17             26                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5826137             2021-10-04                        0                  0.0
# 5965183             2022-04-11                        0                  0.0
# 6009803             2022-06-08                        0                  0.0
# 6045709             2022-07-26                        0                  0.0
# 6046792             2022-07-27                        0                  0.0
# 6050019             2022-08-01                        0                  0.0
# 6052975             2022-08-03                        0                  0.0
# 6054068             2022-08-04                        0                  0.0
# 6072873             2022-08-29                        0                  0.0
# 6083661             2022-09-13                        0                  0.0
# 6086926             2022-09-16                        0                  0.0
# 6097232             2022-09-29                        0                  0.0
#
#                   Birth Year    C-2 Date C-3 Date  \
# Claim Identifier
# 5826137                    0  2021-10-02      NaT
# 5965183                 1999  2022-04-09      NaT
# 6009803                 1999  2022-06-08      NaT
# 6045709                 1993  2022-07-26      NaT
# 6046792                 1996  2022-07-27      NaT
# 6050019                 1992  2022-07-30      NaT
# 6052975                 1996  2022-08-03      NaT
# 6054068                 1992  2022-08-04      NaT
# 6072873                 1995  2022-08-27      NaT
# 6083661                 1995  2022-09-13      NaT
# 6086926                 2001  2022-09-16      NaT
# 6097232                 1996  2022-09-29      NaT
#
#                                    Carrier Name  ...  \
# Claim Identifier                                 ...
# 5826137             TRI-STATE INSURANCE COMPANY  ...
# 5965183           TRI-STATE INS CO OF MINNESOTA  ...
# 6009803             TRI-STATE INSURANCE COMPANY  ...
# 6045709             TRI-STATE INSURANCE COMPANY  ...
# 6046792             TRI-STATE INSURANCE COMPANY  ...
# 6050019           TRI-STATE INS CO OF MINNESOTA  ...
# 6052975             TRI-STATE INSURANCE COMPANY  ...
# 6054068             TRI-STATE INSURANCE COMPANY  ...
# 6072873             TRI-STATE INSURANCE COMPANY  ...
# 6083661           TRI-STATE INS CO OF MINNESOTA  ...
# 6086926             TRI-STATE INSURANCE COMPANY  ...
# 6097232             TRI-STATE INSURANCE COMPANY  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5826137                               74.0
# 5965183                               97.0
# 6009803                               74.0
# 6045709                               74.0
# 6046792                               74.0
# 6050019                               74.0
# 6052975                               74.0
# 6054068                               97.0
# 6072873                               74.0
# 6083661                               97.0
# 6086926                               97.0
# 6097232                               74.0
#
#                         WCIO Cause of Injury Description  \
# Claim Identifier
# 5826137           FELLOW WORKER, PATIENT OR OTHER PERSON
# 5965183                                REPETITIVE MOTION
# 6009803           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6045709           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6046792           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6050019           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6052975           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6054068                                REPETITIVE MOTION
# 6072873           FELLOW WORKER, PATIENT OR OTHER PERSON
# 6083661                                REPETITIVE MOTION
# 6086926                                REPETITIVE MOTION
# 6097232           FELLOW WORKER, PATIENT OR OTHER PERSON
#
#                  WCIO Nature of Injury Code  \
# Claim Identifier
# 5826137                                52.0
# 5965183                                52.0
# 6009803                                52.0
# 6045709                                52.0
# 6046792                                28.0
# 6050019                                52.0
# 6052975                                52.0
# 6054068                                52.0
# 6072873                                37.0
# 6083661                                52.0
# 6086926                                52.0
# 6097232                                52.0
#
#                   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5826137                              STRAIN OR TEAR                   63.0
# 5965183                              STRAIN OR TEAR                   53.0
# 6009803                              STRAIN OR TEAR                   24.0
# 6045709                              STRAIN OR TEAR                   54.0
# 6046792                                    FRACTURE                   36.0
# 6050019                              STRAIN OR TEAR                   52.0
# 6052975                              STRAIN OR TEAR                   42.0
# 6054068                              STRAIN OR TEAR                   52.0
# 6072873                                INFLAMMATION                   58.0
# 6083661                              STRAIN OR TEAR                   56.0
# 6086926                              STRAIN OR TEAR                   53.0
# 6097232                              STRAIN OR TEAR                   52.0
#
#                            WCIO Part Of Body Description Zip Code  \
# Claim Identifier
# 5826137           LUMBAR & OR SACRAL VERTEBRAE (VERTEBRA    V6B2M
# 5965183                                             KNEE    V6B2M
# 6009803                                           LARYNX    V6B2M
# 6045709                                        LOWER LEG    V6B2M
# 6046792                                        FINGER(S)    V6B2M
# 6050019                                        UPPER LEG    V6B2M
# 6052975                                  LOWER BACK AREA    V6B2M
# 6054068                                        UPPER LEG    V6B2M
# 6072873                                        GREAT TOE    V6B2M
# 6083661                                             FOOT    V6B2M
# 6086926                                             KNEE    V6B2M
# 6097232                                        UPPER LEG    V6B2M
#
#                   Agreement Reached      WCB Decision Number of Dependents
# Claim Identifier
# 5826137                         0.0  Not Work Related                    4
# 5965183                         0.0  Not Work Related                    1
# 6009803                         0.0  Not Work Related                    2
# 6045709                         0.0  Not Work Related                    3
# 6046792                         0.0  Not Work Related                    1
# 6050019                         0.0  Not Work Related                    6
# 6052975                         0.0  Not Work Related                    0
# 6054068                         0.0  Not Work Related                    1
# 6072873                         0.0  Not Work Related                    3
# 6083661                         0.0  Not Work Related                    4
# 6086926                         0.0  Not Work Related                    3
# 6097232                         0.0  Not Work Related                    5
#
# [12 rows x 30 columns]

# %% [markdown]
# M3K2B --> 20 // "TRI-STATE INSURANCE COMPANY", todas com o mesmo average weekly wage, há uma maioria associada ao upper leg
#
# M3K2C --> 13 // "TRI-STATE INSURANCE COMPANY", uma grande maioria com "STRAIN OR TEAR", praticamente todos com 0 no average weekly wage
#
# H1V2L --> 15 linhas, com um average igual a 0, associadas a "TRI-STATE INS CO OF MINNESOTA" e "TRI-STATE INSURANCE COMPANY"
#
# H1V3S --> 23 linhas, average == 0, associadas a "TRI-STATE INSURANCE COMPANY" e "TRI-STATE INS CO OF MINNESOTA",
#
# V6T1Z --> 30 linhas, average de 0, "TRI-STATE INS CO OF MINNESOTA", "TRI-STATE INSURANCE COMPANY",
#
# V6B2M --> 11 linhas, average de 0, "TRI-STATE INS CO OF MINNESOTA", "TRI-STATE INSURANCE COMPANY"

# %% [markdown]
# ## Minimum Age

# %% [markdown]
# - The minimum age should be 18, as it is the legal age to start working.

# %%
df_inconsistencies[df_inconsistencies['Age at Injury'] < 18]
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5393971             2019-06-26              0                               0
# 5394788             2019-12-23             16                               0
# 5394093             2019-12-28              0                               0
# 5394068                    NaT              0                               0
# 5393794                    NaT              0                               0
# ...                        ...            ...                             ...
# 6164933                    NaT              0                               0
# 6164795             2022-08-20             17                               0
# 6164931                    NaT              0                               0
# 6164433             2022-12-13              0                               0
# 6165637             2022-11-19              0                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393971             2020-01-02                        0                  0.0
# 5394788             2020-01-02                        0                  0.0
# 5394093             2020-01-02                        0                  0.0
# 5394068             2020-01-02                        1                  0.0
# 5393794             2020-01-02                        1                  0.0
# ...                        ...                      ...                  ...
# 6164933             2022-12-30                        1                  0.0
# 6164795             2022-12-30                        0                  0.0
# 6164931             2022-12-30                        1                  0.0
# 6164433             2022-12-30                        0                  0.0
# 6165637             2022-12-30                        0                  0.0
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 5393971                    0         NaT         NaT
# 5394788                 2003  2020-01-02         NaT
# 5394093                    0  2019-12-30         NaT
# 5394068                 1959         NaT  2019-12-23
# 5393794                 1984         NaT  2019-12-27
# ...                      ...         ...         ...
# 6164933                 1972  2023-01-20  2022-12-22
# 6164795                 2005  2022-12-30         NaT
# 6164931                 1957         NaT  2022-12-27
# 6164433                 1903  2022-12-30         NaT
# 6165637                    0  2022-12-30         NaT
#
#                                     Carrier Name  ...  \
# Claim Identifier                                  ...
# 5393971             AMERICAN ZURICH INSURANCE CO  ...
# 5394788              PENNSYLVANIA MANUFACTURERS'  ...
# 5394093                   TWIN CITY FIRE INS CO.  ...
# 5394068           STARR INDEMNITY & LIABILITY CO  ...
# 5393794                        LM INSURANCE CORP  ...
# ...                                          ...  ...
# 6164933                        LM INSURANCE CORP  ...
# 6164795                SEQUOIA INSURANCE COMPANY  ...
# 6164931             CNY OTHER THAN ED, HED WATER  ...
# 6164433           SECURITY NATIONAL INSURANCE CO  ...
# 6165637            NEW YORK BLACK CAR OPERATORS'  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393971                                NaN
# 5394788                               32.0
# 5394093                               55.0
# 5394068                                NaN
# 5393794                                NaN
# ...                                    ...
# 6164933                               60.0
# 6164795                               60.0
# 6164931                                NaN
# 6164433                               17.0
# 6165637                               45.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393971                                                   NaN
# 5394788                                        ON ICE OR SNOW
# 5394093                                   HOLDING OR CARRYING
# 5394068                                                   NaN
# 5393794                                                   NaN
# ...                                                       ...
# 6164933                              STRAIN OR INJURY BY, NOC
# 6164795                              STRAIN OR INJURY BY, NOC
# 6164931                                                   NaN
# 6164433                        OBJECT BEING LIFTED OR HANDLED
# 6165637           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
#
#                  WCIO Nature of Injury Code  \
# Claim Identifier
# 5393971                                 NaN
# 5394788                                40.0
# 5394093                                52.0
# 5394068                                 NaN
# 5393794                                 NaN
# ...                                     ...
# 6164933                                78.0
# 6164795                                49.0
# 6164931                                 NaN
# 6164433                                43.0
# 6165637                                 1.0
#
#                   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5393971                                         NaN                    NaN
# 5394788                                  LACERATION                   14.0
# 5394093                              STRAIN OR TEAR                   61.0
# 5394068                                         NaN                    NaN
# 5393794                                         NaN                    NaN
# ...                                             ...                    ...
# 6164933                      CARPAL TUNNEL SYNDROME                   39.0
# 6164795                              SPRAIN OR TEAR                   55.0
# 6164931                                         NaN                    NaN
# 6164433                                    PUNCTURE                   36.0
# 6165637                          NO PHYSICAL INJURY                   66.0
#
#                  WCIO Part Of Body Description Zip Code  Agreement Reached  \
# Claim Identifier
# 5393971                                    NaN    11801                0.0
# 5394788                                 EYE(S)    11776                0.0
# 5394093                ABDOMEN INCLUDING GROIN      NaN                0.0
# 5394068                                    NaN      NaN                0.0
# 5393794                                    NaN    13212                0.0
# ...                                        ...      ...                ...
# 6164933                    WRIST (S) & HAND(S)    11221                0.0
# 6164795                                  ANKLE    12149                0.0
# 6164931                                    NaN    11221                0.0
# 6164433                              FINGER(S)    12309                0.0
# 6165637                     NO PHYSICAL INJURY    07666                0.0
#
#                       WCB Decision Number of Dependents
# Claim Identifier
# 5393971           Not Work Related                    1
# 5394788           Not Work Related                    4
# 5394093           Not Work Related                    5
# 5394068           Not Work Related                    6
# 5393794           Not Work Related                    4
# ...                            ...                  ...
# 6164933           Not Work Related                    6
# 6164795           Not Work Related                    5
# 6164931           Not Work Related                    0
# 6164433           Not Work Related                    1
# 6165637           Not Work Related                    6
#
# [7201 rows x 30 columns]

# %% [markdown]
# **Conclusion:** We have 7201 people who are below 18 years old. We can drop these rows because they do not make sense in our context.

# %%
df_inconsistencies = df_inconsistencies[~((df_inconsistencies['Age at Injury'] < 18))]

# %%
# Check what is the mininum age 
df_inconsistencies['Age at Injury'].min()
# Out:
# 18

# %% [markdown]
# **Conclusion:** The minimum age is 18, which is the legal age to start working. Values below 18 were correctly dropped.

# %%
#def calculate_age_at_accident(row):
    #start_date = row['Birth Year']
    #end_date = row['Accident Date']
    
    # Ensure the dates are in datetime format (if not already)
    #if isinstance(start_date, datetime) and isinstance(end_date, datetime):
        
        # Calculate the relativedelta between the two dates
        #delta = relativedelta.relativedelta(end_date, start_date)
        
        # Return the difference in years
        #return delta.years
    #else:
        #return None

# %%
#df_inconsistencies['Age at Accident'] = df_inconsistencies.apply(
    #lambda row: calculate_age_at_accident(row), axis=1
#)

# %%
# Checking the inconsistencies 
#df_inconsistencies[df_inconsistencies['Age at Injury'] != df_inconsistencies['Age at Accident']]

# %% [markdown]
# **Conclusion:** The 'Age at Injury' is the age when the injury occurred, so it should be equal to the difference between the 'Birth Year' and the 'Accident Date'. There are 12,978 values that do not meet this condition (probably because the dates have not been properly set yet, but once corrected, the values should be accurate)

# %% [markdown]
# ## 'Carrier Name' & 'Carrier Type'

# %%
carrier_names = df_inconsistencies['Carrier Name'].unique().tolist()
carrier_names.sort()
carrier_names
# Out:
# ['*** CARRIER UNDETERMINED ***',
#  'A I U INSURANCE COMPANY',
#  'ABF FREIGHT SYSTEM, INC.',
#  'ABF FREIGHT SYSTEMS INC DEL',
#  'ACADIA INSURANCE COMPANY',
#  'ACCIDENT FUND GENERAL',
#  'ACCIDENT FUND GENERAL INS CO',
#  'ACCIDENT FUND INSURANCE',
#  'ACCIDENT FUND INSURANCE CO',
#  'ACCIDENT FUND NATIONAL INS CO',
#  'ACCIDENT FUND NATONAL INS CO',
#  'ACCREDITED SURETY AND CASUALTY',
#  'ACE AMERICAN INSURANCE CO',
#  'ACE AMERICAN INSURANCE CO.',
#  'ACE FIRE UNDERWRITERS',
#  'ACE FIRE UNDERWRITERS INS',
#  'ACE PROPERTY & CASUALTY INS CO',
#  'ACE PROPERTY AND CASUALTY',
#  'ACIG INSURANCE COMPANY',
#  'ADDISON CENTRAL SCHOOL DISTRIC',
#  'ADDISON CSD',
#  'ADIRONDACK CENTRAL SCHOOL',
#  'ADIRONDACK CSD',
#  'ADMIRAL INDEMNITY COMPANY',
#  'ADMIRAL INDEMNITY CORP.',
#  'AIG PROPERTY CASUALTY CO.',
#  'AIG PROPERTY CASUALTY COMPANY',
#  'AIU INSURANCE CO',
#  'AKRON CENTRAL SCHOOL DISTRICT',
#  'AKRON CSD',
#  'ALBANY CITY OF',
#  'ALBANY CITY SCHOOL DISTRICT',
#  'ALBANY, COUNTY OF',
#  'ALBION CENTRAL SCHOOL DIST',
#  'ALBION CENTRAL SCHOOL DISTRICT',
#  'ALDEN C.S.D.',
#  'ALDEN CENTRAL SCHOOL DIST',
#  'ALEXANDRIA CENTRAL SCHOOL DIST',
#  'ALFRED-ALMOND CENTRAL SCHOOL',
#  'ALFRED-ALMOND CSD',
#  'ALL AMERICA INSURANCE CO',
#  'ALLEGANY COUNTY MUTUAL',
#  'ALLEGANY-LIMESTONE',
#  'ALLEGANY-LIMESTONE CSD',
#  'ALLIANCE NATIONAL INS CO',
#  'ALLIANCE NATIONAL INSURANCE CO',
#  'ALLIANZ GLOBAL RISKS US',
#  'ALLIED EASTERN INDEMNITY CO',
#  'ALLIED PROPERTY & CASUALTY',
#  'ALLIED PROPERTY AND CASUALTY',
#  'ALLMERICA FIN BENEFIT INS CO',
#  'ALLMERICA FINANCIAL ALLIANCE',
#  'ALLMERICA FINANCIAL BENEFIT',
#  'ALLSTATE INSURANCE COMPANY',
#  'ALTMAR-PARISH-WILLIAMSTOWN CSD',
#  'AMAGANSETT UFSD',
#  'AMCO INSURANCE COMPANY',
#  'AMERICAN AUTOMOBILE INS CO',
#  'AMERICAN AUTOMOBILE INS. CO.',
#  'AMERICAN CASUALTY CO',
#  'AMERICAN CASUALTY CO OF',
#  'AMERICAN FIRE & CASUALTY CO',
#  'AMERICAN FIRE & CASUALTY CO.',
#  'AMERICAN GUAR & LIAB INS CO',
#  'AMERICAN GUARANTEE & LIABILITY',
#  'AMERICAN HOME ASSURANCE CO',
#  'AMERICAN INSURANCE CO',
#  'AMERICAN MFG. MUT. INS. CO.',
#  'AMERICAN MOTORISTS INS CO',
#  'AMERICAN PROTECTION INS CO.',
#  'AMERICAN ZURICH INSURANCE CO',
#  'AMERISURE INS CO',
#  'AMERISURE INSURANCE COMPANY',
#  'AMERISURE MUTUAL INSURANCE CO',
#  'AMGUARD INSURANCE COMPANY',
#  'AMHERST C.S.D',
#  'AMHERST CENTRAL SCHOOL DIST',
#  'AMITYVILLE UFSD',
#  'AMITYVILLE UNION FREE',
#  'AMTRUST INS CO OF KANSAS INC',
#  'AMTRUST INSURANCE COMPANY',
#  'AMTRUST INSURANCE COMPANY OF',
#  'ANDES CENTRAL SCHOOL',
#  'ANDES CENTRAL SCHOOL DISTRICT',
#  'ANDOVER CENTRAL SCHOOL',
#  'ARCH INDEMNITY INSURANCE CO',
#  'ARCH INDEMNITY INSURANCE CO.',
#  'ARCH INSURANCE CO',
#  'ARCH INSURANCE COMPANY',
#  'ARDSLEY UFSD',
#  'ARDSLEY UNION FREE SCHL DIST',
#  'ARGONAUT INSURANCE COMPANY',
#  'ARGONAUT-MIDWEST INS CO',
#  'ARGONAUT-MIDWEST INS, CO',
#  'ARGYLE CENTRAL SCHOOL DIST',
#  'ARI INSURANCE COMPANY',
#  'ARKPORT CENTRAL SCHOOL',
#  'ARLINGTON CENTRAL',
#  'ARLINGTON CSD',
#  'ARNOT OGDEN MEDICAL CENTER',
#  'ARNOT-OGDEN MEDICAL CTR.',
#  'ARROWOOD INDEMNITY CO',
#  'ARROWOOD INDEMNITY COMPANY',
#  'ASCENSION HEALTH ALLIANCE',
#  'ASPIRE OF WESTERN NEW YORK,INC',
#  'ASPIRE OF WESTERN NY INC.',
#  'ASSURANCE COMPANY OF AMERICA',
#  'ATLANTIC MUTUAL INSURANCE CO.',
#  'ATLANTIC SPECIALTY INS CO',
#  'ATLANTIC SPECIALTY INS. CO.',
#  'AU SABLE VALLEY CENTRAL',
#  'AUBURN ENLARGED CITY SCH DIST',
#  'AUBURN ENLARGED CITY SCHOOL',
#  'AURUBIS BUFFALO, INC.',
#  'AUSABLE VALLEY CSD',
#  'AVERILL PARK CENTRAL SCH DIST',
#  'AVERILL PARK CENTRAL SCHL DIST',
#  'AVOCA CENTRAL SCHOOL DIST',
#  'AVOCA CENTRAL SCHOOL DISTRICT',
#  'AVON CENTRAL SCHOOL DISTRICT',
#  'BABYLON UFSD',
#  'BABYLON UNION FREE SCHOOL DIST',
#  'BAINBRIDGE-GUILFORD',
#  'BAINBRIDGE-GUILFORD CSD',
#  'BALDSWINVILLE SCHOOL DISTRICT',
#  'BALDWIN UFSD',
#  'BALDWIN UNION FREE SCH DIST',
#  'BALDWINSVILLE SCHOOL DISTRICT',
#  'BALL CORP',
#  'BALL CORPORATION',
#  'BALLSTON SPA CENTRAL',
#  'BALLSTON SPA CSD',
#  'BANKERS STANDARD INS CO',
#  'BANKERS STANDARD INS. CO.',
#  'BARKER CENTRAL SCHOOL DISTRICT',
#  'BARKER CSD',
#  'BATH & BODY WORKS, INC',
#  'BATH & BODY WORKS, INC.',
#  'BATH CENTRAL SCHOOL',
#  'BAY SHORE PUBLIC SCHOOL',
#  'BAY SHORE PUBLIC SCHOOL UFSD',
#  'BAYPORT-BLUE POINT UFSD',
#  'BAYPORT-BLUE POINT UNION',
#  'BEACON CITY SCHOOL DISTRICT',
#  'BEAVER RIVER CENTRAL',
#  'BEAVER RIVER CSD',
#  'BEDFORD CENTRAL SCHOOL DIST',
#  'BEDFORD CSD',
#  'BEDIVERE INSURANCE COMPANY',
#  'BEEKMANTOWN CSD',
#  'BELFAST CENTRAL SCHOOL DIST',
#  'BELLEVILLE HENDERSON CENTRAL',
#  'BELLMORE MERRICK CENTRAL',
#  'BELLMORE/MERRICK CHSD',
#  'BERKLEY CASUALTY COMPANY',
#  'BERKLEY NATIONAL INSURANCE CO',
#  'BERKLEY NATIONAL INSURANCE CO.',
#  'BERKLEY REGIONAL INS COMPANY',
#  'BERKLEY REGIONAL INSURANCE CO.',
#  'BERKSHIRE HATHAWAY DIRECT',
#  'BERKSHIRE HATHAWAY HOMESTATE',
#  'BERKSHIRE HATHAWAY HOMESTEAD',
#  'BERLIN CENTRAL SCHOOL DIST',
#  'BERLIN CENTRAL SCHOOL DISTRICT',
#  'BETHLEHEM CENTRAL SCH DIST',
#  'BETHLEHEM CSD',
#  'BETHLEHEM STEEL CORPORATION',
#  'BETHPAGE UFSD',
#  'BETHPAGE UNION FREE',
#  'BITCO GENERAL INSURANCE',
#  "BJ'S WHOLESALE CLUB INC",
#  "BJ'S WHOLESALE CLUB, INC.",
#  'BLIND BROOK - RYE UNION FREE',
#  'BLIND BROOK-RYE UFSD',
#  'BOARD OF COOPERATIVE',
#  'BOARD OF COOPERATIVE EDUC',
#  'BOARD OF EDUCATION CNY',
#  'BOARD OF HIGHER ED CNY',
#  'BOARD OF HIGHER EDUCATION CNY',
#  'BOCES #1',
#  'BOCES CLINTON, ESSEX, WARREN &',
#  'BOCES DISTRICT OF ORANGE &',
#  'BOCES DUTCHESS COUNTY',
#  'BOCES ERIE NO.1, 1ST SUPR DIST',
#  'BOCES FIRST SUPERVISORY',
#  'BOCES FRANKLIN-ESSEX-HAMILTON',
#  'BOCES LIVINGSTON-STEUBEN-',
#  'BOCES MONROE #2',
#  'BOCES ORLEANS-NIAGARA',
#  'BOCES OSWEGO COUNTY',
#  'BOCES PUTNAM-WESTCHESTER',
#  'BOCES PUTNAM-WESTCHESTER CTIES',
#  'BOCES ROCKLAND COUNTY',
#  'BOCES SOLE SUPERVISORY DIST',
#  'BOCES SOLE SUPERVISORY OF',
#  'BOCES SOUTHERN WESTCHESTER',
#  'BOCES ST LAWRENCE-LEWIS',
#  'BOCES ST. LAWRENCE-LEWIS',
#  'BOCES SUFFOLK - 3RD SUP DIST',
#  'BOCES WASHINGTON WARREN',
#  'BOCES-WASHINGTON-WARREN',
#  'BOLIVAR-RICHBURG CENTRAL',
#  'BOLIVAR-RICHBURG CSD',
#  'BOLTON CENTRAL SCHOOL DISTRICT',
#  'BON SECOURS CHARITY HEALTH',
#  'BON SECOURS CHARITY HLTH SYS',
#  'BOQUET VALLEY CSD',
#  'BRADFORD CENTRAL SCHOOL',
#  'BRADFORD CENTRAL SCHOOL DIST',
#  'BRASHER FALLS CSD',
#  'BRENTWOOD UFSD',
#  'BRENTWOOD UNION FREE',
#  'BREWSTER CENTRAL SCHOOL DIST',
#  'BREWSTER CSD',
#  'BRIARCLIFF MANOR UFSD',
#  'BRIARCLIFF MANOR UNION FREE',
#  'BRIDGEHAMPTON UFSD',
#  'BRIDGEHAMPTON UNION FREE',
#  'BRIGGS & STRATTON CORPORATION',
#  'BRIGHTON CENTRAL SCHOOL DIST',
#  'BROCKPORT CENTRAL',
#  'BROCKPORT CSD',
#  'BROCKPORT, VILLAGE OF',
#  'BRONXVILLE UNION FREE SCHOOL',
#  'BROOKDALE HOSPITAL MED CTR',
#  'BROOKDALE HOSPITAL MEDICAL CTR',
#  'BROOKFIELD CENTRAL SCHOOL',
#  'BROOKFIELD CSD',
#  'BROOKHAVEN COMESWOGUE UFSD',
#  'BROOKHAVEN COMSEWEGUE',
#  'BROOKHAVEN, TOWN OF',
#  'BROOKLYN BUREAU OF COMMUNITY',
#  'BROOME COUNTY SELF INS PLAN',
#  'BROOME COUNTY SELF-INS. PLAN',
#  'BROOME-DELAWARE-TIOGA BOCES',
#  'BROTHERHOOD MUTUAL INS CO',
#  'BROTHERHOOD MUTUAL INS. CO.',
#  'BRUNSWICK CENTRAL',
#  'BRUNSWICK CSD',
#  'BRUSHTON - MOIRA CSD',
#  'BUFFALO BOARD OF EDUCATION',
#  'BUFFALO SEWER AUTHORITY',
#  'BUFFALO, CITY OF',
#  'BURNT HILLS BALLSTON LAKE CSD',
#  'BURNT HILLS-BALLSTON LAKE',
#  'BUSH INDUSTRIES INC',
#  'BYRAM HILLS CENTRAL',
#  'BYRAM HILLS CSD',
#  'CAIRO-DURHAM CSD',
#  'CALEDONIA MUMFORD CENTRAL',
#  'CALEDONIA MUMFORD CSD',
#  'CALIFORNIA INSURANCE COMPANY',
#  'CAMBRIDGE CENTRAL SCHOOL',
#  'CAMBRIDGE CSD',
#  'CAMPBELL SAVONA CENTRAL SCHOOL',
#  'CAMPBELL-SAVONA CSD',
#  'CANANDAIGUA CITY SCHOOL DIST',
#  'CANANDAIGUA CSD',
#  'CANASERAGA CENTRAL SCHOOL',
#  'CANDOR CENTRAL SCHOOL DIST',
#  'CANDOR CSD',
#  'CANISTEO CENTRAL SCHOOL DIST',
#  'CANISTEO-GREENWOOD C.S.D.',
#  'CANTON CENTRAL SCHOOL DIST',
#  'CANTON CENTRAL SCHOOL DISTRICT',
#  'CAPITAL DIST TRANS AUTHORITY',
#  'CAPITAL DISTRICT TRANS AUTH',
#  'CARILLON NURSING & REHAB CTR.',
#  'CARILLON NURSING AND',
#  'CARLE PLACE UFSD',
#  'CARLE PLACE UNION FREE',
#  'CARMEL CENTRAL SCHOOL DIST',
#  'CARMEL CENTRAL SCHOOL DISTRICT',
#  'CAROLINA CASUALTY INS CO',
#  'CAROLINA CASUALTY INSURANCE CO',
#  'CARTHAGE C.S.D.',
#  'CARTHAGE CENTRAL SCHOOL DIST',
#  'CASTLEPOINT NATIONAL INS CO',
#  'CATSKILL CENTRAL',
#  'CATSKILL CSD',
#  'CATTARAUGUS ALLEGANY ERIE',
#  'CATTARAUGUS COUNTY',
#  'CATTARAUGUS COUNTY SI PLAN',
#  'CATTARAUGUS-LITTLE VALLEY',
#  'CATTARAUGUS-LITTLE VALLEY CSD',
#  'CATTARAUGUS/ALLEGANY/ERIE',
#  'CAYUGA MEDICAL CENTER',
#  'CAYUGA MEDICAL CENTER AT',
#  'CAZENOVIA CENTRAL SCH DIST',
#  'CAZENOVIA CSD',
#  'CBS CORPORATION',
#  'CENTRAL ISLIP UFSD',
#  'CENTRAL ISLIP UNION FREE',
#  'CENTRAL MUTUAL INSURANCE CO',
#  'CENTRAL SQUARE CENTRAL SCHOOLS',
#  'CERITY INSURANCE COMPANY',
#  'CH ENERGY GROUP, INC.',
#  'CHAMPLAIN VALLEY PHYSICIANS',
#  'CHAPPAQUA CENTRAL SCHL DIST',
#  'CHAPPAQUA CSD',
#  'CHARLOTTE VALLEY CENTRAL SCH',
#  'CHARLOTTE VALLEY CENTRAL SD',
#  'CHARTER OAK FIRE INS CO',
#  'CHATEAUGAY CENTRAL',
#  'CHATEAUGAY CSD',
#  'CHATHAM CENTRAL SCHOOL DISTRIC',
#  'CHATHAM CSD',
#  'CHAUTAUQUA CNTY SELF-INS FND',
#  'CHAUTAUQUA COUNTY',
#  'CHAZY CENTRAL SCHOOL DIST',
#  'CHAZY CENTRAL SCHOOL DISTRICT',
#  'CHEEKTOWAGA CENTRAL SCHOOL DIS',
#  'CHEEKTOWAGA CSD',
#  'CHEEKTOWAGA MARYVALE UFSD',
#  'CHEEKTOWAGA-SLOAN U.F.S.D.',
#  'CHEEKTOWAGA-SLOAN UNION FREE',
#  'CHEETOWAGA-SLOAN UNION FREE',
#  'CHEMUNG COUNTY SELF-INS. PLAN',
#  'CHENANGO VALLEY CENTRAL',
#  'CHEROKEE INSURANCE COMPANY',
#  'CHERRY VALLEY SPRINGFIELD',
#  'CHERRY VALLEY SPRINGFIELD CSD',
#  'CHESTER UFSD',
#  'CHESTER UNION FREE',
#  'CHILD & FAMILY SERVICES',
#  'CHILD AND FAMILY SERVICES OF',
#  'CHILI, TOWN OF',
#  'CHIRON INSURANCE COMPANY',
#  'CHITTENANGO CENTRAL SCHOOL',
#  'CHITTENANGO CSD',
#  'CHUBB INDEMNITY COMPANY',
#  'CHUBB INDEMNITY INS CO',
#  'CHUBB NATIONAL INS COMPANY',
#  'CHUBB NATIONAL INSURANCE CO.',
#  'CHURCH MUTUAL INSURANCE',
#  'CHURCH MUTUAL INSURANCE CO',
#  'CHURCHVILLE-CHILI CSD',
#  'CINCINNATI CASUALTY COMPANY',
#  'CINCINNATI INDEMNITY COMPANY',
#  'CINCINNATI INSURANCE CO',
#  'CINCINNATI INSURANCE CO.',
#  'CINCINNATTI CASUALTY COMPANY',
#  'CINCINNATUS CENTRAL SCH DIST',
#  'CINCINNATUS CSD',
#  'CITIZENS INS CO OF AMERICA',
#  'CITIZENS INS. CO. OF AMERICA',
#  'CITY OF ALBANY NEW YORK',
#  'CITY OF ALBANY SCHOOL DISTRICT',
#  'CITY OF BATAVIA',
#  'CITY OF BINGHAMTON',
#  'CITY OF BUFFALO',
#  'CITY OF BUFFALO BOARD OF',
#  'CITY OF COHOES',
#  'CITY OF ELMIRA',
#  'CITY OF GLEN COVE',
#  'CITY OF ITHACA',
#  'CITY OF LACKAWANNA',
#  'CITY OF LOCKPORT',
#  'CITY OF MIDDLETOWN',
#  'CITY OF MOUNT VERNON',
#  'CITY OF NEW ROCHELLE',
#  'CITY OF NIAGARA FALLS',
#  'CITY OF NORTH TONAWANDA',
#  'CITY OF PEEKSKILL',
#  'CITY OF PORT JERVIS',
#  'CITY OF POUGHKEEPSIE',
#  'CITY OF ROCHESTER',
#  'CITY OF ROCHESTER BD OF ED',
#  'CITY OF ROME',
#  'CITY OF SCHENECTADY',
#  'CITY OF SYRACUSE',
#  'CITY OF TROY',
#  'CITY OF WATERTOWN',
#  'CITY OF WATERVLIET',
#  'CITY OF WHITE PLAINS',
#  'CITY OF YONKERS',
#  'CITY SCHOOL DISTRICT',
#  'CITY SCHOOL DISTRICT OF THE',
#  'CLARENDON NATIONAL INS. CO.',
#  'CLARKSTOWN CENTRAL SCHL DIST',
#  'CLARKSTOWN CSD',
#  'CLEAR SPRING PROPERTY AND',
#  'CLERMONT INSURANCE COMPANY',
#  'CLEVELAND HILL UNION',
#  'CLEVELAND-HILL UFSD',
#  'CLIFFSTAR CORPORATION',
#  'CLIFTON-FINE CSD',
#  'CLINTON COUNTY SELF INS PLAN',
#  'CLINTON CSD',
#  'CLYDE-SAVANNAH CSD',
#  'CNY OTHER THAN E HE WT HHC & H',
#  'CNY OTHER THAN ED, HED WATER',
#  'COHOES CITY OF',
#  'COHOES CITY SCHOOL DISTRICT',
#  'COLD SPRING HARBOR',
#  'COLD SPRING HARBOR CSD',
#  'COLONIE, TOWN OF',
#  'COLTON-PIERREPONT CSD',
#  'COLTON-PIERREPONT CTL SCHOOL',
#  'COLUMBIA COUNTY MUT SELF INS',
#  'COLUMBIA COUNTY MUTUAL',
#  'COLUMBIA UNIVERSITY',
#  'COMMACK UFSD',
#  'COMMACK UNION FREE SCH DIST',
#  'COMMERCE AND INDUSTRY INS CO',
#  'COMMUNITY COLLEGES OF CUNY',
#  'CONNETQUOT CENTRAL SCHOOL',
#  'CONNETQUOT CSD OF ISLIP',
#  'CONSOLIDATED EDISON CO OF NY',
#  'CONSOLIDATED EDISON COMPANY',
#  'CONTINENTAL CASUALTY COMPANY',
#  'CONTINENTAL INDEMNITY COMPANY',
#  'CONTINENTAL INSURANCE CO',
#  'CONTINENTAL WESTERN INS CO',
#  'CONTINENTAL WESTERN INS. CO.',
#  'COOPERSTOWN CENTRAL',
#  'COOPERSTOWN CSD',
#  'COPENHAGEN CENTRAL SCHOOL DIST',
#  'COPIAGUE UFSD',
#  'COPIAGUE UNION FREE',
#  'CORINTH CENTRAL SCHOOL DIST',
#  'CORNELL UNIVERSITY',
#  'CORNING INCORPORATED',
#  'CORNING-PAINTED POST',
#  'CORNING-PAINTED POST AREA',
#  'CORNWALL CENTRAL SCHOOL DIST',
#  'CORNWALL CSD',
#  'CORTLAND CITY SCHOOL DISTRICT',
#  'CORTLAND COUNTY SELF INS',
#  'CORTLAND ENLARGED CITY',
#  'CORTLANDT, TOWN OF',
#  'COSTCO WHOLESALE CORPORATION',
#  'COUNTY OF ALBANY',
#  'COUNTY OF CHEMUNG',
#  'COUNTY OF CLINTON',
#  'COUNTY OF ERIE',
#  'COUNTY OF FULTON WORKERS',
#  'COUNTY OF MONROE',
#  'COUNTY OF MONROE LAW DEPT',
#  'COUNTY OF NASSAU',
#  'COUNTY OF ORANGE',
#  'COUNTY OF PUTNAM',
#  'COUNTY OF ROCKLAND',
#  'COUNTY OF SUFFOLK',
#  'COUNTY OF ULSTER',
#  'COUNTY OF WARREN',
#  'COUNTY OF WESTCHESTER',
#  'COXSACKIE ATHENS',
#  'COXSACKIE-ATHENS CSD',
#  'CRH AMERICAS INC.',
#  'CRH AMERICAS, INC',
#  'CROTON HARMON UFSD',
#  'CROTON HARMON UNION FREE',
#  'CROUSE HEALTH HOSPITAL INC',
#  'CROUSE HEALTH HOSPITAL INC DBA',
#  'CROUSE HOSPITAL',
#  'CRUM & FORSTER INDEMNITY CO',
#  'CRUM & FORSTER INDEMNITY CO.',
#  'CUBA-RUSHFORD CSD',
#  'CUMMINS INC',
#  'CUMMINS, INC',
#  'DANSVILLE CENTRAL SCH DIST',
#  'DANSVILLE CSD',
#  'DE RUYTER CENTRAL',
#  'DE RUYTER CENTRAL SCHOOL DIST',
#  'DEER PARK UFSD',
#  'DEER PARK UNION FREE SCH DST',
#  'DELAWARE COUNTY',
#  'DELAWARE COUNTY SELF-INS. FUND',
#  'DELHAIZE AMERICA, LLC',
#  'DELHI CENTRAL SCHOOL DIST',
#  'DELHI CENTRAL SCHOOL DISTRICT',
#  'DELHI CSD',
#  'DEPARTMENT OF HEALTH CNY',
#  'DEPAUL GROUP INC',
#  'DEPAUL GROUP, INC.',
#  'DEPEW UFSD',
#  'DEPEW UNION FREE',
#  'DEPOSIT CENTRAL SCHOOL DIST',
#  'DEPOSIT CSD',
#  'DEPOSITORS INSURANCE COMPANY',
#  'DERUYTER CENTRAL SCHOOL DIST',
#  'DIOCESE OF BUFFALO',
#  'DISCOVER PROP & CAS INS CO',
#  'DOBBS FERRY UFSD',
#  'DOBBS FERRY UNION FREE',
#  'DOLGEN NEW YORK LLC',
#  'DOLGEN OF NEW YORK LLC',
#  'DOLGENCORP OF NEW YORK, INC.',
#  'DOLLAR GENERAL CORPORATION',
#  'DOVER UFSD',
#  'DOVER UNION FREE SCH DIST',
#  'DPWN HOLDINGS (USA) INC.',
#  'DRESSER INDUSTRIES, INC.',
#  'DRYDEN CENTRAL SCHOOL',
#  'DRYDEN CSD',
#  'DUNDEE CENTRAL SCHOOL DIST',
#  'DUNDEE CSD',
#  'DUTCHESS COUNTY',
#  'DUTCHESS COUNTY BOCES',
#  'DUTCHESS COUNTY SELF-INS PLAN',
#  'DUTCHESS COUNTY SI PLAN',
#  'E I DU PONT DE NEMOURS & CO.',
#  'E ROCKAWAY UNION FREE SCH DT',
#  'E. ROCH UNION FREE SCH. DIST',
#  'E. ROCH. UNION FREE SCH DIST',
#  'EAST BLOOMFIELD CENTRAL',
#  'EAST BLOOMFIELD CENTRAL SCHOOL',
#  'EAST GREENBUSH CENTRAL SCHS',
#  'EAST GREENBUSH CSD',
#  'EAST HAMPTON UFSD',
#  'EAST HAMPTON UNION FREE',
#  'EAST IRONDEQUOIT CENTRAL',
#  'EAST IRONDEQUOIT CSD',
#  'EAST ISLIP SCHOOL DISTRICT',
#  'EAST ISLIP UFSD',
#  'EAST MEADOW UFSD',
#  'EAST MEADOW UNION FREE',
#  'EAST QUOGUE UNION FREE',
#  'EAST QUOQUE UFSD',
#  'EAST RAMAPO CENTRAL SCH DIST',
#  'EAST RAMAPO CSD',
#  'EAST ROCHESTER UNION FREE',
#  'EAST ROCHESTER, VILLAGE OF',
#  'EAST ROCKAWAY UFSD',
#  'EAST SYRACUSE MINOA',
#  'EAST SYRACUSE-MINOA CSD',
#  'EAST WILLISTON UFSD',
#  'EAST WILLISTON UNION FREE',
#  'EASTCHESTER UFSD',
#  'EASTCHESTER UNION FREE',
#  'EASTCHESTER, TOWN OF',
#  'EASTERN ALLIANCE INSUR COMPANY',
#  'EASTGUARD INSURANCE COMPANY',
#  'EASTMAN KODAK CO',
#  'EASTMAN KODAK COMPANY',
#  'EASTPORT/SOUTH MANOR C. S. D.',
#  'EASTPORT/SOUTH MANOR C.S.D.',
#  'EDGEMONT UFSD',
#  'EDMESTON CENTRAL',
#  'EDWARDS-KNOX CENTRAL',
#  'EDWARDS-KNOX CSD',
#  'ELDRED CENTRAL SCHOOL DISTRICT',
#  'ELDRED CSD',
#  'ELECTRIC INSURANCE COMPANY',
#  'ELECTRICAL EMPLOYERS',
#  'ELECTRICAL EMPLOYERS SELF',
#  'ELLENVILLE CENTRAL SCHOOL DIST',
#  'ELLENVILLE CSD',
#  'ELLICOTTVILLE CENTRAL',
#  'ELLICOTTVILLE CENTRAL SCHOOL',
#  'ELMA, TOWN OF',
#  'ELMIRA CITY CENTRAL',
#  'ELMIRA CITY CSD',
#  'ELMIRA HEIGHTS CENTRAL',
#  'ELMIRA HEIGHTS CSD',
#  'ELMONT UFSD',
#  'ELMONT UNION FREE SCHL DIST',
#  'ELMSFORD UFSD',
#  'ELMSFORD UNION FREE',
#  'ELWOOD UFSD',
#  'ELWOOD UNION FREE',
#  'EMPIRE STATE TRANSPORTATION',
#  'EMPLOYERS',
#  'EMPLOYERS ASSURANCE CO.',
#  'EMPLOYERS ASSURANCE COMPANY',
#  'EMPLOYERS COMPENSATION',
#  'EMPLOYERS COMPENSATION INS CO',
#  'EMPLOYERS INS. CO. OF WAUSAU',
#  'EMPLOYERS INSURANCE COMPANY',
#  'EMPLOYERS MUTUAL CASUALTY CO',
#  'EMPLOYERS PREFERRED',
#  'EMPLOYERS PREFERRED INS. CO.',
#  'EMPLOYERS PREFERRED INSURANCE',
#  'ENLARGED CITY SCHOOL',
#  'ENTERGY NUCLEAR OPERATIONS INC',
#  'ENTERGY NUCLEAR OPERATIONS, IN',
#  'ERIE #2 AREA SCHOOLS SELF-',
#  'ERIE #2 SCHOOLS',
#  'ERIE #2 SCHOOLS SELF-FUNDED',
#  'ERIE COUNTY MEDICAL CENTER',
#  'ERIE COUNTY MEDICAL CENTER COR',
#  'ERIE COUNTY MEDICAL CTR CORP.',
#  'ERIE COUNTY MEDICAL CTR. CORP',
#  'ERIE INS PROPERTY CASUALTY CO',
#  'ERIE INSURANCE CO OF NY',
#  'ERIE INSURANCE COMPANY',
#  'ERIE INSURANCE COMPANY OF',
#  'ERIE INSURANCE PROPERTY',
#  'ERIE, COUNTY OF',
#  'EVEREST DENALI INSURANCE',
#  'EVEREST DENALI INSURANCE CO.',
#  'EVEREST NATIONAL INS COMPANY',
#  'EVEREST NATIONAL INSURANCE CO.',
#  'EVEREST PREMIER INSURANCE',
#  'EVEREST PREMIER INSURANCE CO.',
#  'EXCELSIOR INSURANCE CO',
#  'EXECUTIVE RISK INDEMNITY INC',
#  'EXECUTIVE RISK INDEMNITY INC.',
#  'FABIUS-POMPEY CSD',
#  'FABIUS-POMPY CENTRAL',
#  'FAIRMONT INS. CO. C/O TIG INS.',
#  'FAIRPORT CENTRAL SCHL DIST',
#  'FAIRPORT CSD',
#  'FAIRPORT MUNICIPAL COMMISSION',
#  'FAIRPORT, VILLAGE OF',
#  'FALLSBURG CENTRAL SCHOOL DIST',
#  'FALLSBURG CSD',
#  'FARM FAMILY CASUALTY INS CO',
#  'FARMERS INSURANCE EXCHANGE',
#  'FARMINGTON CASUALTY COMPANY',
#  'FAYETTEVILLE-MANLIUS',
#  'FAYETTEVILLE-MANLIUS CSD',
#  'FDM PREFERRED INSURANCE',
#  'FEDERAL EXPRESS CORPORATION',
#  'FEDERAL INSURANCE COMPANY',
#  'FEDERATED MUTUAL INS CO',
#  'FEDERATED RESERVE INSURANCE',
#  'FEDERATED RURAL ELECTRIC',
#  'FEDERATED RURAL ELECTRIC INS.',
#  'FEDERATED SERVICE INSURANCE CO',
#  'FEDEX FREIGHT, INC.',
#  'FEDEX GROUND PACKAGE SYS.',
#  'FEDEX GROUND PACKAGE SYSTEM IN',
#  'FIDELITY & GUARANTY INS CO',
#  'FILLMORE CENTRAL SCHOOL',
#  'FILLMORE CSD',
#  'FINGER LAKES REGIONAL HEALTH',
#  'FIRE DISTRICTS INSURANCE',
#  'FIRE DISTRICTS OF NEW YORK',
#  'FIRE ISLAND UFSD',
#  "FIREMAN'S FUND INSURANCE CO",
#  'FIREMANS FUND INSURANCE CO',
#  'FIREMANS INSURANCE COMPANY OF',
#  'FIRST CENTRAL INS CO',
#  'FIRST LIBERTY INS CORPORATION',
#  'FIRST LIBERTY INSURANCE CORP.',
#  'FLAGSHIP CITY INSURANCE CO',
#  'FLAGSHIP CITY INSURANCE CO.',
#  'FLORAL PARK, INC. VILLAGE OF',
#  'FLORAL PARK-BELLEROSE',
#  'FLORAL PARK-BELLEROSE SCH DIST',
#  'FLORIDA UFSD',
#  'FLORIDA UNION FREE SCH DIST',
#  'FLORISTS MUTUAL INSURANCE CO',
#  "FLORISTS' MUTUAL INSURANCE CO",
#  'FORD MOTOR CO',
#  'FORD MOTOR COMPANY',
#  'FORT ANN CENTRAL SCH DIST',
#  'FORT ANN CSD',
#  'FORT EDWARD UFSD',
#  'FORT EDWARD UNION',
#  'FRANKLIN CENTRAL SCHOOL DIST.',
#  'FRANKLIN COUNTY SELF INS PLAN',
#  'FRANKLIN COUNTY SELF-INS PLAN',
#  'FRANKLIN SQ UNION FREE',
#  'FRANKLIN SQUARE UFSD',
#  'FRANKLIN-ESSEX-',
#  'FRANKLINVILLE CENTRAL',
#  'FRANKLINVILLE CSD',
#  'FREEPORT UFSD',
#  'FREEPORT UNION FREE SCH DIST',
#  'FREEPORT, VILLAGE OF',
#  'FRIENDSHIP CSD',
#  'FRONTIER CENTRAL SCHOOL',
#  'FRONTIER CENTRAL SCHOOLS',
#  "FULMONT WORKERS'",
#  "FULMONT WORKERS' COMP PLAN",
#  'FULTON BOILER WORKS, INC.',
#  'FULTON CO SELF INS PLAN',
#  'FULTON GROUP N.A., INC.',
#  'GALWAY CENTRAL SCHOOL DIST',
#  'GALWAY CSD',
#  'GANANDA CSD',
#  'GARDEN CITY UFSD',
#  'GARDEN CITY UNION FREE',
#  'GARRISON UFSD',
#  'GARRISON UNION FREE SCH DIST',
#  'GATES CHILI CENTRAL SCH DIST',
#  'GATES VOLUNTEER AMBULANCE',
#  'GATES VOLUNTEER AMBULANCE SVC',
#  'GATES, TOWN OF',
#  'GATES-CHILI CSD',
#  'GENERAL BROWN CENTRAL',
#  'GENERAL BROWN CSD',
#  'GENERAL CASUALTY CO OF WI',
#  'GENERAL CASUALTY COMPANY OF',
#  'GENERAL MOTORS, LLC',
#  'GENESEE COUNTY SELF INS PLAN',
#  'GENESEE COUNTY SELF-INS PLAN',
#  'GENESEE VALLEY CENTRAL',
#  'GENESEE VALLEY CSD',
#  'GENESEE-LIVINGSTON-STEUBEN-',
#  'GENESEO CENTRAL SCHOOL DIST',
#  'GENESEO CSD',
#  'GENESIS INSURANCE COMPANY',
#  'GENEVA CITY SCHOOL DISTRICT',
#  'GEORGE JUNIOR REPUBLIC',
#  'GEORGE JUNIOR REPUBLIC UFSD',
#  'GEORGIA PACIFIC CORPORATION',
#  'GERMANTOWN CEN SCHOOL DIST',
#  'GERMANTOWN CENTRAL',
#  'GILBOA CONESVILLE CSD',
#  'GILBOA-CONESVILLE',
#  'GLEASON WORKS',
#  'GLEN COVE CITY SCHOOL DISTRICT',
#  'GLEN COVE, CITY OF',
#  'GLENS FALLS CITY SCHOOL DIST',
#  'GLENS FALLS COMMON SD',
#  'GLENS FALLS CSD',
#  'GOLUB CORP',
#  'GOLUB CORPORATION',
#  'GORHAM-MIDDLESEX CSD',
#  'GOSHEN CENTRAL SCHOOL DIST',
#  'GOSHEN CENTRAL SCHOOL DISTRICT',
#  'GOUVERNEUR CENTRAL',
#  'GOUVERNEUR CSD',
#  'GRANITE STATE INSURANCE CO',
#  'GRANVILLE CENTRAL',
#  'GRAPHIC ARTS MUTUAL INS CO',
#  'GREAT AMERICAN ALLIANCE INS CO',
#  'GREAT AMERICAN ASSURANCE CO',
#  'GREAT AMERICAN INS CO',
#  'GREAT AMERICAN INS CO OF NY',
#  'GREAT AMERICAN INSURANCE',
#  'GREAT AMERICAN INSURANCE CO.',
#  'GREAT AMERICAN SPIRIT',
#  'GREAT AMERICAN SPIRIT INS. CO',
#  'GREAT ATLANTIC & PACIFIC',
#  'GREAT ATLANTIC & PACIFIC TEA',
#  'GREAT DIVIDE INSURANCE CO.',
#  'GREAT DIVIDE INSURANCE COMPANY',
#  'GREAT NECK UFSD',
#  'GREAT NECK UNION FREE',
#  'GREAT NORTHERN INS CO',
#  'GREAT NORTHERN INSURANCE CO',
#  'GREAT NORTHERN INSURANCE CO.',
#  'GREAT WEST CASUALTY COMPANY',
#  'GREAT WESTERN CASUALTY CO.',
#  'GREATER N Y MUTUAL INS CO',
#  'GREATER NEW YORK MUTUAL',
#  'GREECE CENTRAL SCHOOL DIST',
#  'GREECE CSD',
#  'GREECE, TOWN OF',
#  'GREENBURGH CENTRAL',
#  'GREENBURGH CSD - NO. 7',
#  'GREENE CENTRAL SCHOOL DIST',
#  'GREENE CENTRAL SCHOOL DISTRICT',
#  'GREENE COUNTY',
#  'GREENPORT UFSD',
#  'GREENPORT UNION FREE',
#  'GREENVILLE CENTRAL SCHOOL',
#  'GREENVILLE CSD',
#  'GREENWICH CENTRAL',
#  'GREENWICH CSD',
#  'GREENWICH INSURANCE CO',
#  'GREENWICH INSURANCE COMPANY',
#  'GREENWOOD LAKE UFSD',
#  'GREENWOOD LAKE UNION',
#  'GREIF BROS CORP',
#  'GROTON CENTRAL SCHOOL DIST',
#  'GROTON CSD',
#  'GUARANTEE INSURANCE COMPANY',
#  'GUIDEONE ELITE INSURANCE CO.',
#  'GUIDEONE ELITE INSURANCE COMPA',
#  'GUIDEONE INSURANCE COMPANY',
#  'GUIDEONE MUTUAL INS CO',
#  'GUIDEONE MUTUAL INSURANCE CO',
#  'GUIDEONE SPECIALTY  INSURANCE',
#  'GUIDEONE SPECIALTY MUTUAL',
#  'GUIDEONE SPECIALTY MUTUAL INSU',
#  'GUILDERLAND CSD',
#  'GULF INSURANCE COMPANY',
#  'HADLEY LUZERNE CSD',
#  'HADLEY-LUZERNE CENTRAL SCH',
#  'HALDANE CENTRAL SCHOOL DIST',
#  'HALDANE CSD',
#  'HALF HOLLOW HILLS CSD',
#  'HALF HOLLOW HLS CENT SCL DST',
#  'HAMMOND CENTRAL SCHOOL',
#  'HAMMONDSPORT CENTRAL',
#  'HAMMONDSPORT CSD',
#  'HAMPTON BAYS U F S D',
#  'HAMPTON BAYS UFSD',
#  'HANCOCK CENTRAL SCHOOL DISTRIC',
#  'HANCOCK CSD',
#  'HANNIBAL CENTRAL SCHOOL',
#  'HANNIBAL CSD',
#  'HANOVER AMERICAN INS COMPANY',
#  'HANOVER AMERICAN INSURANCE CO',
#  'HANOVER INSURANCE CO',
#  'HANOVER INSURANCE GROUP',
#  'HARBORFIELDS CENTRAL',
#  'HARBORFIELDS CSD',
#  'HARLEYSVILLE INS CO. OF NY',
#  'HARLEYSVILLE INSURANCE COMPANY',
#  'HARLEYSVILLE PREFERRED INS CO',
#  'HARLEYSVILLE WORCESTER INS CO',
#  'HARRISON CENTRAL SCHOOL DIST',
#  'HARRISON CSD',
#  'HARRISON, TOWN/VILLAGE OF',
#  'HARRISVILLE CENTRAL',
#  'HARRISVILLE CSD',
#  'HARTFORD ACCIDENT & INDEMNITY',
#  'HARTFORD CASUALTY INS CO',
#  'HARTFORD CASUALTY INSURANCE CO',
#  'HARTFORD CENTRAL SCHOOL',
#  'HARTFORD CSD',
#  'HARTFORD FIRE INSURANCE CO',
#  'HARTFORD INS CO OF ILLINOIS',
#  'HARTFORD INS CO OF THE MIDWEST',
#  'HARTFORD INSURANCE COMPANY',
#  'HARTFORD INSURANCE COMPANY OF',
#  'HARTFORD UNDERWRITERS INS CO',
#  'HASTINGS ON HUDSON UNION',
#  'HASTINGS-ON-HUDSON UFSD',
#  'HAUPPAUGE UFSD',
#  'HAUPPAUGE UNION FREE SCH DST',
#  'HDI GLOBAL INSURANCE COMPANY',
#  'HEALTH & HOSPITAL CORP.',
#  'HEALTH & HOSPITALS CORP CNY',
#  'HEALTH & HOSPITALS CORP. CNY',
#  'HEALTHCARE IND TRUST OF NY',
#  'HEALTHCARE OF NY WC TRUST',
#  'HEALTHCARE UNDERWRITERS MUTUAL',
#  'HEALTHSTAR NETWORK INC',
#  'HEALTHSTAR NETWORK INC.',
#  'HEMPSTEAD UFSD',
#  'HEMPSTEAD UNION FREE',
#  'HEMPSTEAD, INC. VILLAGE OF',
#  'HENDRICK HUDSON SCHOOL DIST',
#  'HEREFORD INS. CO. ILDBF',
#  'HEREFORD INSURANCE - ILDBF',
#  'HEREFORD INSURANCE COMPANY',
#  'HERKIMER COUNTY',
#  'HERMON-DEKALB CENTRAL',
#  'HERMON-DEKALB CSD',
#  'HERRICKS UFSD',
#  'HERRICKS UNION FREE',
#  'HEUVELTON CENTRAL',
#  'HEWLETT WOODMERE UFSD',
#  'HEWLETT WOODMERE UNION FREE',
#  'HICKSVILLE UFSD',
#  'HICKSVILLE UNION FREE',
#  'HIGHLAND FALLS-FORT',
#  'HIGHLAND FALLS/FT MONTGOMERY',
#  'HIGHLAND HOSPITAL',
#  'HIGHLAND HOSPITAL OF ROCHESTER',
#  'HIGHVIEW  NATIONAL INSURANCE',
#  'HIGHVIEW NATIONAL INSURANCE',
#  "HILLSIDE CHILDREN'S CENTER",
#  'HILLSIDE FAMILY OF AGENCIES',
#  'HILTON CENTRAL SCHOOL DIST',
#  'HILTON CSD',
#  'HILTON, VILLAGE OF',
#  'HILTON-PARMA FIRE DISTRICT',
#  'HINSDALE CENTRAL SCHOOL',
#  'HOLLAND PATENT CSD',
#  'HOLLEY CENTRAL SCHOOL DIST',
#  'HOLLEY CSD',
#  'HOMELAND INSURANCE CO OF NY',
#  'HOMER CENTRAL SCHOOL DIST',
#  'HOMER CSD',
#  'HONEOYE CENTRAL SCHOOL DIST',
#  'HONEOYE CSD',
#  'HONEOYE FALLS, VILLAGE OF',
#  'HONEOYE FALLS-LIMA CENTRAL',
#  'HONEOYE FALLS-LIMA CSD',
#  'HOOSIC VALLEY CENTRAL SCHOOL',
#  'HOOSIC VALLEY CSD',
#  'HOOSICK FALLS CSD',
#  'HORNELL CITY SCHOOL DISTRICT',
#  'HUDSON CITY SCHOOL DISTRICT',
#  'HUDSON FALLS CENTRAL',
#  'HUDSON FALLS CSD',
#  'HUDSON HEALTH CARE WC GROUP',
#  'HUNTER TANNERSVILLE CSD',
#  'HUNTER-TANNERSVILLE CENTRAL',
#  'HUNTINGTON UFSD',
#  'HUNTINGTON UNION FREE',
#  'HUNTINGTON, TOWN OF',
#  'HYDE PARK CENTRAL SCH DIST',
#  'HYDE PARK CSD',
#  'IBM CORPORATION',
#  'IDEAL MUTUAL INSURANCE CO',
#  'ILLINOIS NATIONAL INS CO',
#  'IMPERIUM INSURANCE COMPANY',
#  'INCORPORATED VILLAGE',
#  'INDEMNITY INS. OF N AMERICA',
#  'INDEMNITY INSURANCE CO OF',
#  'INDIAN LAKE CSD',
#  'INDIAN RIVER CENTRAL',
#  'INDIAN RIVER CENTRAL SCHOOL',
#  'INDIAN RIVER CENTRAL SCHOOL SY',
#  'INFINITY ASSURANCE INS. CO.',
#  'INS CO OF STATE OF PENN',
#  'INSURANCE CO OF GREATER N Y',
#  'INSURANCE CO OF NORTH AMERICA',
#  'INSURANCE COMPANY OF GREATER',
#  'INSURANCE COMPANY OF NORTH',
#  'INSURANCE COMPANY OF THE STATE',
#  'INSURANCE COMPANY OF THE WEST',
#  'INTERNATIONAL HARVESTER CO.',
#  'INTREPID INSURANCE COMPANY',
#  'IRVINGTON UNION FR SCH DIST',
#  'ISLAND PARK UFSD',
#  'ISLAND PARK UNION FREE',
#  'ISLAND TREES UFSD',
#  'ISLAND TREES UNION FREE',
#  'ISLIP UFSD',
#  'ISLIP UNION FREE',
#  'ISLIP, TOWN OF',
#  'ITHACA CITY SCHOOL DISTRICT',
#  'ITHACA, CITY OF',
#  'JAMESTOWN CITY SCHOOL DISTRICT',
#  'JAMESVILLE-DEWITT CENTRAL',
#  'JAMESVILLE-DEWITT CSD',
#  'JASPER-TROUPSBURG CSD',
#  'JEFFERSON CO SELF INSURANCE',
#  'JEFFERSON COUNTY',
#  'JEFFERSON COUNTY SIP',
#  'JEFFERSON CSD',
#  'JEFFERSON LEWIS BOARD OF',
#  'JEFFERSON-LEWIS BOCES',
#  'JERICHO UNION FREE SCHOOL DIST',
#  'JOHNSBURG CENTRAL SCH DIST',
#  'JOHNSBURG CSD',
#  'JORDAN ELBRIDGE CENTRAL',
#  'JORDAN-ELBRIDGE CSD',
#  'KATONAH LEWISBORO SCHOOLS',
#  'KATONAH-LEWISBORO CSD',
#  'KEENE CENTRAL SCHOOL DIST',
#  'KEENE CENTRAL SCHOOL DISTRICT',
#  'KENDALL CSD',
#  'KENMORE-TN.TONAWANDA UFSD',
#  'KENMORE-TOWN OF TONAWANDA',
#  'KESHEQUA CENTRAL SCH DIST',
#  'KESHEQUA CSD',
#  'KEY RISK INSURANCE COMPANY',
#  'KINDERHOOK / ICHABOD CRANE',
#  'KINDERHOOK CSD',
#  'KINGS PARK CENTRAL SCHL DIST',
#  'KINGS PARK CENTRAL SCHOOL DIST',
#  'KIRYAS JOEL VILLAGE UFSD',
#  'KIRYAS JOEL VILLAGE UNION',
#  'KISTNER CONCRETE PRODUCTS INC',
#  'KISTNER CONCRETE PRODUCTS INC.',
#  'KRASDALE FOODS INC',
#  'KRASDALE FOODS, INC.',
#  'L & J G STICKLEY INC',
#  'L & J G STICKLEY, INC.',
#  'L BRANDS INC',
#  'L T V STEEL COMPANY,  INC.',
#  'L. & J.G. STICKLEY, INC.',
#  'LAFARGEVILLE CENTRAL SCHOOL DI',
#  'LAFAYETTE CENTRAL SCH DIST',
#  'LAFAYETTE CENTRAL SCHOOL DIST',
#  'LAKE GEORGE CENTRAL',
#  'LAKE GEORGE CSD',
#  'LAKE GEORGE SCHOOL DISTRICT',
#  'LAKE PLACID CENTRAL SCH DIST',
#  'LAKE PLACID CSD',
#  'LAKELAND CENTRAL SCHOOL',
#  'LAKELAND CSD OF SHRUB OAK',
#  'LANCER INDEMNITY COMPANY',
#  'LANSING CENTRAL SCHOOL DIST',
#  'LANSING CSD',
#  'LANSINGBURGH CENTRAL',
#  'LANSINGBURGH CSD',
#  'LAURENS CENTRAL SCHOOL',
#  'LAURENS CENTRAL SCHOOL DISTRIC',
#  'LAWRENCE UFSD',
#  'LAWRENCE UNION FREE SCH DIST',
#  'LE ROY CENTRAL SCHOOL DISTRICT',
#  'LE ROY CSD',
#  'LEPRINO FOODS CO',
#  'LEPRINO FOODS COMPANY',
#  'LETCHWORTH CENTRAL',
#  'LETCHWORTH CSD',
#  'LEVITTOWN UFSD',
#  'LEVITTOWN UNION FREE',
#  'LEWIS COUNTY SELF INS FUND',
#  'LEWIS COUNTY SELF-INS PLAN',
#  'LIBERTY CENTRAL SCHOOL DIST',
#  'LIBERTY CSD',
#  'LIBERTY INSURANCE CORP.',
#  'LIBERTY INSURANCE CORPORATION',
#  'LIBERTY MUTUAL FIRE INS CO',
#  'LIBERTY MUTUAL INSURANCE CO',
#  'LIFETIME HEALTHCARE, INC.',
#  'LIMITED BRANDS, INC.',
#  'LINCOLN GENERAL INSURANCE CO.',
#  'LINDENHURST UFSD',
#  'LINDENHURST UNION FREE',
#  'LISBON CSD',
#  'LIVERPOOL CENTRAL SCHOOL DIST',
#  'LIVERPOOL CSD',
#  'LIVINGSTON CO SELF INS PLAN',
#  'LIVINGSTON COUNTY',
#  'LIVINGSTON COUNTY SELF INS',
#  ...]

# %% [markdown]
# ## 'First Hearing Date'

# %% [markdown]
# - 90-day period for scheduling the First Hearing Date typically begins from the date the claim is filed with the Workers' Compensation Board.
# - If the case or claim is more complex or if there are delays (e.g., missing documentation or issues with the employer), the actual hearing may take longer to schedule, but 90 days is the standard guideline for the first hearing.

# %%
df_inconsistencies['First Hearing Date']
# Out:
# Claim Identifier
# 5393875           NaT
# 5393091    2020-02-21
# 5393889           NaT
# 5393887           NaT
# 5393863           NaT
#               ...
# 6165265           NaT
# 6165285           NaT
# 6165506           NaT
# 6165339           NaT
# 6165075           NaT
# Name: First Hearing Date, Length: 565276, dtype: object

# %%
# Ensure both columns are in datetime format
df_inconsistencies['First Hearing Date'] = pd.to_datetime(df_inconsistencies['First Hearing Date'])
df_inconsistencies['C-3 Date'] = pd.to_datetime(df_inconsistencies['C-3 Date'])

# Calculate the difference
df_inconsistencies['Diference'] = df_inconsistencies['First Hearing Date'] - df_inconsistencies['C-3 Date']
df_inconsistencies[df_inconsistencies['Diference'].dt.days > 90]
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5393811             2019-12-19             34                               0
# 5394132             2019-12-09             44                               0
# 5393898             2019-12-18             29                               0
# 5394183             2019-12-27             56                               0
# 5394112             2019-11-30             51                               0
# ...                        ...            ...                             ...
# 6164515             2022-12-16             56                               0
# 6165181             2022-12-15             40                               0
# 6164439             2022-12-16             42                               0
# 6165390             2022-10-24             37                               0
# 6164934             2022-12-19             25                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393811             2020-01-01                        1              1682.39
# 5394132             2020-01-01                        1              2115.00
# 5393898             2020-01-01                        0               610.72
# 5394183             2020-01-01                        1               815.20
# 5394112             2020-01-01                        1              1404.89
# ...                        ...                      ...                  ...
# 6164515             2022-12-30                        1              1258.59
# 6165181             2022-12-30                        1               860.38
# 6164439             2022-12-30                        1              1167.93
# 6165390             2022-12-30                        1              2100.00
# 6164934             2022-12-30                        1               600.00
#
#                   Birth Year    C-2 Date   C-3 Date  \
# Claim Identifier
# 5393811                 1985  2020-01-01 2020-01-07
# 5394132                 1975  2020-01-01 2020-01-07
# 5393898                 1990  2020-01-01 2019-12-31
# 5394183                 1963  2019-12-31 2020-01-24
# 5394112                 1968  2019-12-31 2020-01-17
# ...                      ...         ...        ...
# 6164515                 1966  2023-03-08 2022-12-27
# 6165181                 1982  2022-12-30 2023-04-28
# 6164439                 1980  2023-01-05 2022-12-28
# 6165390                 1985  2022-12-27 2022-12-16
# 6164934                 <NA>  2023-03-20 2022-12-27
#
#                                    Carrier Name  ...  \
# Claim Identifier                                 ...
# 5393811                   NYC TRANSIT AUTHORITY  ...
# 5394132                   NYC TRANSIT AUTHORITY  ...
# 5393898           PROPERTY & CASUALTY INSURANCE  ...
# 5394183               INDEMNITY INSURANCE CO OF  ...
# 5394112                       LM INSURANCE CORP  ...
# ...                                         ...  ...
# 6164515            CNY OTHER THAN ED, HED WATER  ...
# 6165181           SYRACUSE CITY SCHOOL DISTRICT  ...
# 6164439             MARRIOTT INTERNATIONAL, INC  ...
# 6165390             STARR INDEMNITY & LIABILITY  ...
# 6164934            AMERICAN ZURICH INSURANCE CO  ...
#
#                   WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 5393811                 OTHER - MISCELLANEOUS, NOC                       49.0
# 5394132                    FALL, SLIP OR TRIP, NOC                       10.0
# 5393898                          REPETITIVE MOTION                       59.0
# 5394183           FROM DIFFERENT LEVEL (ELEVATION)                       49.0
# 5394112                                    LIFTING                       52.0
# ...                                            ...                        ...
# 6164515                 FROM LADDER OR SCAFFOLDING                       49.0
# 6165181                    FALL, SLIP OR TRIP, NOC                       10.0
# 6164439                    FALL, SLIP OR TRIP, NOC                       59.0
# 6165390                              ON SAME LEVEL                       52.0
# 6164934                         MOTOR VEHICLE, NOC                       90.0
#
#                  WCIO Nature of Injury Description  WCIO Part Of Body Code  \
# Claim Identifier
# 5393811                             SPRAIN OR TEAR                    54.0
# 5394132                                  CONTUSION                    53.0
# 5393898           ALL OTHER SPECIFIC INJURIES, NOC                    23.0
# 5394183                             SPRAIN OR TEAR                    34.0
# 5394112                             STRAIN OR TEAR                    42.0
# ...                                            ...                     ...
# 6164515                             SPRAIN OR TEAR                    -9.0
# 6165181                                  CONTUSION                    -9.0
# 6164439           ALL OTHER SPECIFIC INJURIES, NOC                    42.0
# 6165390                             STRAIN OR TEAR                    42.0
# 6164934            MULTIPLE PHYSICAL INJURIES ONLY                    42.0
#
#                  WCIO Part Of Body Description Zip Code Agreement Reached  \
# Claim Identifier
# 5393811                              LOWER LEG    11788               0.0
# 5394132                                   KNEE    10460               0.0
# 5393898                            SPINAL CORD    12116               0.0
# 5394183                                  WRIST    10475               0.0
# 5394112                        LOWER BACK AREA    11420               0.0
# ...                                        ...      ...               ...
# 6164515                               MULTIPLE    10466               0.0
# 6165181                               MULTIPLE    13212               0.0
# 6164439                        LOWER BACK AREA    10465               0.0
# 6165390                        LOWER BACK AREA    11360               0.0
# 6164934                        LOWER BACK AREA    10039               0.0
#
#                       WCB Decision Number of Dependents Diference
# Claim Identifier
# 5393811           Not Work Related                    6  219 days
# 5394132           Not Work Related                    5  653 days
# 5393898           Not Work Related                    1  476 days
# 5394183           Not Work Related                    4  390 days
# 5394112           Not Work Related                    6  122 days
# ...                            ...                  ...       ...
# 6164515           Not Work Related                    6  230 days
# 6165181           Not Work Related                    1  132 days
# 6164439           Not Work Related                    2  159 days
# 6165390           Not Work Related                    4  140 days
# 6164934           Not Work Related                    3  119 days
#
# [81410 rows x 31 columns]

# %% [markdown]
# ## Date Consistency

# %% [markdown]
# - The sequence should be: Accident Date < C-2 Date < C-3 Date <Assembly Date < First Hearing Date

# %%
df_inconsistencies[df_inconsistencies['Accident Date'] > df_inconsistencies['C-2 Date']]
# Out:
#                  Accident Date  Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 5394177             2019-12-24             72                               0
# 5393953             2020-02-26             57                               0
# 5394099             2020-01-23             62                               0
# 5393830             2020-03-01             62                               0
# 5394613             2020-01-27             57                               0
# ...                        ...            ...                             ...
# 6156163             2023-01-26             56                               0
# 6158378             2022-12-27             41                               0
# 6160613             2023-02-07             51                               0
# 6162010             2023-02-02             52                               0
# 6162263             2022-12-28             55                               0
#
#                  Assembly Date  Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5394177             2020-01-01                        1               273.27
# 5393953             2020-01-01                        1              1997.87
# 5394099             2020-01-02                        1              1775.89
# 5393830             2020-01-02                        1              1467.47
# 5394613             2020-01-03                        1              1450.00
# ...                        ...                      ...                  ...
# 6156163             2022-12-16                        1              2191.97
# 6158378             2022-12-20                        1               746.80
# 6160613             2022-12-22                        1              1646.06
# 6162010             2022-12-26                        1               992.39
# 6162263             2022-12-26                        0                 0.00
#
#                   Birth Year    C-2 Date   C-3 Date  \
# Claim Identifier
# 5394177                    0  2019-07-31 2020-01-30
# 5393953                 1962  2019-12-31 2020-01-31
# 5394099                 1957  2020-01-14 2019-12-27
# 5393830                 1957  2020-01-17 2019-12-27
# 5394613                 <NA>  2020-01-15 2019-12-30
# ...                      ...         ...        ...
# 6156163                 1966  2022-12-16        NaT
# 6158378                 1981  2022-12-20 2022-12-20
# 6160613                 1971  2022-12-22 2022-12-02
# 6162010                 1970  2022-12-26        NaT
# 6162263                 1967  2022-12-26        NaT
#
#                                   Carrier Name  ...  \
# Claim Identifier                                ...
# 5394177           AMERICAN ZURICH INSURANCE CO  ...
# 5393953           CNY OTHER THAN ED, HED WATER  ...
# 5394099                  NYC TRANSIT AUTHORITY  ...
# 5393830                   STATE INSURANCE FUND  ...
# 5394613             NEW YORK CITY TRANSIT AUTH  ...
# ...                                        ...  ...
# 6156163                   STATE INSURANCE FUND  ...
# 6158378            AMERICAN GUAR & LIAB INS CO  ...
# 6160613                LIBERTY INSURANCE CORP.  ...
# 6162010           MASSACHUSETTS BAY INS.CO.C/O  ...
# 6162263                   STATE INSURANCE FUND  ...
#
#                  WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 5394177                         REPETITIVE MOTION                       52.0
# 5393953                         REPETITIVE MOTION                       71.0
# 5394099                OTHER - MISCELLANEOUS, NOC                       71.0
# 5393830                           CONTINUAL NOISE                       31.0
# 5394613                OTHER - MISCELLANEOUS, NOC                       31.0
# ...                                           ...                        ...
# 6156163                        PUSHING OR PULLING                       52.0
# 6158378                  STRAIN OR INJURY BY, NOC                       49.0
# 6160613                         REPETITIVE MOTION                       78.0
# 6162010                         REPETITIVE MOTION                       52.0
# 6162263                   FALL, SLIP OR TRIP, NOC                       52.0
#
#                            WCIO Nature of Injury Description  \
# Claim Identifier
# 5394177                                       STRAIN OR TEAR
# 5393953           ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC
# 5394099           ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC
# 5393830                           HEARING LOSS OR IMPAIRMENT
# 5394613                           HEARING LOSS OR IMPAIRMENT
# ...                                                      ...
# 6156163                                       STRAIN OR TEAR
# 6158378                                       SPRAIN OR TEAR
# 6160613                               CARPAL TUNNEL SYNDROME
# 6162010                                       STRAIN OR TEAR
# 6162263                                       STRAIN OR TEAR
#
#                   WCIO Part Of Body Code        WCIO Part Of Body Description  \
# Claim Identifier
# 5394177                             39.0                  WRIST (S) & HAND(S)
# 5393953                             31.0                            UPPER ARM
# 5394099                             90.0  MULTIPLE BODY PARTS (INCLUDING BODY
# 5393830                             13.0                               EAR(S)
# 5394613                             13.0                               EAR(S)
# ...                                  ...                                  ...
# 6156163                             -9.0                             MULTIPLE
# 6158378                             35.0                                 HAND
# 6160613                             35.0                                 HAND
# 6162010                             39.0                  WRIST (S) & HAND(S)
# 6162263                             42.0                      LOWER BACK AREA
#
#                  Zip Code Agreement Reached      WCB Decision  \
# Claim Identifier
# 5394177             20770               1.0  Not Work Related
# 5393953             11226               0.0  Not Work Related
# 5394099             11001               0.0  Not Work Related
# 5393830               NaN               0.0  Not Work Related
# 5394613             28115               0.0  Not Work Related
# ...                   ...               ...               ...
# 6156163             13316               0.0  Not Work Related
# 6158378             14569               0.0  Not Work Related
# 6160613             14092               0.0  Not Work Related
# 6162010             13501               0.0  Not Work Related
# 6162263             07407               0.0  Not Work Related
#
#                  Number of Dependents Diference
# Claim Identifier
# 5394177                             4  113 days
# 5393953                             0   94 days
# 5394099                             3  161 days
# 5393830                             1  245 days
# 5394613                             5  611 days
# ...                               ...       ...
# 6156163                             5       NaT
# 6158378                             6   87 days
# 6160613                             3   97 days
# 6162010                             6       NaT
# 6162263                             3       NaT
#
# [982 rows x 31 columns]

# %% [markdown]
# **Conclusion:** We have 982 occurrences where the Accident Date is after the C-2 Date, which makes no sense.

# %%
df_train_treat_missing['C-2 Date'] = pd.to_datetime(df_train_treat_missing['C-2 Date'])

# Identify rows with missing dates
missing_c2_dates = df_train_treat_missing['C-2 Date'].isna()

# Get the list of valid (non-missing) dates from the dataframe
valid_c2_dates = df_train_treat_missing['C-2 Date'].dropna()

# Randomly choose dates from valid dates
random_c2_dates = np.random.choice(valid_dates, size=missing_c2_dates.sum(), replace=True)

# Fill the missing dates with randomly selected valid dates
df_train_treat_missing.loc[missing_c2_dates, 'C-2 Date'] = random_c2_dates
random_c2_dates



df_train_treat_missing['C-3 Date'] = pd.to_datetime(df_train_treat_missing['C-3 Date'])

missing_c3_dates = df_train_treat_missing['C-3 Date'].isna()

valid_c3_dates = df_train_treat_missing['C-3 Date'].dropna()

random_c3_dates = np.random.choice(valid_c3_dates, size=missing_c3_dates.sum(), replace=True)

df_train_treat_missing.loc[missing_c3_dates, 'C-3 Date'] = random_c3_dates
random_c3_dates   



df_train_treat_missing['Accident Date'] = pd.to_datetime(df_train_treat_missing['Accident Date'])

missing_acc_dates = df_train_treat_missing['Accident Date'].isna()

valid_acc_dates = df_train_treat_missing['Accident Date'].dropna()

random_acc_dates = np.random.choice(valid_acc_dates, size=missing_acc_dates.sum(), replace=True)

df_train_treat_missing.loc[missing_acc_dates, 'Accident Date'] = random_acc_dates
random_acc_dates  



df_train_treat_missing['First Hearing Date'] = pd.to_datetime(df_train_treat_missing['First Hearing Date'])

missing_fh_dates = df_train_treat_missing['First Hearing Date'].isna()

valid_fh_dates = df_train_treat_missing['First Hearing Date'].dropna()

random_fh_dates = np.random.choice(valid_fh_dates, size=missing_fh_dates.sum(), replace=True)

df_train_treat_missing.loc[missing_fh_dates, 'First Hearing Date'] = random_fh_dates
random_fh_dates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/1748712578.py in <module>
#       8
#       9 # Randomly choose dates from valid dates
# ---> 10 random_c2_dates = np.random.choice(valid_dates, size=missing_c2_dates.sum(), replace=True)
#      11
#      12 # Fill the missing dates with randomly selected valid dates
#
# NameError: name 'valid_dates' is not defined

# %%
df_train_treat_missing['Accident Date'] = pd.to_datetime(df_train_treat_missing['Accident Date'])
df_train_treat_missing['C-2 Date'] = pd.to_datetime(df_train_treat_missing['C-2 Date'])
df_train_treat_missing['C-3 Date'] = pd.to_datetime(df_train_treat_missing['C-3 Date'])
df_train_treat_missing['Assembly Date'] = pd.to_datetime(df_train_treat_missing['Assembly Date'])
df_train_treat_missing['First Hearing Date'] = pd.to_datetime(df_train_treat_missing['First Hearing Date'])

# This Function will reorder dates if the condition is not met
def reorder_dates(row):
    dates = [row['Accident Date'], row['C-2 Date'], row['C-3 Date'], row['Assembly Date'], row['First Hearing Date']]
    sorted_dates = sorted(dates)
    row['Accident Date'], row['C-2 Date'], row['C-3 Date'], row['Assembly Date'], row['First Hearing Date'] = sorted_dates
    
    return row

df_train_treat_missing = df_train_treat_missing.apply(reorder_dates, axis=1)
df_train_treat_missing
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393875             2019-12-30           31.0                              N
# 5393091             2019-08-30           46.0                              N
# 5393889             2019-12-06           40.0                              N
# 5393887             2019-12-30           61.0                              N
# 5393863             2019-12-26           67.0                              N
# ...                        ...            ...                            ...
# 6165265             2022-12-14           35.0                              N
# 6165285             2022-12-15           33.0                              N
# 6165506             2022-12-13           61.0                              N
# 6165339             2022-12-14           24.0                              N
# 6165075             2022-12-13           72.0                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393875             2020-01-01                       N                 0.00
# 5393091             2020-01-14                       Y              1745.93
# 5393889             2020-01-01                       N              1434.80
# 5393887             2020-01-01                       N                  NaN
# 5393863             2020-01-01                       N                 0.00
# ...                        ...                     ...                  ...
# 6165265             2022-12-30                       N                 0.00
# 6165285             2022-12-31                       N                 0.00
# 6165506             2022-12-31                       N               991.08
# 6165339             2022-12-31                       N                 0.00
# 6165075             2022-12-31                       N                 0.00
#
#                   Birth Year   C-2 Date   C-3 Date  \
# Claim Identifier
# 5393875               1988.0 2019-12-31        NaT
# 5393091               1973.0 2020-01-01 2020-01-01
# 5393889               1979.0 2020-01-01        NaT
# 5393887               1958.0 2019-12-31        NaT
# 5393863               1952.0 2019-12-31        NaT
# ...                      ...        ...        ...
# 6165265               1987.0 2022-12-30        NaT
# 6165285               1989.0 2022-12-31        NaT
# 6165506               1961.0 2022-12-31        NaT
# 6165339               1998.0 2022-12-31        NaT
# 6165075               1950.0 2022-12-31        NaT
#
#                                     Carrier Name  ...  \
# Claim Identifier                                  ...
# 5393875               NEW HAMPSHIRE INSURANCE CO  ...
# 5393091             ZURICH AMERICAN INSURANCE CO  ...
# 5393889                INDEMNITY INSURANCE CO OF  ...
# 5393887                     STATE INSURANCE FUND  ...
# 5393863              INDEMNITY INS. OF N AMERICA  ...
# ...                                          ...  ...
# 6165265                     STATE INSURANCE FUND  ...
# 6165285                       WESCO INSURANCE CO  ...
# 6165506           SECURITY NATIONAL INSURANCE CO  ...
# 6165339            TECHNOLOGY INSURANCE CO. INC.  ...
# 6165075            TECHNOLOGY INSURANCE CO. INC.  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                               27.0
# 5393091                               97.0
# 5393889                               79.0
# 5393887                               16.0
# 5393863                               31.0
# ...                                    ...
# 6165265                               45.0
# 6165285                               74.0
# 6165506                               98.0
# 6165339                               59.0
# 6165075                               25.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393875                          FROM LIQUID OR GREASE SPILLS
# 5393091                                     REPETITIVE MOTION
# 5393889                        OBJECT BEING LIFTED OR HANDLED
# 5393887                       HAND TOOL, UTENSIL; NOT POWERED
# 5393863                               FALL, SLIP OR TRIP, NOC
# ...                                                       ...
# 6165265           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# 6165285                FELLOW WORKER, PATIENT OR OTHER PERSON
# 6165506                                       CUMULATIVE, NOC
# 6165339                               USING TOOL OR MACHINERY
# 6165075                      FROM DIFFERENT LEVEL (ELEVATION)
#
#                  WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# Claim Identifier
# 5393875                                10.0                         CONTUSION
# 5393091                                49.0                    SPRAIN OR TEAR
# 5393889                                 7.0                        CONCUSSION
# 5393887                                43.0                          PUNCTURE
# 5393863                                10.0                         CONTUSION
# ...                                     ...                               ...
# 6165265                                10.0                         CONTUSION
# 6165285                                37.0                      INFLAMMATION
# 6165506                                80.0  ALL OTHER CUMULATIVE INJURY, NOC
# 6165339                                59.0  ALL OTHER SPECIFIC INJURIES, NOC
# 6165075                                90.0   MULTIPLE PHYSICAL INJURIES ONLY
#
#                  WCIO Part Of Body Code WCIO Part Of Body Description  \
# Claim Identifier
# 5393875                            62.0                      BUTTOCKS
# 5393091                            38.0                   SHOULDER(S)
# 5393889                            10.0          MULTIPLE HEAD INJURY
# 5393887                            36.0                     FINGER(S)
# 5393863                            38.0                   SHOULDER(S)
# ...                                 ...                           ...
# 6165265                            42.0               LOWER BACK AREA
# 6165285                            35.0                          HAND
# 6165506                            34.0                         WRIST
# 6165339                            55.0                         ANKLE
# 6165075                            -9.0                      MULTIPLE
#
#                  Zip Code  Agreement Reached      WCB Decision  \
# Claim Identifier
# 5393875             13662                0.0  Not Work Related
# 5393091             14569                1.0  Not Work Related
# 5393889             12589                0.0  Not Work Related
# 5393887             12603                0.0  Not Work Related
# 5393863             11772                0.0  Not Work Related
# ...                   ...                ...               ...
# 6165265             10467                0.0  Not Work Related
# 6165285             11590                0.0  Not Work Related
# 6165506             14227                0.0  Not Work Related
# 6165339             10029                0.0  Not Work Related
# 6165075             12779                0.0  Not Work Related
#
#                  Number of Dependents
# Claim Identifier
# 5393875                           1.0
# 5393091                           4.0
# 5393889                           6.0
# 5393887                           1.0
# 5393863                           5.0
# ...                               ...
# 6165265                           4.0
# 6165285                           6.0
# 6165506                           3.0
# 6165339                           5.0
# 6165075                           3.0
#
# [572477 rows x 30 columns]

# %% [markdown]
# # 4.6. Outliers

# %% [markdown]
# ## 4.6.1 Outlier - Defining Features

# %%
df_outliers = df_train.copy()

# %% [markdown]
# - The way we work with metric features is different from the way we work with non-metric features, so we need to create lists of the different names of features and objects, with only the information about the types of features we want.

# %%
# defining metric and non-metric features 

non_metric_features = list(df_outliers.select_dtypes(exclude = np.number).set_index(df_outliers.index).columns) #todas as variaveis que são categóricas
metric_features = list(df_outliers.select_dtypes(include = np.number).set_index(df_outliers.index).columns) #apenas as que são numéricas (são as que interessam)

# %% [markdown]
# - Our first idea was test all the numeric features for outliers, but then we conclude that no make any sense: as the concept of outliers applies to continuous or discrete data with a broader range of values. So, we decided to include all variables except 'Agreement Reached' because is a binary variable and 'Number of Dependents'.

# %%
metric_features_final = ['Age at Injury','Average Weekly Wage', 'IME-4 Count', 'WCIO Cause of Injury Code', 'WCIO Nature of Injury Code', 'WCIO Part Of Body Code']

# %% [markdown]
# - The same applies to the categorical variables, not all variables make sense to test

# %%
non_metric_features_final = ['Alternative Dispute Resolution', 'Attorney/Representative', 'Carrier Type', 'COVID-19 Indicator', 'District Name', 'Gender', 'Medical Fee Region']

# %% [markdown]
# ## 4.6.2 Variables' Histograms

# %%
n_colums = min(4, len(non_metric_features_final))
n_rows = ceil(len(non_metric_features_final) / n_colums)

fig, axes = plt.subplots(n_rows, n_colums, figsize=(5 * n_colums, 4 * n_rows))

for i, column in enumerate(non_metric_features_final):
    row, col = divmod(i, n_colums)
    
    # Create histogram
    sns.histplot(data=df_outliers, x=column, ax=axes[row, col], color='grey')
    
    axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Hide any empty subplots
for j in range(i + 1, n_rows * n_colums):
    fig.delaxes(axes.flatten()[j])

plt.tight_layout()
plt.show()

# %%
#we can plot all numeric features variables histograms in one figure. 
fig, axes = plt.subplots(2, ceil(len(metric_features_final) / 2), figsize = (20, 11))

# ploting the data
# iterating across axes objects and associate each histogram:
for ax, feat in zip(axes.flatten(), metric_features_final):
    ax.hist(df_outliers[feat], bins = 10, color='grey')
    ax.set_title(feat, y = -0.15)

#Removing the empty axles
for ax in axes.flatten()[len(metric_features_final):]:
    fig.delaxes(ax)
    
# adding a centered title to the figure:
title = 'Numeric Variables - Histograms'
plt.suptitle(title)

# showing the plot
plt.show()

# %% [markdown]
# **Interpretation:** Upon analyzing the data, we can conclude that the "Age at Injury" distribution seems relatively uniform across ages 20 to 70, with a slight concentration at the extremes (ages close to 20 and 60).
# - The "Average Weekly Wage" variable displays a massive concentration of values near zero, with a few scattered values at very high levels (close to 1.5 million), this suggests the presence of extreme outliers.
# - 'IME-4' have many low values and a few high ones, is common in data with outliers.

# %%
# Creating boxplots for each numerical feature
fig, axes = plt.subplots(2, ceil(len(metric_features_final) / 2), figsize=(20, 11))

for ax, feat in zip(axes.flatten(), metric_features_final):
    sns.boxplot(data=df_outliers, x=feat, ax=ax, color='grey')
    ax.set_title(feat)

#Removing the empty axles
for ax in axes.flatten()[len(metric_features_final):]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# - By analyzing the boxplots we concluded that we have to focus on the variables 'Age at Injury', 'Average Weekly Wage', 'IME-4 Count' and ' WCIO Part of body Code'

# %%
# Creating distribution plots (distplots) for numeric features
fig, axes = plt.subplots(2, ceil(len(metric_features_final) / 2), figsize=(20, 11))

# Loop through the numeric features and create distribution plots
for ax, feat in zip(axes.flatten(), metric_features_final):
    sns.histplot(data=df_outliers, x=feat, kde=True, ax=ax, color='grey')  # kde=True adds a kernel density estimate
    ax.set_title(feat)

#Removing the empty axles
for ax in axes.flatten()[len(metric_features_final):]:
    fig.delaxes(ax)

# Adjust the layout to avoid overlap
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/2090497117.py in <module>
#       4 # Loop through the numeric features and create distribution plots
#       5 for ax, feat in zip(axes.flatten(), metric_features_final):
# ----> 6     sns.histplot(data=df_outliers, x=feat, kde=True, ax=ax, color='grey')  # kde=True adds a kernel density estimate
#       7     ax.set_title(feat)
#       8
#
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1430     if p.univariate:
#    1431
# -> 1432         p.plot_univariate_histogram(
#    1433             multiple=multiple,
#    1434             element=element,
#
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     653
#     654                 line_kws["color"] = to_rgba(sub_color, 1)
# --> 655                 line, = ax.plot(
#     656                     *line_args, **line_kws,
#     657                 )
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     485
#     486         if len(xy) == 2:
# --> 487             x = _check_1d(xy[0])
#     488             y = _check_1d(xy[1])
#     489         else:
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1325                     message='Support for multi-dimensional indexing')
#    1326
# -> 1327                 ndim = x[:, None].ndim
#    1328                 # we have definitely hit a pandas index or series object
#    1329                 # cast to a numpy array.
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
# -> 5419             disallow_ndim_indexing(result)
#    5420
#    5421         # NB: Using _constructor._simple_new would break if MultiIndex
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexers/utils.py in disallow_ndim_indexing(result)
#     339     """
#     340     if np.ndim(result) > 1:
# --> 341         raise ValueError(
#     342             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# ## 4.6.3 Filtering

# %% [markdown]
# ## 4.6.3.1 Filter 1 - IQR Method

# %% [markdown]
# We should as well solve the problem with the outliers: our initial idea was to use the **Z-score** method to identify and potentially remove outliers. However, this approach has its limitations, as it is only applicable to data columns that are normally distributed. Therefore, we decided to use the **Interquartile Range (IQR)** method to handle skewed distributions more effectively.

# %%
def Drop_Outliers_IQR(df, mf):

    Q1 = df[mf].quantile(0.25)
    Q3 = df[mf].quantile(0.75)
    IQR = (Q3 - Q1)

    upper_lim = Q3 + 1.5 * IQR
    lower_lim = Q1 - 1.5 * IQR
    
    # applying the calculated measures to filter the observations in our dataset and transforming the result into a pandas series
    filter = []
    for metric in mf:
        llim = lower_lim[metric]
        ulim = upper_lim[metric]
        filter.append(df[metric].between(llim, ulim, inclusive = 'both'))
        
    filter = pd.Series(np.all(filter, 0), index = df.index)
    
    # applying the filter to our dataframe
    df_filter = df[filter]

    return df_filter

# %%
outliers_filter1 = Drop_Outliers_IQR(df_outliers, metric_features_final)

# %%
# calculate the % of data after removing outliers

print('Percentage of data kept after removing outliers:', np.round((outliers_filter1.shape[0] / df_outliers[metric_features_final].shape[0]) * 100, 4))
# Out:
# Percentage of data kept after removing outliers: 14.8

# %% [markdown]
# **Conclusion:** As we can notice, this approach is problematic since it removes too much observations.

# %% [markdown]
# ## 4.6.3.2 Filter 2 - Manual

# %%
filter2 = (
    (df_outliers["Age at Injury"] <= 100) 
    &
    (df_outliers["WCIO Part Of Body Code"] >= 10)
    #&
    #(df_outliers["IME-4 Count"] <= 73)
)

# %%
outliers_filter2 = df_outliers[filter2]
print('Percentage of data kept after removing outliers:', np.round(outliers_filter2.shape[0] / df_outliers.shape[0] * 100, 4))
# Out:
# Percentage of data kept after removing outliers: 86.7572

# %% [markdown]
# So, in this case we are removing 10% of our observations, which is acceptable. So we will keep this approach, but should as well test our models with the dataset with the outliers in order to see the diference in the performance.
#
# On the manual filter we only included the variables `WCIO Part Of Body Code` and `Age at Injury` as these are the variables that are not acceptable in our case.

# %% [markdown]
# **Interpretation:**
# - Not all the outliers in our dataset are true outliers. For instance, regarding 'Age at Injury', the average life expectancy in New York is around 80.3 years. However, exceptions exist; only 888 individuals in our dataset are over 80, which is relatively small compared to the overall range of ages. Ages exceeding 100 years are considered unrealistic, so we decided to exclude these (142 individuals).
#
# - In the case of the 'WCIO Part Of Body Code', based on the WCIO tables, we conclude that the part of the body code must be a positive number. All other values are documented in the table. https://www.nycirb.org/digital-library/public/pdf_generate_paragraph?paragraph_id=A4E00D96-5539-4FD3-9489-41864CCC6503
#
# - The 'IME-4 Count' is more challenging to assess. Some injuries may not require an IME-4 form, and there is no established maximum for how many forms a person can have.
#
# - 'Industry Code': https://www.naics.com/search-naics-codes-by-industry/ (all the numbers seem correct)
# - 'WCIO Nature of Injury Code': https://www.nycirb.org/digital-library/public/pdf_generate_paragraph?paragraph_id=A4E00D96-5539-4FD3-9489-41864CCC6504 (same)
# - 'Average Weekly Wage': It is not correct to consider higher values as outliers and vice versa. There are people who earn above average, just as there are people who earn below. In this case, it is correct to conclude that all values are acceptable.

# %% [markdown]
# ### Insights
# - Ask teacher: about 'IME-4'

# %% [markdown]
# ## 4.6.3.3 Filter 3 - Winsorization

# %% [markdown]
# Winsorizing the data involves replacing the income outliers with the nearest non-outlier values. This ensures that the extreme values are still accounted for in the analysis, but their impact is minimized.

# %%
df_test = df_train.copy()

# %%
def apply_winsorization(df, col):
    upper_limit = df[col].quantile(0.90)
    lower_limit = df[col].quantile(0.10)

    df[col] = np.where(df[col] >= upper_limit,
                       upper_limit,
                       np.where(df[col] <= lower_limit,
                                lower_limit,
                                df[col]))

    return df

# %%
# Check min/max values before winsorization
before_winsorization = {
    "Age at Injury": (df_outliers['Age at Injury'].min(), df_outliers['Age at Injury'].max()),
    "IME-4 Count": (df_outliers['IME-4 Count'].min(), df_outliers['IME-4 Count'].max()),
    "WCIO Part Of Body Code": (df_outliers['WCIO Part Of Body Code'].min(), df_outliers['WCIO Part Of Body Code'].max())
}

apply_winsorization(df_test, "Age at Injury")
apply_winsorization(df_test, "WCIO Part Of Body Code")
apply_winsorization(df_test, "IME-4 Count")

# Check min/max values after winsorization
after_winsorization = {
    "Age at Injury": (df_test['Age at Injury'].min(), df_test['Age at Injury'].max()),
    "IME-4 Count": (df_test['IME-4 Count'].min(), df_outliers['IME-4 Count'].max()),
    "WCIO Part Of Body Code": (df_test['WCIO Part Of Body Code'].min(), df_test['WCIO Part Of Body Code'].max())
}

print("Before Winsorization:", before_winsorization)
print("After Winsorization:", after_winsorization)
# Out:
# Before Winsorization: {'Age at Injury': (0.0, 117.0), 'IME-4 Count': (1.0, 73.0), 'WCIO Part Of Body Code': (-9.0, 99.0)}
# After Winsorization: {'Age at Injury': (24.0, 61.0), 'IME-4 Count': (1.0, 73.0), 'WCIO Part Of Body Code': (11.0, 61.0)}

# %%
plt.figure(figsize=(20, 12))

# IME-4 Count
plt.subplot(3, 4, 1)
sns.histplot(df_outliers['IME-4 Count'], kde=True, color="grey")
plt.title('IME-4 Count - Before Winsorization (Density)')

plt.subplot(3, 4, 2)
sns.boxplot(y=df_outliers['IME-4 Count'], color="grey")
plt.title('IME-4 Count - Before Winsorization (Box)')

plt.subplot(3, 4, 3)
sns.histplot(df_test['IME-4 Count'], kde=True, color="grey")
plt.title('IME-4 Count - After Winsorization (Density)')

plt.subplot(3, 4, 4)
sns.boxplot(y=df_test['IME-4 Count'], color="grey")
plt.title('IME-4 Count - After Winsorization (Box)')

# Age at Injury
plt.subplot(3, 4, 5)
sns.histplot(df_outliers['Age at Injury'], kde=True, color="grey")
plt.title('Age at Injury - Before Winsorization (Density)')

plt.subplot(3, 4, 6)
sns.boxplot(y=df_outliers['Age at Injury'], color="grey")
plt.title('Age at Injury - Before Winsorization (Box)')

plt.subplot(3, 4, 7)
sns.histplot(df_test['Age at Injury'], kde=True, color="grey")
plt.title('Age at Injury - After Winsorization (Density)')

plt.subplot(3, 4, 8)
sns.boxplot(y=df_test['Age at Injury'], color="grey")
plt.title('Age at Injury - After Winsorization (Box)')

# WCIO Part Of Body Code
plt.subplot(3, 4, 9)
sns.histplot(df_outliers['WCIO Part Of Body Code'], kde=True, color="grey")
plt.title('WCIO Part Of Body Code - Before Winsorization (Density)')

plt.subplot(3, 4, 10)
sns.boxplot(y=df_outliers['WCIO Part Of Body Code'], color="grey")
plt.title('WCIO Part Of Body Code - Before Winsorization (Box)')

plt.subplot(3, 4, 11)
sns.histplot(df_test['WCIO Part Of Body Code'], kde=True, color="grey")
plt.title('WCIO Part Of Body Code - After Winsorization (Density)')

plt.subplot(3, 4, 12)
sns.boxplot(y=df_test['WCIO Part Of Body Code'], color="grey")
plt.title('WCIO Part Of Body Code - After Winsorization (Box)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/3141217190.py in <module>
#       3 # IME-4 Count
#       4 plt.subplot(3, 4, 1)
# ----> 5 sns.histplot(df_outliers['IME-4 Count'], kde=True, color="grey")
#       6 plt.title('IME-4 Count - Before Winsorization (Density)')
#       7
#
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1430     if p.univariate:
#    1431
# -> 1432         p.plot_univariate_histogram(
#    1433             multiple=multiple,
#    1434             element=element,
#
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     653
#     654                 line_kws["color"] = to_rgba(sub_color, 1)
# --> 655                 line, = ax.plot(
#     656                     *line_args, **line_kws,
#     657                 )
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     485
#     486         if len(xy) == 2:
# --> 487             x = _check_1d(xy[0])
#     488             y = _check_1d(xy[1])
#     489         else:
#
# ~/Library/Python/3.9/lib/python/site-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1325                     message='Support for multi-dimensional indexing')
#    1326
# -> 1327                 ndim = x[:, None].ndim
#    1328                 # we have definitely hit a pandas index or series object
#    1329                 # cast to a numpy array.
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
# -> 5419             disallow_ndim_indexing(result)
#    5420
#    5421         # NB: Using _constructor._simple_new would break if MultiIndex
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexers/utils.py in disallow_ndim_indexing(result)
#     339     """
#     340     if np.ndim(result) > 1:
# --> 341         raise ValueError(
#     342             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# ## 4.6.3.3 Filter 4 - LOF?

# %% [markdown]
# # TRAIN-VAL SPLIT

# %%
# creating an object named X that will contain the independent variables and another object named y that will contain the dependent variable/target

X = df_train.drop('Claim Injury Type', axis = 1)
y = df_train['Claim Injury Type']

# %%
# dividing the X into X_train and X_val, the y into y_train and y_val

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, 
                                                  random_state=0, 
                                                  stratify=y, 
                                                  shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/1127973610.py in <module>
#       1 # dividing the X into X_train and X_val, the y into y_train and y_val
#       2
# ----> 3 X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3,
#       4                                                   random_state=0,
#       5                                                   stratify=y,
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#    2161         return super().split(X, y, groups)
#    2162
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     917
#     918         if force_all_finite:
# --> 919             _assert_all_finite(
#     920                 array,
#     921                 input_name=input_name,
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     109     if X.dtype == np.dtype("object") and not allow_nan:
#     110         if _object_dtype_isnan(X).any():
# --> 111             raise ValueError("Input contains NaN")
#     112
#     113     # We need only consider float arrays, hence can early return for all else.
#
# ValueError: Input contains NaN

# %% [markdown]
# <img src="01_images/phase04.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# After the exploration and understanding of data, we need to fix possible problems on data like missing values or outliers and we can create new variables in order to get variables with higher predictive power. <br>
# At this moment, we are going to ignore this. <br>However, to create a predictive model we need to identify what are our independent variables and the dependent one (the target), as also we need to split our data into at least two different datasets - the train and the validation.

# %% [markdown]
# __`Step 11`__ Create a new dataset named as `X` that will include all the independent variables.

# %%
X = drugs_truth.iloc[:,:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/3036447899.py in <module>
# ----> 1 X = drugs_truth.iloc[:,:-1]
#
# NameError: name 'drugs_truth' is not defined

# %%
# or
# X = drugs_truth.drop(columns = 'DrugPlant')

# %%
X
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 0         2019-12-30           31.0                              N
# 1         2019-08-30           46.0                              N
# 2         2019-12-06           40.0                              N
# 3                NaN            NaN                            NaN
# 4         2019-12-30           61.0                              N
# ...              ...            ...                            ...
# 593466           NaN            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaN            NaN                            NaN
# 593469           NaN            NaN                            NaN
# 593470           NaN            NaN                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  Birth Year  \
# 0         2020-01-01                       N                 0.00      1988.0
# 1         2020-01-01                       Y              1745.93      1973.0
# 2         2020-01-01                       N              1434.80      1979.0
# 3         2020-01-01                     NaN                  NaN         NaN
# 4         2020-01-01                       N                  NaN      1958.0
# ...              ...                     ...                  ...         ...
# 593466    2022-12-31                     NaN                  NaN         NaN
# 593467    2022-12-31                       N                 0.00      1950.0
# 593468    2022-12-31                     NaN                  NaN         NaN
# 593469    2022-12-31                     NaN                  NaN         NaN
# 593470    2022-12-31                     NaN                  NaN         NaN
#
#           C-2 Date    C-3 Date                   Carrier Name  ...  \
# 0       2019-12-31         NaN     NEW HAMPSHIRE INSURANCE CO  ...
# 1       2020-01-01  2020-01-14   ZURICH AMERICAN INSURANCE CO  ...
# 2       2020-01-01         NaN      INDEMNITY INSURANCE CO OF  ...
# 3              NaN         NaN                            NaN  ...
# 4       2019-12-31         NaN           STATE INSURANCE FUND  ...
# ...            ...         ...                            ...  ...
# 593466         NaN         NaN                            NaN  ...
# 593467  2022-12-31         NaN  TECHNOLOGY INSURANCE CO. INC.  ...
# 593468         NaN         NaN                            NaN  ...
# 593469         NaN         NaN                            NaN  ...
# 593470         NaN         NaN                            NaN  ...
#
#        WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# 0                           27.0      FROM LIQUID OR GREASE SPILLS
# 1                           97.0                 REPETITIVE MOTION
# 2                           79.0    OBJECT BEING LIFTED OR HANDLED
# 3                            NaN                               NaN
# 4                           16.0   HAND TOOL, UTENSIL; NOT POWERED
# ...                          ...                               ...
# 593466                       NaN                               NaN
# 593467                      25.0  FROM DIFFERENT LEVEL (ELEVATION)
# 593468                       NaN                               NaN
# 593469                       NaN                               NaN
# 593470                       NaN                               NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# 0                            10.0                         CONTUSION
# 1                            49.0                    SPRAIN OR TEAR
# 2                             7.0                        CONCUSSION
# 3                             NaN                               NaN
# 4                            43.0                          PUNCTURE
# ...                           ...                               ...
# 593466                        NaN                               NaN
# 593467                       90.0   MULTIPLE PHYSICAL INJURIES ONLY
# 593468                        NaN                               NaN
# 593469                        NaN                               NaN
# 593470                        NaN                               NaN
#
#        WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# 0                        62.0                      BUTTOCKS    13662
# 1                        38.0                   SHOULDER(S)    14569
# 2                        10.0          MULTIPLE HEAD INJURY    12589
# 3                         NaN                           NaN      NaN
# 4                        36.0                     FINGER(S)    12603
# ...                       ...                           ...      ...
# 593466                    NaN                           NaN      NaN
# 593467                   -9.0                      MULTIPLE    12779
# 593468                    NaN                           NaN      NaN
# 593469                    NaN                           NaN      NaN
# 593470                    NaN                           NaN      NaN
#
#         Agreement Reached      WCB Decision Number of Dependents
# 0                     0.0  Not Work Related                  1.0
# 1                     1.0  Not Work Related                  4.0
# 2                     0.0  Not Work Related                  6.0
# 3                     NaN               NaN                  NaN
# 4                     0.0  Not Work Related                  1.0
# ...                   ...               ...                  ...
# 593466                NaN               NaN                  NaN
# 593467                0.0  Not Work Related                  3.0
# 593468                NaN               NaN                  NaN
# 593469                NaN               NaN                  NaN
# 593470                NaN               NaN                  NaN
#
# [593471 rows x 32 columns]

# %% [markdown]
# __`Step 12`__ Create a new dataset named as `y` that will include the dependent variable (the last column - DrugPlant)

# %%
y = drugs_truth.iloc[:,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/3814217491.py in <module>
# ----> 1 y = drugs_truth.iloc[:,-1]
#
# NameError: name 'drugs_truth' is not defined

# %%
# or
# y = drugs_truth['DrugPlant']

# %%
y
# Out:
# 0          2. NON-COMP
# 1         4. TEMPORARY
# 2         4. TEMPORARY
# 3                  NaN
# 4          2. NON-COMP
#               ...
# 593466             NaN
# 593467     2. NON-COMP
# 593468             NaN
# 593469             NaN
# 593470             NaN
# Name: Claim Injury Type, Length: 593471, dtype: object

# %% [markdown]
# __`Step 13`__ Using the `train_test_split()`, split the data into train and validation, where the training dataset should contain 70% of the observations. (We are going to talk more about this in a future class).

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X,y,
                                                               train_size = 0.7, 
                                                               shuffle = True, 
                                                               stratify = y) # to have the same percentage of 1s in train and test data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_88976/3467869721.py in <module>
# ----> 1 X_train, X_validation, y_train, y_validation = train_test_split(X,y,
#       2                                                                train_size = 0.7,
#       3                                                                shuffle = True,
#       4                                                                stratify = y) # to have the same percentage of 1s in train and test data
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#    2161         return super().split(X, y, groups)
#    2162
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     917
#     918         if force_all_finite:
# --> 919             _assert_all_finite(
#     920                 array,
#     921                 input_name=input_name,
#
# /usr/local/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     109     if X.dtype == np.dtype("object") and not allow_nan:
#     110         if _object_dtype_isnan(X).any():
# --> 111             raise ValueError("Input contains NaN")
#     112
#     113     # We need only consider float arrays, hence can early return for all else.
#
# ValueError: Input contains NaN

# %% [markdown]
# # 4.3. Missing Values Imputation

# %% [markdown]
# # 5. Creating New Features-Henry & Rodrigo

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split


df_train_features=df_train_treat_missing.copy()

# %%
# from sklearn.feature_selection import chi2
# from sklearn.preprocessing import LabelEncoder

# # Encode target if necessary
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(df_train_features['Claim Injury Type'])

# # Perform Chi-Square test on Medical Fee Region
# medical_fee_region_encoded = pd.get_dummies(df_train_features['Medical Fee Region'], drop_first=True)
# chi2_value, p_value = chi2(medical_fee_region_encoded, y)

# print("Chi-Square Test p-value for Medical Fee Region:", p_value)

# %%
#checking Data frame 
df_train_features.head(1).T
# Out:
# Claim Identifier                                        5393875
# Accident Date                               2019-12-30 00:00:00
# Age at Injury                                              31.0
# Alternative Dispute Resolution                                N
# Assembly Date                               2020-01-01 00:00:00
# Attorney/Representative                                       N
# Average Weekly Wage                                         0.0
# Birth Year                                               1988.0
# C-2 Date                                    2019-12-31 00:00:00
# C-3 Date                                                    NaT
# Carrier Name                         NEW HAMPSHIRE INSURANCE CO
# Carrier Type                                        1A. PRIVATE
# Claim Injury Type                                   2. NON-COMP
# County of Injury                                   ST. LAWRENCE
# COVID-19 Indicator                                            N
# District Name                                          SYRACUSE
# First Hearing Date                                          NaT
# Gender                                                        M
# Industry Code                                              44.0
# Industry Code Description                          RETAIL TRADE
# Medical Fee Region                                            I
# WCIO Cause of Injury Code                                  27.0
# WCIO Cause of Injury Description   FROM LIQUID OR GREASE SPILLS
# WCIO Nature of Injury Code                                 10.0
# WCIO Nature of Injury Description                     CONTUSION
# WCIO Part Of Body Code                                     62.0
# WCIO Part Of Body Description                          BUTTOCKS
# Zip Code                                                  13662
# Agreement Reached                                           0.0
# WCB Decision                                   Not Work Related
# Number of Dependents                                        1.0

# %% [markdown]
# We created features that capture various aspects of the data, including timing, socioeconomic indicators, carrier characteristics, injury causes, and affected body regions. These features should provide a comprehensive basis for our predictive model.

# %% [markdown]
# # Features Extraction

# %%
# Calculate time-based features

#Encode Target Variable 
label_encoder = LabelEncoder()
df_train_features['Claim Injury Type'] = label_encoder.fit_transform(df_train_features['Claim Injury Type']) 
#Encode Medical Region
df_train_features = pd.get_dummies(df_train_features, columns=['Medical Fee Region'], drop_first=True)

df_train_features['processing_time'] = (pd.to_datetime(df_train_features['Assembly Date']) - pd.to_datetime(df_train_features['Accident Date'])).dt.days
# df_train_features['first_hearing_delay'] = (pd.to_datetime(df_train_features['First Hearing Date']) - pd.to_datetime(df_train_features['Assembly Date'])).dt.days

# Add missing indicator for first hearing delay
# df_train_features['first_hearing_missing'] = df_train_features['first_hearing_delay'].isnull().astype(int)

# Extract year and month from Accident Date for temporal analysis
df_train_features['accident_year'] = pd.to_datetime(df_train_features['Accident Date']).dt.year
df_train_features['accident_month'] = pd.to_datetime(df_train_features['Accident Date']).dt.month

# Encode age group and combine age and wage for interaction effects
df_train_features['high_income'] = (df_train_features['Average Weekly Wage'] > df_train_features['Average Weekly Wage'].median()).astype(int)
df_train_features['age_wage_interaction'] = df_train_features['Age at Injury'] * df_train_features['Average Weekly Wage']
df_train_features['has_attorney'] = (df_train_features['Attorney/Representative'] == 'Y').astype(int)
df_train_features['has_dependents'] = (df_train_features['Number of Dependents'] > 0).astype(int)

# Define carrier type flags
df_train_features['carrier_private'] = df_train_features['Carrier Type'].isin(['1A. PRIVATE', '4A. SELF PRIVATE']).astype(int)
df_train_features['carrier_self_public'] = (df_train_features['Carrier Type'] == '3A. SELF PUBLIC').astype(int)
df_train_features['carrier_sif'] = (df_train_features['Carrier Type'] == '2A. SIF').astype(int)
df_train_features['carrier_special_fund'] = df_train_features['Carrier Type'].str.contains('SPECIAL FUND', case=False, na=False).astype(int)
df_train_features['carrier_unknown'] = (df_train_features['Carrier Type'] == 'UNKNOWN').astype(int)

# Create interactions with carrier types
df_train_features['private_with_attorney'] = df_train_features['carrier_private'] * df_train_features['has_attorney']
df_train_features['self_public_with_attorney'] = df_train_features['carrier_self_public'] * df_train_features['has_attorney']
df_train_features['private_high_income'] = df_train_features['carrier_private'] * df_train_features['high_income']
df_train_features['sif_high_income'] = df_train_features['carrier_sif'] * df_train_features['high_income']

# Group injury cause categories
df_train_features['cause_injury_lifting'] = df_train_features['WCIO Cause of Injury Description'].str.contains('LIFTING|STRAIN OR INJURY BY', case=False, na=False).astype(int)
df_train_features['cause_injury_fall_trip'] = df_train_features['WCIO Cause of Injury Description'].str.contains('FALL|TRIP|SLIP|ON SAME LEVEL', case=False, na=False).astype(int)
df_train_features['cause_injury_patient_interaction'] = df_train_features['WCIO Cause of Injury Description'].str.contains('FELLOW WORKER|PATIENT|OTHER PERSON', case=False, na=False).astype(int)
df_train_features['cause_injury_mechanical'] = df_train_features['WCIO Cause of Injury Description'].str.contains('MACHINERY|EQUIPMENT|HAND TOOL', case=False, na=False).astype(int)
df_train_features['cause_injury_environmental'] = df_train_features['WCIO Cause of Injury Description'].str.contains('MOLD|ABNORMAL AIR PRESSURE|RADIATION', case=False, na=False).astype(int)
df_train_features['cause_injury_vehicle'] = df_train_features['WCIO Cause of Injury Description'].str.contains('CRASH|VEHICLE', case=False, na=False).astype(int)

# Group body part categories
df_train_features['part_upper_body'] = df_train_features['WCIO Part Of Body Description'].str.contains('SHOULDER|UPPER ARM|UPPER BACK|HAND|THUMB', case=False, na=False).astype(int)
df_train_features['part_lower_body'] = df_train_features['WCIO Part Of Body Description'].str.contains('KNEE|ANKLE|LOWER LEG|FOOT|TOES|HIP', case=False, na=False).astype(int)
df_train_features['part_head_neck'] = df_train_features['WCIO Part Of Body Description'].str.contains('SKULL|FACIAL BONES|EYE|NOSE|EAR|HEAD', case=False, na=False).astype(int)
df_train_features['part_trunk_spine'] = df_train_features['WCIO Part Of Body Description'].str.contains('CHEST|ABDOMEN|LUMBAR|VERTEBRAE|BACK', case=False, na=False).astype(int)
df_train_features['part_internal'] = df_train_features['WCIO Part Of Body Description'].str.contains('LUNGS|HEART|BRAIN|INTERNAL ORGANS|BODY SYSTEMS', case=False, na=False).astype(int)

# %%
#Drop columns representing engineered features
df_train_features = df_train_features.drop(columns=[
    'Number of Dependents','Accident Date', 'Assembly Date', 'First Hearing Date', 'Age at Injury', 'Average Weekly Wage',
    'Alternative Dispute Resolution', 'Attorney/Representative', 
    'Gender', 'COVID-19 Indicator', 'District Name', 'County of Injury', 'Zip Code', 
    'Carrier Name', 'Industry Code', 'Industry Code Description', 
    'Birth Year', 'C-2 Date', 'C-3 Date', 'WCB Decision',
    'WCIO Cause of Injury Code','WCIO Cause of Injury Description','WCIO Part Of Body Description', 'WCIO Nature of Injury Code', 'WCIO Nature of Injury Description', 
    'WCIO Part Of Body Code','Carrier Name','Carrier Type'
])

# %%
df_train_features.head(1).T
# Out:
# Claim Identifier                 5393875
# Claim Injury Type                      1
# Agreement Reached                    0.0
# Medical Fee Region_II              False
# Medical Fee Region_III             False
# Medical Fee Region_IV              False
# processing_time                      2.0
# accident_year                     2019.0
# accident_month                      12.0
# high_income                            0
# age_wage_interaction                 0.0
# has_attorney                           0
# has_dependents                         1
# carrier_private                        1
# carrier_self_public                    0
# carrier_sif                            0
# carrier_special_fund                   0
# carrier_unknown                        0
# private_with_attorney                  0
# self_public_with_attorney              0
# private_high_income                    0
# sif_high_income                        0
# cause_injury_lifting                   0
# cause_injury_fall_trip                 0
# cause_injury_patient_interaction       0
# cause_injury_mechanical                0
# cause_injury_environmental             0
# cause_injury_vehicle                   0
# part_upper_body                        0
# part_lower_body                        0
# part_head_neck                         0
# part_trunk_spine                       0
# part_internal                          0

# %%
#Check for missing values in each column 
# Check for missing values in each column
missing_values = df_train_features.isnull().sum()

# Filter columns with missing values only
missing_columns = missing_values[missing_values > 0]

# Display the count and percentage of missing values in each column
missing_info = pd.DataFrame({
    'Missing Count': missing_columns,
    'Missing Percentage': (missing_columns / len(df_train_features)) * 100
})

print("Columns with missing values:\n", missing_info)
# Out:
# Columns with missing values:
#  Empty DataFrame
# Columns: [Missing Count, Missing Percentage]
# Index: []

# %%
#Imputing those values since they have a low percentage 
from sklearn.impute import SimpleImputer

#convert columns to int

df_train_features = df_train_features.astype({col: 'int' for col in df_train_features.select_dtypes(include=['bool']).columns})


# List of columns to impute
columns_to_impute = ['processing_time', 'accident_month', 'age_wage_interaction','accident_year']

# Create an imputer with the median strategy
median_imputer = SimpleImputer(strategy='median')

# Apply imputer to the selected columns
df_train_features[columns_to_impute] = median_imputer.fit_transform(df_train_features[columns_to_impute])

# Verify if there are any remaining NaN values
print("Remaining missing values:\n", df_train_features[columns_to_impute].isnull().sum())
# Out:
# Remaining missing values:
#  processing_time         0
# accident_month          0
# age_wage_interaction    0
# accident_year           0
# dtype: int64

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Filter Method

# %%
import numpy as np


# Calculate correlation matrix
corr_matrix = df_train_features.corr().abs()

# Select upper triangle of correlation matrix
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.85
high_corr_features = [column for column in upper_tri.columns if any(upper_tri[column] > 0.85)]

# Drop highly correlated features
df_train_features = df_train_features.drop(columns=high_corr_features)
print("Remaining features after correlation filter:", df_train_features.columns)
# Out:
# Remaining features after correlation filter: Index(['Claim Injury Type', 'Agreement Reached', 'Medical Fee Region_II',
#        'Medical Fee Region_III', 'Medical Fee Region_IV', 'processing_time',
#        'accident_month', 'high_income', 'age_wage_interaction', 'has_attorney',
#        'has_dependents', 'carrier_private', 'carrier_self_public',
#        'carrier_sif', 'carrier_special_fund', 'carrier_unknown',
#        'private_with_attorney', 'self_public_with_attorney',
#        'private_high_income', 'sif_high_income', 'cause_injury_lifting',
#        'cause_injury_fall_trip', 'cause_injury_patient_interaction',
#        'cause_injury_mechanical', 'cause_injury_environmental',
#        'cause_injury_vehicle', 'part_upper_body', 'part_lower_body',
#        'part_head_neck', 'part_trunk_spine', 'part_internal'],
#       dtype='object')

# %%
# Check again for any remaining missing values in each column
remaining_missing = df_train_features.isnull().sum()
missing_columns = remaining_missing[remaining_missing > 0]

# Display columns with missing values, if any
print("Remaining columns with missing values:\n", missing_columns)


# Check for NaNs in feature set (X)
X = X.apply(pd.to_numeric, errors='coerce')

# Ensure y is integer type
y = y.astype(int)

# %% [markdown]
# ### Wrapper Method

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)

rfe_selector = RFE(estimator=model, n_features_to_select=42, step=5)
rfe_selector.fit(df_train_features.drop(columns=['Claim Injury Type']), y)

# Get selected features
selected_features_rfe = df_train_features.drop(columns=['Claim Injury Type']).columns[rfe_selector.support_]
print("Selected Features using RFE:", selected_features_rfe)
# Out:
# Selected Features using RFE: Index(['Agreement Reached', 'Medical Fee Region_II', 'Medical Fee Region_III',
#        'Medical Fee Region_IV', 'processing_time', 'accident_year',
#        'accident_month', 'high_income', 'age_wage_interaction', 'has_attorney',
#        'has_dependents', 'carrier_private', 'carrier_self_public',
#        'carrier_sif', 'carrier_special_fund', 'carrier_unknown',
#        'private_with_attorney', 'self_public_with_attorney',
#        'private_high_income', 'sif_high_income', 'cause_injury_lifting',
#        'cause_injury_fall_trip', 'cause_injury_patient_interaction',
#        'cause_injury_mechanical', 'cause_injury_environmental',
#        'cause_injury_vehicle', 'part_upper_body', 'part_lower_body',
#        'part_head_neck', 'part_trunk_spine', 'part_internal'],
#       dtype='object')

# %% [markdown]
# ### Embedded Methods

# %%
# Fit model to get feature importance
model.fit(df_train_features.drop(columns=['Claim Injury Type']), y)
feature_importances = pd.Series(model.feature_importances_, index=df_train_features.drop(columns=['Claim Injury Type']).columns).sort_values(ascending=False)

print("Feature Importances from Random Forest:\n", feature_importances)
# Out:
# Feature Importances from Random Forest:
#  age_wage_interaction                0.216288
# processing_time                     0.206753
# high_income                         0.145898
# accident_month                      0.098242
# private_high_income                 0.059822
# has_attorney                        0.047093
# Agreement Reached                   0.042435
# accident_year                       0.031058
# sif_high_income                     0.021069
# private_with_attorney               0.020631
# self_public_with_attorney           0.011365
# has_dependents                      0.010497
# part_trunk_spine                    0.008886
# part_upper_body                     0.007904
# Medical Fee Region_IV               0.007447
# cause_injury_fall_trip              0.006646
# Medical Fee Region_II               0.006296
# cause_injury_lifting                0.006119
# part_lower_body                     0.006107
# Medical Fee Region_III              0.005536
# part_internal                       0.004983
# carrier_private                     0.004626
# cause_injury_vehicle                0.004513
# cause_injury_patient_interaction    0.004365
# carrier_self_public                 0.004148
# part_head_neck                      0.003956
# carrier_sif                         0.003854
# cause_injury_mechanical             0.003173
# carrier_special_fund                0.000212
# cause_injury_environmental          0.000077
# carrier_unknown                     0.000000
# dtype: float64

# %% [markdown]
# The most important features are age_wage_interaction, processing_time, and high_income, followed by accident_month, private_high_income, and has_attorney. These features have substantially higher importance scores, making them strong candidates for the final model.

# %% [markdown]
# ### ANOVA F-TEST

# %%
numerical_features = df_train_features.select_dtypes(include=['float64', 'int64'])
categorical_features = df_train_features.select_dtypes(include=['object'])


from sklearn.feature_selection import f_classif

# Perform ANOVA F-Test on imputed numerical features
f_values, p_values = f_classif(numerical_features, df_train_features['Claim Injury Type'])

anova_results = pd.DataFrame({
    'Feature': numerical_features.columns,
    'F-Value': f_values,
    'P-Value': p_values
}).sort_values(by='F-Value', ascending=False)

print(anova_results)
# Out:
#                              Feature       F-Value        P-Value
# 0                  Claim Injury Type           inf   0.000000e+00
# 8                        high_income  2.417183e+05   0.000000e+00
# 10                      has_attorney  4.898968e+04   0.000000e+00
# 19               private_high_income  3.743035e+04   0.000000e+00
# 17             private_with_attorney  1.353595e+04   0.000000e+00
# 1                  Agreement Reached  1.234373e+04   0.000000e+00
# 20                   sif_high_income  1.215300e+04   0.000000e+00
# 18         self_public_with_attorney  1.153229e+04   0.000000e+00
# 30                  part_trunk_spine  1.717317e+03   0.000000e+00
# 13               carrier_self_public  1.593739e+03   0.000000e+00
# 12                   carrier_private  1.509416e+03   0.000000e+00
# 14                       carrier_sif  1.156947e+03   0.000000e+00
# 31                     part_internal  1.056385e+03   0.000000e+00
# 28                   part_lower_body  8.936532e+02   0.000000e+00
# 9               age_wage_interaction  8.442964e+02   0.000000e+00
# 27                   part_upper_body  7.980671e+02   0.000000e+00
# 26              cause_injury_vehicle  7.589940e+02   0.000000e+00
# 29                    part_head_neck  7.369127e+02   0.000000e+00
# 5                    processing_time  7.138939e+02   0.000000e+00
# 6                      accident_year  6.844869e+02   0.000000e+00
# 21              cause_injury_lifting  4.340182e+02   0.000000e+00
# 4              Medical Fee Region_IV  3.014305e+02   0.000000e+00
# 22            cause_injury_fall_trip  2.838384e+02   0.000000e+00
# 24           cause_injury_mechanical  1.684969e+02  3.529605e-250
# 23  cause_injury_patient_interaction  1.302100e+02  2.291076e-192
# 2              Medical Fee Region_II  9.183544e+01  1.713647e-134
# 7                     accident_month  4.940981e+01   9.931364e-71
# 15              carrier_special_fund  3.157566e+01   4.071002e-44
# 3             Medical Fee Region_III  1.106974e+01   4.485127e-14
# 25        cause_injury_environmental  5.810693e+00   9.351963e-07
# 11                    has_dependents  4.954071e-01   8.386185e-01
# 16                   carrier_unknown           NaN            NaN

# %% [markdown]
# Features with the highest F-values and low p-values (e.g., high_income, has_attorney, private_high_income, private_with_attorney, etc.) are highly significant. Also features with moderate F-values, like processing_time, accident_year, and various Medical Fee Region and cause_injury_* columns, still have strong statistical significance

# %% [markdown]
# ### Insights
# Keep features with high F-values (e.g., high_income, has_attorney, private_high_income, Agreement Reached, age_wage_interaction, etc.). Include moderate-impact features like processing_time, accident_year, and Medical Fee Region columns in the initial model training, we will be  re-evaluating if they contribute minimally to the model's predictive performance.Drop low impact features

# %%
selected_features = [
    'high_income', 'has_attorney', 'private_high_income', 'Agreement Reached',
    'age_wage_interaction', 'processing_time', 'accident_month', 'accident_year',
    'Medical Fee Region_II', 'Medical Fee Region_III', 'Medical Fee Region_IV',
    'cause_injury_lifting', 'cause_injury_fall_trip', 'cause_injury_mechanical',
    'part_upper_body', 'part_trunk_spine', 'part_head_neck'
]

# Final feature set
X_final = X[selected_features]
print("Final selected features:", X_final.columns)
# Out:
# Final selected features: Index(['high_income', 'has_attorney', 'private_high_income',
#        'Agreement Reached', 'age_wage_interaction', 'processing_time',
#        'accident_month', 'accident_year', 'Medical Fee Region_II',
#        'Medical Fee Region_III', 'Medical Fee Region_IV',
#        'cause_injury_lifting', 'cause_injury_fall_trip',
#        'cause_injury_mechanical', 'part_upper_body', 'part_trunk_spine',
#        'part_head_neck'],
#       dtype='object')

# %%
# # df_train_features['first_hearing_delay'].head(100).T
# missing_rate = df_train_features['first_hearing_delay'].isnull().mean()
# print(f"Missing Rate of first_hearing_delay: {missing_rate * 100:.2f}%")
# correlation_with_target = df_train_features['first_hearing_delay'].corr(df_train_features['Claim Injury Type Encoded'])
# print("Correlation with Claim Injury Type:", correlation_with_target)

# %%
# from sklearn.preprocessing import LabelEncoder

# # Convert 'Claim Injury Type' to numeric labels
# label_encoder = LabelEncoder()
# df_train_features['Claim Injury Type Encoded'] = label_encoder.fit_transform(df_train_features['Claim Injury Type'])

# # Now calculate the correlation
# correlation_with_target = df_train_features['processing_time'].corr(df_train_features['Claim Injury Type Encoded'])
# print("Correlation with Processing Time", correlation_with_target)

# %%
# numerical_features = df_train_features.select_dtypes(include=['int64', 'float64'])

# # Calculate the correlation matrix with the encoded target
# correlation_matrix = numerical_features.corr()

# # Extract the correlation values for the encoded target variable
# target_correlations = correlation_matrix['Claim Injury Type'].sort_values(ascending=False)
# print("Correlation of each feature with the target variable:\n", target_correlations)
# Out:
# Correlation of each feature with the target variable:
#  Claim Injury Type                   1.000000
# high_income                         0.828563
# has_attorney                        0.581481
# private_high_income                 0.510520
# private_with_attorney               0.347508
# sif_high_income                     0.333888
# self_public_with_attorney           0.289227
# Agreement Reached                   0.224826
# age_wage_interaction                0.099042
# carrier_sif                         0.091570
# part_lower_body                     0.082216
# cause_injury_vehicle                0.064680
# part_upper_body                     0.060208
# cause_injury_lifting                0.056596
# carrier_self_public                 0.047264
# cause_injury_fall_trip              0.041600
# Medical Fee Region_IV               0.040134
# part_trunk_spine                    0.021351
# processing_time                     0.020711
# carrier_special_fund                0.004889
# has_dependents                      0.001175
# cause_injury_environmental         -0.006835
# Medical Fee Region_III             -0.008427
# cause_injury_patient_interaction   -0.009158
# Medical Fee Region_II              -0.019103
# accident_month                     -0.020331
# accident_year                      -0.027256
# cause_injury_mechanical            -0.030152
# part_internal                      -0.074409
# part_head_neck                     -0.079193
# carrier_private                    -0.109176
# carrier_unknown                          NaN
# Name: Claim Injury Type, dtype: float64

# %% [markdown]
# # 5. Creating New Features

# %% [markdown]
# 3.2. New features
# We can create multiple new variables in order to try to extract some useful information. Some examples are:
#
# Age gives us the age of the patient, based on the BirthYear and the current year.

# %%
df_train_treat_missing = df_train_treat_missing.loc[:,~df_train_treat_missing.columns.isin(['Industry Code','WCIO Cause of Injury Code',
                                                                   'WCIO Nature of Injury Code','WCIO Part Of Body Code','IME-4 Count'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_68031/4052773481.py in <module>
# ----> 1 df_train_treat_missing = df_train_treat_missing.loc[:,~df_train_treat_missing.columns.isin(['Industry Code','WCIO Cause of Injury Code',
#       2                                                                    'WCIO Nature of Injury Code','WCIO Part Of Body Code','IME-4 Count'])]
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
claim_injury_severity = []
for i in df_train_treat_missing.index:
    claim_injury_severity.append(int(df_train_treat_missing["Claim Injury Type"][i][0]))

df_train_treat_missing["Claim Severity"] = claim_injury_severity 
df_train_treat_missing["Claim Severity"]# a rank of how much will be lost in monetary terms. 8 represents high monetary loss, 1 low monetary loss

# %%
df_train_treat_missing["Claim Injury Type"] = df_train_treat_missing['Claim Injury Type'].str.replace(r'^\d+\.', '', regex=True)
df_train_treat_missing["Claim Injury Type"]

# %%
def clean_carrier_type(carrier):
    if isinstance(carrier, str):  # Check if the carrier is a string
        return carrier.split('.', 1)[-1].strip() if '.' in carrier else carrier.strip()
    return carrier  # Return the value unchanged if it's not a string (e.g., NaN)

df_train_treat_missing["Carrier Type"] = df_train_treat_missing["Carrier Type"].apply(clean_carrier_type)
df_train_treat_missing["Carrier Type"]

# %%
damage = {"no recovery time needed":["NO PHYSICAL INJURY"], 
         "short term recovery": ["CONTUSION", "SPRAIN OR TEAR", "STRAIN OR TEAR", "BURN", "INFECTION", "CRUSHING", "SYNCOPE"],
         "mid term recovery": ["VDT-RELATED DISEASES","FOREIGN BODY","CONCUSSION", "LACERATION", "FRACTURE", "DISLOCATION", "RUPTURE", "HERNIA" ,"DERMATITIS", "AMPUTATION", "VISION LOSS"],
         "long term recovery": ["LOSS OF HEARING","INFLAMMATION" ,"ANGINA PECTORIS" ,"CARPAL TUNNEL SYNDROME", "HEARING LOSS OR IMPAIRMENT" ,"MENTAL STRESS" ,"ELECTRIC SHOCK" ,"DUST DISEASE, NOC" ,"ASBESTOSIS" ,"SILICOSIS" ,"RADIATION" ,"HEPATITIS C"],
         "permanent damage": ["AIDS","ENUCLEATION","SEVERANCE","RESPIRATORY DISORDER","PUNCTURE","MULTIPLE PHYSICAL INJURIES ONLY" ,"ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC" ,"ALL OTHER SPECIFIC INJURIES, NOC" ,"ALL OTHER CUMULATIVE INJURY, NOC" ,"MENTAL DISORDER" ,"CONTAGIOUS DISEASE" ,"MYOCARDIAL INFARCTION" ,"CANCER" ,"COVID-19" ,"ADVERSE REACTION TO A VACCINATION OR INOCULATION" ,"FREEZING" ,"BLACK LUNG" ,"BYSSINOSIS" ,"POISONING - GENERAL (NOT OD OR CUMULATIVE)" ,"POISONING - CHEMICAL, (OTHER THAN METALS)" ,"POISONING - METAL" ,"MULTIPLE INJURIES INCLUDING BOTH PHYSICAL AND PSYCHOLOGICAL" ,"HEAT PROSTRATION"]}

damage_flat = {injury: recovery_time for recovery_time, injuries in damage.items() for injury in injuries}

# Function to assign expected recovery time
def assign_recovery_time(injury):
    return damage_flat.get(injury, np.nan)

df_train_treat_missing["Expected Recovery Time"] = df_train_treat_missing["WCIO Nature of Injury Description"].apply(assign_recovery_time)

df_train_treat_missing["Expected Recovery Time"]

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency
cat_var = df_train_treat_missing[['Accident Date',
                                  'Alternative Dispute Resolution',
                                  'Assembly Date', 
                                  'Attorney/Representative',
                                  'Birth Year', 
                                  'C-2 Date', 
                                  'C-3 Date', 
                                  'Carrier Name', 
                                  'Carrier Type',
                                  'County of Injury', 
                                  'COVID-19 Indicator',
                                  'District Name', 
                                  'First Hearing Date', 
                                  'Gender',
                                  'Industry Code Description', 
                                  'Medical Fee Region',
                                  'WCIO Cause of Injury Description', 
                                  'WCIO Nature of Injury Description',
                                  'WCIO Part Of Body Description', 
                                  'Zip Code', 
                                  'Agreement Reached',
                                  'WCB Decision',
                                  'Claim Severity',
                                  'Expected Recovery Time']]

target = df_train_treat_missing["Claim Injury Type"]


def TestIndependence(X,y,var,alpha=0.05):        
    dfObserved = pd.crosstab(y,X) 
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    dfExpected = pd.DataFrame(expected, columns=dfObserved.columns, index = dfObserved.index)
    if p<alpha:
        result="{0} is IMPORTANT for Prediction".format(var)
    else:
        result="{0} is NOT an important predictor. (Discard {0} from model)".format(var)
    print(result)


for var in cat_var:
    TestIndependence(cat_var[var],target, var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/91/jkcwqfq53b39k8bfrbhqbjrw0000gn/T/ipykernel_68031/69745462.py in <module>
#       1 import scipy.stats as stats
#       2 from scipy.stats import chi2_contingency
# ----> 3 cat_var = df_train_treat_missing[['Accident Date',
#       4                                   'Alternative Dispute Resolution',
#       5                                   'Assembly Date',
#
# TypeError: list indices must be integers or slices, not list

# %% [markdown]
# # 5. Modelling - Create a predictive model

# %% [markdown]
# It is time to create a model. At this step, we are going to implement a simple algorithm named as "Decision Trees".

# %% [markdown]
# <img src="01_images/phase05.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# __`Step 14`__ Create an instance of a DecisionTreeClassifier named as `dt` with the default parameters and fit the instance to the training data (again, we are going to talk more about this later).

# %%
dt = DecisionTreeClassifier().fit(X_train, y_train)

# %% [markdown]
# __`Step 15`__ Using the model just created in the previous step, predict the values of the target in the train dataset using the method `.predict()`. Assign those values to the object `predictions_train`

# %%
predictions_train = dt.predict(X_train)

# %% [markdown]
# __`Step 16`__ Similarly to what you have done in the previous step, predict the target values for the validation dataset and assign those values to the object `predictions_val`

# %%
predictions_val = dt.predict(X_validation)

# %% [markdown]
# # 6. Assess

# %% [markdown]
# We already have the ground truth and the predicted values. In this way we can start evaluating the performance of our model in the train and the validation dataset.

# %% [markdown]
# <img src="01_images/phase06.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# __`Step 17`__ Using the method `.score()`, check the mean accuracy of the model `dt`in the train dataset.

# %%
dt.score(X_train, y_train)

# %% [markdown]
# __`Step 18`__ Similarly to what you have done in step 17, check the mean accuracy now for the validation dataset.

# %%
dt.score(X_validation, y_validation)

# %% [markdown]
# Are we dealing with a case of __overfitting__? <br>
# Yes, decision trees are known to be prone to overfitting. <br>
# Luckily, there are strategies to avoid this problem. <br>
# We are going to understand better what is overfitting and how to avoid it in the different algorithms in the next classes.

# %% [markdown]
# It is time to check the confusion matrix of the model for the training and the validation dataset. <br> <br>
# __`Step 19`__ Check the confusion matrix for the training dataset, passing as parameters the ground truth (y_train) and the predicted values (predictions_train)<br>
# [[TN, FP],<br>
# [FN. TP]]

# %%
confusion_matrix(y_train, predictions_train)

# %% [markdown]
# __`Step 20`__ Do the same for the validation dataset.

# %%
confusion_matrix(y_validation, predictions_val)

# %% [markdown]
# __Can we conclude something from the results above?__ <br>It seems that our model is not so good at predicting the 1's in the target. <br>__Why?__ <br>Because we are dealing with an unbalanced dataset (more about this in the future).
#
# We are going to learn also different metrics that allow to understant better the performance of our model in unbalanced datasets - the mean accuracy is not a good metric to evaluate those cases.

# %% [markdown]
# # 7. Deploy

# %% [markdown]
# In the end, we want to classify the unclassified data. If we are already satisfied with our model, we can now predict the target to the new dataset.

# %% [markdown]
# __`Step 21`__ Check the dataset that we want to classify, imported as `drugs_2classify`

# %%
# test data
drugs_2classify

# %% [markdown]
# __`Step 22`__ Using the `.predict()` method and the model created named as `dt`, predict the target on the new dataset and assign those values to a column named as `DrugPlant`

# %%
drugs_2classify['DrugPlant'] = dt.predict(drugs_2classify)

# %% [markdown]
# __`Step 23`__ Check the new dataset.

# %%
drugs_2classify

# %% [markdown]
# Now we have already predicted the target for our new dataset! Next, if we wish to save a set of predictions, we can export a solution to a csv file.

# %%
#export test data predictions
drugs_2classify['DrugPlant'].to_csv('Exercise1_predictions.csv')
